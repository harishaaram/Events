# %% [markdown]
# # Named entities extraction

# %% [markdown]
# #### After the exploratory analysis, the focus is on identifying and extracting named entities in the text

# %%
import nltk # imports nltk

# %%
nltk.download("punkt") # downloads punkt tokenizer models
nltk.download('averaged_perceptron_tagger') # downloads the algorithm for predicting the part of speech information
nltk.download('maxent_ne_chunker') # downloads the maximum entropy chunker that has been trained on the ACE 2004 corpus https://catalog.ldc.upenn.edu/LDC2005T09
nltk.download('words') #downloads the list of English language words
nltk.download('stopwords') # downloads the list of stopwords
from nltk import word_tokenize, pos_tag, ne_chunk #imports a word tokenizer, part of speech tagger and named entity tagger
# Out:
# [nltk_data] Downloading package punkt to /home/harish/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/harish/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/harish/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/harish/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/harish/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from IPython.display import display
import string
import urllib2
import os
import re
from collections import OrderedDict
import sys
import codecs
codecs.register_error("strict", codecs.ignore_errors)

# %% [markdown]
# #### Function for extracting named entities

# %%
def extract_entity_names(t, entity_type): # this function has been defined here: https://gist.github.com/onyxfish/322906
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == entity_type:
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child, entity_type))

    return entity_names

# %% [markdown]
# #### Function for converting a list to a dictionary structure

# %%
def list_to_dict(li):  
     dct = {}  
     for item in li:  
         if dct.has_key(item):  
             dct[item] = dct[item] + 1  
         else:  
             dct[item] = 1  
     return dct

# %% [markdown]
# #### File opening and reading

# %%
url = "https://www.gutenberg.org/files/140/140-0.txt" #assigns a link to a variable
data = urllib2.urlopen(url.encode('utf-8')).read() #opens up the link/file
data = data.replace("\r\n", " ")
data = re.sub('^(.*?)START OF THIS PROJECT GUTENBERG EBOOK', '', data) #removes Project Gutenberg metadata
data = re.sub('End of the Project Gutenberg(.*?)$', '', data)#removes Project Gutenberg metadata
data = unicode(data, errors="ignore") #ignores encoding errors
data[:10000]
#Alternative texts to use
#https://www.gutenberg.org/files/140/140-0.txt The Jungle by Upton Sinclair
# https://www.gutenberg.org/files/1342/1342-0.txt Pride and Prejudice by Jane Austen
#https://www.gutenberg.org/files/543/543-0.txt The Main Street by Sinclair Lewis
# Out:
# u' THE JUNGLE ***     Produced by David Meltzer, Christy Phillips, Scott Coulter, Leroy Smith and David Widger       THE JUNGLE  by Upton Sinclair   (1906)      Chapter 1   It was four oclock when the ceremony was over and the carriages began to arrive. There had been a crowd following all the way, owing to the exuberance of Marija Berczynskas. The occasion rested heavily upon Marijas broad shoulders--it was her task to see that all things went in due form, and after the best home traditions; and, flying wildly hither and thither, bowling every one out of the way, and scolding and exhorting all day with her tremendous voice, Marija was too eager to see that others conformed to the proprieties to consider them herself. She had left the church last of all, and, desiring to arrive first at the hall, had issued orders to the coachman to drive faster. When that personage had developed a will of his own in the matter, Marija had flung up the window of the carriage, and, leaning out, proceeded to tell him her opinion of him, first in Lithuanian, which he did not understand, and then in Polish, which he did. Having the advantage of her in altitude, the driver had stood his ground and even ventured to attempt to speak; and the result had been a furious altercation, which, continuing all the way down Ashland Avenue, had added a new swarm of urchins to the cortege at each side street for half a mile.  This was unfortunate, for already there was a throng before the door. The music had started up, and half a block away you could hear the dull broom, broom of a cello, with the squeaking of two fiddles which vied with each other in intricate and altitudinous gymnastics. Seeing the throng, Marija abandoned precipitately the debate concerning the ancestors of her coachman, and, springing from the moving carriage, plunged in and proceeded to clear a way to the hall. Once within, she turned and began to push the other way, roaring, meantime, Eik! Eik! Uzdaryk-duris! in tones which made the orchestral uproar sound like fairy music.  Z. Graiczunas, Pasilinksminimams darzas. Vynas. Sznapsas. Wines and Liquors. Union Headquarters--that was the way the signs ran. The reader, who perhaps has never held much converse in the language of far-off Lithuania, will be glad of the explanation that the place was the rear room of a saloon in that part of Chicago known as back of the yards. This information is definite and suited to the matter of fact; but how pitifully inadequate it would have seemed to one who understood that it was also the supreme hour of ecstasy in the life of one of Gods gentlest creatures, the scene of the wedding feast and the joy-transfiguration of little Ona Lukoszaite!  She stood in the doorway, shepherded by Cousin Marija, breathless from pushing through the crowd, and in her happiness painful to look upon. There was a light of wonder in her eyes and her lids trembled, and her otherwise wan little face was flushed. She wore a muslin dress, conspicuously white, and a stiff little veil coming to her shoulders. There were five pink paper roses twisted in the veil, and eleven bright green rose leaves. There were new white cotton gloves upon her hands, and as she stood staring about her she twisted them together feverishly. It was almost too much for her--you could see the pain of too great emotion in her face, and all the tremor of her form. She was so young--not quite sixteen--and small for her age, a mere child; and she had just been married--and married to Jurgis,* (*Pronounced Yoorghis) of all men, to Jurgis Rudkus, he with the white flower in the buttonhole of his new black suit, he with the mighty shoulders and the giant hands.  Ona was blue-eyed and fair, while Jurgis had great black eyes with beetling brows, and thick black hair that curled in waves about his ears--in short, they were one of those incongruous and impossible married couples with which Mother Nature so often wills to confound all prophets, before and after. Jurgis  ...

# %% [markdown]
# #### Sentence tokenization

# %%
sentences = nltk.sent_tokenize(data) #tokenizes the file into sentences
sentences [20:40]
# Out:
# [u'She stood in the doorway, shepherded by Cousin Marija, breathless from pushing through the crowd, and in her happiness painful to look upon.',
#  u'There was a light of wonder in her eyes and her lids trembled, and her otherwise wan little face was flushed.',
#  u'She wore a muslin dress, conspicuously white, and a stiff little veil coming to her shoulders.',
#  u'There were five pink paper roses twisted in the veil, and eleven bright green rose leaves.',
#  u'There were new white cotton gloves upon her hands, and as she stood staring about her she twisted them together feverishly.',
#  u'It was almost too much for her--you could see the pain of too great emotion in her face, and all the tremor of her form.',
#  u'She was so young--not quite sixteen--and small for her age, a mere child; and she had just been married--and married to Jurgis,* (*Pronounced Yoorghis) of all men, to Jurgis Rudkus, he with the white flower in the buttonhole of his new black suit, he with the mighty shoulders and the giant hands.',
#  u'Ona was blue-eyed and fair, while Jurgis had great black eyes with beetling brows, and thick black hair that curled in waves about his ears--in short, they were one of those incongruous and impossible married couples with which Mother Nature so often wills to confound all prophets, before and after.',
#  u'Jurgis could take up a two-hundred-and-fifty-pound quarter of beef and carry it into a car without a stagger, or even a thought; and now he stood in a far corner, frightened as a hunted animal, and obliged to moisten his lips with his tongue each time before he could answer the congratulations of his friends.',
#  u'Gradually there was effected a separation between the spectators and the guests--a separation at least sufficiently complete for working purposes.',
#  u'There was no time during the festivities which ensued when there were not groups of onlookers in the doorways and the corners; and if any one of these onlookers came sufficiently close, or looked sufficiently hungry, a chair was offered him, and he was invited to the feast.',
#  u'It was one of the laws of the veselija that no one goes hungry; and, while a rule made in the forests of Lithuania is hard to apply in the stockyards district of Chicago, with its quarter of a million inhabitants, still they did their best, and the children who ran in from the street, and even the dogs, went out again happier.',
#  u'A charming informality was one of the characteristics of this celebration.',
#  u'The men wore their hats, or, if they wished, they took them off, and their coats with them; they ate when and where they pleased, and moved as often as they pleased.',
#  u'There were to be speeches and singing, but no one had to listen who did not care to; if he wished, meantime, to speak or sing himself, he was perfectly free.',
#  u'The resulting medley of sound distracted no one, save possibly alone the babies, of which there were present a number equal to the total possessed by all the guests invited.',
#  u'There was no other place for the babies to be, and so part of the preparations for the evening consisted of a collection of cribs and carriages in one corner.',
#  u'In these the babies slept, three or four together, or wakened together, as the case might be.',
#  u'Those who were still older, and could reach the tables, marched about munching contentedly at meat bones and bologna sausages.',
#  u'The room is about thirty feet square, with whitewashed walls, bare save for a calendar, a picture of a race horse, and a family tree in a gilded frame.']

# %%
senten = len(sentences)
senten
# Out:
# 6643

# %% [markdown]
# ####  Word tokenization

# %%
words = [nltk.word_tokenize(sent) for sent in sentences] # rather than tokenizing the entire file that has been converted into a string, this function tokenizes each of the sentence -- the sentence boundaries are maintained

# %%
words[20:70] # notice the sentence boundaries
# Out:
# [[u'She',
#   u'stood',
#   u'in',
#   u'the',
#   u'doorway',
#   u',',
#   u'shepherded',
#   u'by',
#   u'Cousin',
#   u'Marija',
#   u',',
#   u'breathless',
#   u'from',
#   u'pushing',
#   u'through',
#   u'the',
#   u'crowd',
#   u',',
#   u'and',
#   u'in',
#   u'her',
#   u'happiness',
#   u'painful',
#   u'to',
#   u'look',
#   u'upon',
#   u'.'],
#  [u'There',
#   u'was',
#   u'a',
#   u'light',
#   u'of',
#   u'wonder',
#   u'in',
#   u'her',
#   u'eyes',
#   u'and',
#   u'her',
#   u'lids',
#   u'trembled',
#   u',',
#   u'and',
#   u'her',
#   u'otherwise',
#   u'wan',
#   u'little',
#   u'face',
#   u'was',
#   u'flushed',
#   u'.'],
#  [u'She',
#   u'wore',
#   u'a',
#   u'muslin',
#   u'dress',
#   u',',
#   u'conspicuously',
#   u'white',
#   u',',
#   u'and',
#   u'a',
#   u'stiff',
#   u'little',
#   u'veil',
#   u'coming',
#   u'to',
#   u'her',
#   u'shoulders',
#   u'.'],
#  [u'There',
#   u'were',
#   u'five',
#   u'pink',
#   u'paper',
#   u'roses',
#   u'twisted',
#   u'in',
#   u'the',
#   u'veil',
#   u',',
#   u'and',
#   u'eleven',
#   u'bright',
#   u'green',
#   u'rose',
#   u'leaves',
#   u'.'],
#  [u'There',
#   u'were',
#   u'new',
#   u'white',
#   u'cotton',
#   u'gloves',
#   u'upon',
#   u'her',
#   u'hands',
#   u',',
#   u'and',
#   u'as',
#   u'she',
#   u'stood',
#   u'staring',
#   u'about',
#   u'her',
#   u'she',
#   u'twisted',
#   u'them',
#   u'together',
#   u'feverishly',
#   u'.'],
#  [u'It',
#   u'was',
#   u'almost',
#   u'too',
#   u'much',
#   u'for',
#   u'her',
#   u'--',
#   u'you',
#   u'could',
#   u'see',
#   u'the',
#   u'pain',
#   u'of',
#   u'too',
#   u'great',
#   u'emotion',
#   u'in',
#   u'her',
#   u'face',
#   u',',
#   u'and',
#   u'all',
#   u'the',
#   u'tremor',
#   u'of',
#   u'her',
#   u'form',
#   u'.'],
#  [u'She',
#   u'was',
#   u'so',
#   u'young',
#   u'--',
#   u'not',
#   u'quite',
#   u'sixteen',
#   u'--',
#   u'and',
#   u'small',
#   u'for',
#   u'her',
#   u'age',
#   u',',
#   u'a',
#   u'mere',
#   u'child',
#   u';',
#   u'and',
#   u'she',
#   u'had',
#   u'just',
#   u'been',
#   u'married',
#   u'--',
#   u'and',
#   u'married',
#   u'to',
#   u'Jurgis',
#   u',',
#   u'*',
#   u'(',
#   u'*Pronounced',
#   u'Yoorghis',
#   u')',
#   u'of',
#   u'all',
#   u'men',
#   u',',
#   u'to',
#   u'Jurgis',
#   u'Rudkus',
#   u',',
#   u'he',
#   u'with',
#   u'the',
#   u'white',
#   u'flower',
#   u'in',
#   u'the',
#   u'buttonhole',
#   u'of',
#   u'his',
#   u'new',
#   u'black',
#   u'suit',
#   u',',
#   u'he',
#   u'with',
#   u'the',
#   u'mighty',
#   u'shoulders',
#   u'and',
#   u'the',
#   u'giant',
#   u'hands',
#   u'.'],
#  [u'Ona',
#   u'was',
#   u'blue-eyed',
#   u'and',
#   u'fair',
#   u',',
#   u'while',
#   u'Jurgis',
#   u'had',
#   u'great',
#   u'black',
#   u'eyes',
#   u'with',
#   u'beetling',
#   u'brows',
#   u',',
#   u'and',
#   u'thick',
#   u'black',
#   u'hair',
#   u'that',
#   u'curled',
#   u'in',
#   u'waves',
#   u'about',
#   u'his',
#   u'ears',
#   u'--',
#   u'in',
#   u'short',
#   u',',
#   u'they',
#   u'were',
#   u'one',
#   u'of',
#   u'those',
#   u'incongruous',
#   u'and',
#   u'impossible',
#   u'married',
#   u'couples',
#   u'with',
#   u'which',
#   u'Mother',
#   u'Nature',
#   u'so',
#   u'often',
#   u'wills',
#   u'to',
#   u'confound',
#   u'all',
#   u'prophets',
#   u',',
#   u'before',
#   u'and',
#   u'after',
#   u'.'],
#  [u'Jurgis',
#   u'could',
#   u'take',
#   u'up',
#   u'a',
#   u'two-hundred-and-fifty-pound',
#   u'quarter',
#   u'of',
#   u'beef',
#   u'and',
#   u'carry',
#   u'it',
#   u'into',
#   u'a',
#   u'car',
#   u'without',
#   u'a',
#   u'stagger',
#   u',',
#   u'or',
#   u'even',
#   u'a',
#   u'thought',
#   u';',
#   u'and',
#   u'now',
#   u'he',
#   u'stood',
#   u'in',
#   u'a',
#   u'far',
#   u'corner',
#   u',',
#   u'frightened',
#   u'as',
#   u'a',
#   u'hunted',
#   u'animal',
#   u',',
#   u'and',
#   u'obliged',
#   u'to',
#   u'moisten',
#   u'his',
#   u'lips',
#   u'with',
#   u'his',
#   u'tongue',
#   u'each',
#   u'time',
#   u'before',
#   u'he',
#   u'could',
#   u'answer',
#   u'the',
#   u'congratulations',
#   u'of',
#   u'his',
#   u'friends',
#   u'.'],
#  [u'Gradually',
#   u'there',
#   u'was',
#   u'effected',
#   u'a',
#   u'separation',
#   u'between',
#   u'the',
#   u'spectators',
#   u'and',
#   u'the',
#   u'guests',
#   u'--',
#   u'a',
#   u'separation',
#   u'at',
#   u'least',
#   u'sufficiently',
#   u'complete',
#   u'for',
#   u'working',
#   u'purposes',
#   u'.'],
#  [u'There',
#   u'was',
#   u'no',
#   u'time',
#   u'during',
#   u'the',
#   u'festivities',
#   u'which',
#   u'ensued',
#   u'when',
#   u'there',
#   u'were',
#   u'not',
#   u'groups',
#   u'of',
#   u'onlookers',
#   u'in',
#   u'the',
#   u'doorways',
#   u'and',
#   u'the',
#   u'corners',
#   u';',
#   u'and',
#   u'if',
#   u'any',
#   u'one',
#   u'of',
#   u'these',
#   u'onlookers',
#   u'came',
#   u'sufficiently',
#   u'close',
#   u',',
#   u'or',
#   u'looked',
#   u'sufficiently',
#   u'hungry',
#   u',',
#   u'a',
#   u'chair',
#   u'was',
#   u'offered',
#   u'him',
#   u',',
#   u'and',
#   u'he',
#   u'was',
#   u'invited',
#   u'to',
#   u'the',
#   u'feast',
#   u'.'],
#  [u'It',
#   u'was',
#   u'one',
#   u'of',
#   u'the',
#   u'laws',
#   u'of',
#   u'the',
#   u'veselija',
#   u'that',
#   u'no',
#   u'one',
#   u'goes',
#   u'hungry',
#   u';',
#   u'and',
#   u',',
#   u'while',
#   u'a',
#   u'rule',
#   u'made',
#   u'in',
#   u'the',
#   u'forests',
#   u'of',
#   u'Lithuania',
#   u'is',
#   u'hard',
#   u'to',
#   u'apply',
#   u'in',
#   u'the',
#   u'stockyards',
#   u'district',
#   u'of',
#   u'Chicago',
#   u',',
#   u'with',
#   u'its',
#   u'quarter',
#   u'of',
#   u'a',
#   u'million',
#   u'inhabitants',
#   u',',
#   u'still',
#   u'they',
#   u'did',
#   u'their',
#   u'best',
#   u',',
#   u'and',
#   u'the',
#   u'children',
#   u'who',
#   u'ran',
#   u'in',
#   u'from',
#   u'the',
#   u'street',
#   u',',
#   u'and',
#   u'even',
#   u'the',
#   u'dogs',
#   u',',
#   u'went',
#   u'out',
#   u'again',
#   u'happier',
#   u'.'],
#  [u'A',
#   u'charming',
#   u'informality',
#   u'was',
#   u'one',
#   u'of',
#   u'the',
#   u'characteristics',
#   u'of',
#   u'this',
#   u'celebration',
#   u'.'],
#  [u'The',
#   u'men',
#   u'wore',
#   u'their',
#   u'hats',
#   u',',
#   u'or',
#   u',',
#   u'if',
#   u'they',
#   u'wished',
#   u',',
#   u'they',
#   u'took',
#   u'them',
#   u'off',
#   u',',
#   u'and',
#   u'their',
#   u'coats',
#   u'with',
#   u'them',
#   u';',
#   u'they',
#   u'ate',
#   u'when',
#   u'and',
#   u'where',
#   u'they',
#   u'pleased',
#   u',',
#   u'and',
#   u'moved',
#   u'as',
#   u'often',
#   u'as',
#   u'they',
#   u'pleased',
#   u'.'],
#  [u'There',
#   u'were',
#   u'to',
#   u'be',
#   u'speeches',
#   u'and',
#   u'singing',
#   u',',
#   u'but',
#   u'no',
#   u'one',
#   u'had',
#   u'to',
#   u'listen',
#   u'who',
#   u'did',
#   u'not',
#   u'care',
#   u'to',
#   u';',
#   u'if',
#   u'he',
#   u'wished',
#   u',',
#   u'meantime',
#   u',',
#   u'to',
#   u'speak',
#   u'or',
#   u'sing',
#   u'himself',
#   u',',
#   u'he',
#   u'was',
#   u'perfectly',
#   u'free',
#   u'.'],
#  [u'The',
#   u'resulting',
#   u'medley',
#   u'of',
#   u'sound',
#   u'distracted',
#   u'no',
#   u'one',
#   u',',
#   u'save',
#   u'possibly',
#   u'alone',
#   u'the',
#   u'babies',
#   u',',
#   u'of',
#   u'which',
#   u'there',
#   u'were',
#   u'present',
#   u'a',
#   u'number',
#   u'equal',
#   u'to',
#   u'the',
#   u'total',
#   u'possessed',
#   u'by',
#   u'all',
#   u'the',
#   u'guests',
#   u'invited',
#   u'.'],
#  [u'There',
#   u'was',
#   u'no',
#   u'other',
#   u'place',
#   u'for',
#   u'the',
#   u'babies',
#   u'to',
#   u'be',
#   u',',
#   u'and',
#   u'so',
#   u'part',
#   u'of',
#   u'the',
#   u'preparations',
#   u'for',
#   u'the',
#   u'evening',
#   u'consisted',
#   u'of',
#   u'a',
#   u'collection',
#   u'of',
#   u'cribs',
#   u'and',
#   u'carriages',
#   u'in',
#   u'one',
#   u'corner',
#   u'.'],
#  [u'In',
#   u'these',
#   u'the',
#   u'babies',
#   u'slept',
#   u',',
#   u'three',
#   u'or',
#   u'four',
#   u'together',
#   u',',
#   u'or',
#   u'wakened',
#   u'together',
#   u',',
#   u'as',
#   u'the',
#   u'case',
#   u'might',
#   u'be',
#   u'.'],
#  [u'Those',
#   u'who',
#   u'were',
#   u'still',
#   u'older',
#   u',',
#   u'and',
#   u'could',
#   u'reach',
#   u'the',
#   u'tables',
#   u',',
#   u'marched',
#   u'about',
#   u'munching',
#   u'contentedly',
#   u'at',
#   u'meat',
#   u'bones',
#   u'and',
#   u'bologna',
#   u'sausages',
#   u'.'],
#  [u'The',
#   u'room',
#   u'is',
#   u'about',
#   u'thirty',
#   u'feet',
#   u'square',
#   u',',
#   u'with',
#   u'whitewashed',
#   u'walls',
#   u',',
#   u'bare',
#   u'save',
#   u'for',
#   u'a',
#   u'calendar',
#   u',',
#   u'a',
#   u'picture',
#   u'of',
#   u'a',
#   u'race',
#   u'horse',
#   u',',
#   u'and',
#   u'a',
#   u'family',
#   u'tree',
#   u'in',
#   u'a',
#   u'gilded',
#   u'frame',
#   u'.'],
#  [u'To',
#   u'the',
#   u'right',
#   u'there',
#   u'is',
#   u'a',
#   u'door',
#   u'from',
#   u'the',
#   u'saloon',
#   u',',
#   u'with',
#   u'a',
#   u'few',
#   u'loafers',
#   u'in',
#   u'the',
#   u'doorway',
#   u',',
#   u'and',
#   u'in',
#   u'the',
#   u'corner',
#   u'beyond',
#   u'it',
#   u'a',
#   u'bar',
#   u',',
#   u'with',
#   u'a',
#   u'presiding',
#   u'genius',
#   u'clad',
#   u'in',
#   u'soiled',
#   u'white',
#   u',',
#   u'with',
#   u'waxed',
#   u'black',
#   u'mustaches',
#   u'and',
#   u'a',
#   u'carefully',
#   u'oiled',
#   u'curl',
#   u'plastered',
#   u'against',
#   u'one',
#   u'side',
#   u'of',
#   u'his',
#   u'forehead',
#   u'.'],
#  [u'In',
#   u'the',
#   u'opposite',
#   u'corner',
#   u'are',
#   u'two',
#   u'tables',
#   u',',
#   u'filling',
#   u'a',
#   u'third',
#   u'of',
#   u'the',
#   u'room',
#   u'and',
#   u'laden',
#   u'with',
#   u'dishes',
#   u'and',
#   u'cold',
#   u'viands',
#   u',',
#   u'which',
#   u'a',
#   u'few',
#   u'of',
#   u'the',
#   u'hungrier',
#   u'guests',
#   u'are',
#   u'already',
#   u'munching',
#   u'.'],
#  [u'At',
#   u'the',
#   u'head',
#   u',',
#   u'where',
#   u'sits',
#   u'the',
#   u'bride',
#   u',',
#   u'is',
#   u'a',
#   u'snow-white',
#   u'cake',
#   u',',
#   u'with',
#   u'an',
#   u'Eiffel',
#   u'tower',
#   u'of',
#   u'constructed',
#   u'decoration',
#   u',',
#   u'with',
#   u'sugar',
#   u'roses',
#   u'and',
#   u'two',
#   u'angels',
#   u'upon',
#   u'it',
#   u',',
#   u'and',
#   u'a',
#   u'generous',
#   u'sprinkling',
#   u'of',
#   u'pink',
#   u'and',
#   u'green',
#   u'and',
#   u'yellow',
#   u'candies',
#   u'.'],
#  [u'Beyond',
#   u'opens',
#   u'a',
#   u'door',
#   u'into',
#   u'the',
#   u'kitchen',
#   u',',
#   u'where',
#   u'there',
#   u'is',
#   u'a',
#   u'glimpse',
#   u'to',
#   u'be',
#   u'had',
#   u'of',
#   u'a',
#   u'range',
#   u'with',
#   u'much',
#   u'steam',
#   u'ascending',
#   u'from',
#   u'it',
#   u',',
#   u'and',
#   u'many',
#   u'women',
#   u',',
#   u'old',
#   u'and',
#   u'young',
#   u',',
#   u'rushing',
#   u'hither',
#   u'and',
#   u'thither',
#   u'.'],
#  [u'In',
#   u'the',
#   u'corner',
#   u'to',
#   u'the',
#   u'left',
#   u'are',
#   u'the',
#   u'three',
#   u'musicians',
#   u',',
#   u'upon',
#   u'a',
#   u'little',
#   u'platform',
#   u',',
#   u'toiling',
#   u'heroically',
#   u'to',
#   u'make',
#   u'some',
#   u'impression',
#   u'upon',
#   u'the',
#   u'hubbub',
#   u';',
#   u'also',
#   u'the',
#   u'babies',
#   u',',
#   u'similarly',
#   u'occupied',
#   u',',
#   u'and',
#   u'an',
#   u'open',
#   u'window',
#   u'whence',
#   u'the',
#   u'populace',
#   u'imbibes',
#   u'the',
#   u'sights',
#   u'and',
#   u'sounds',
#   u'and',
#   u'odors',
#   u'.'],
#  [u'Suddenly',
#   u'some',
#   u'of',
#   u'the',
#   u'steam',
#   u'begins',
#   u'to',
#   u'advance',
#   u',',
#   u'and',
#   u',',
#   u'peering',
#   u'through',
#   u'it',
#   u',',
#   u'you',
#   u'discern',
#   u'Aunt',
#   u'Elizabeth',
#   u',',
#   u'Onas',
#   u'stepmother',
#   u'--',
#   u'Teta',
#   u'Elzbieta',
#   u',',
#   u'as',
#   u'they',
#   u'call',
#   u'her',
#   u'--',
#   u'bearing',
#   u'aloft',
#   u'a',
#   u'great',
#   u'platter',
#   u'of',
#   u'stewed',
#   u'duck',
#   u'.'],
#  [u'Behind',
#   u'her',
#   u'is',
#   u'Kotrina',
#   u',',
#   u'making',
#   u'her',
#   u'way',
#   u'cautiously',
#   u',',
#   u'staggering',
#   u'beneath',
#   u'a',
#   u'similar',
#   u'burden',
#   u';',
#   u'and',
#   u'half',
#   u'a',
#   u'minute',
#   u'later',
#   u'there',
#   u'appears',
#   u'old',
#   u'Grandmother',
#   u'Majauszkiene',
#   u',',
#   u'with',
#   u'a',
#   u'big',
#   u'yellow',
#   u'bowl',
#   u'of',
#   u'smoking',
#   u'potatoes',
#   u',',
#   u'nearly',
#   u'as',
#   u'big',
#   u'as',
#   u'herself',
#   u'.'],
#  [u'So',
#   u',',
#   u'bit',
#   u'by',
#   u'bit',
#   u',',
#   u'the',
#   u'feast',
#   u'takes',
#   u'form',
#   u'--',
#   u'there',
#   u'is',
#   u'a',
#   u'ham',
#   u'and',
#   u'a',
#   u'dish',
#   u'of',
#   u'sauerkraut',
#   u',',
#   u'boiled',
#   u'rice',
#   u',',
#   u'macaroni',
#   u',',
#   u'bologna',
#   u'sausages',
#   u',',
#   u'great',
#   u'piles',
#   u'of',
#   u'penny',
#   u'buns',
#   u',',
#   u'bowls',
#   u'of',
#   u'milk',
#   u',',
#   u'and',
#   u'foaming',
#   u'pitchers',
#   u'of',
#   u'beer',
#   u'.'],
#  [u'There',
#   u'is',
#   u'also',
#   u',',
#   u'not',
#   u'six',
#   u'feet',
#   u'from',
#   u'your',
#   u'back',
#   u',',
#   u'the',
#   u'bar',
#   u',',
#   u'where',
#   u'you',
#   u'may',
#   u'order',
#   u'all',
#   u'you',
#   u'please',
#   u'and',
#   u'do',
#   u'not',
#   u'have',
#   u'to',
#   u'pay',
#   u'for',
#   u'it',
#   u'.'],
#  [u'Eiksz', u'!'],
#  [u'Graicziau', u'!'],
#  [u'screams',
#   u'Marija',
#   u'Berczynskas',
#   u',',
#   u'and',
#   u'falls',
#   u'to',
#   u'work',
#   u'herself',
#   u'--',
#   u'for',
#   u'there',
#   u'is',
#   u'more',
#   u'upon',
#   u'the',
#   u'stove',
#   u'inside',
#   u'that',
#   u'will',
#   u'be',
#   u'spoiled',
#   u'if',
#   u'it',
#   u'be',
#   u'not',
#   u'eaten',
#   u'.'],
#  [u'So',
#   u',',
#   u'with',
#   u'laughter',
#   u'and',
#   u'shouts',
#   u'and',
#   u'endless',
#   u'badinage',
#   u'and',
#   u'merriment',
#   u',',
#   u'the',
#   u'guests',
#   u'take',
#   u'their',
#   u'places',
#   u'.'],
#  [u'The',
#   u'young',
#   u'men',
#   u',',
#   u'who',
#   u'for',
#   u'the',
#   u'most',
#   u'part',
#   u'have',
#   u'been',
#   u'huddled',
#   u'near',
#   u'the',
#   u'door',
#   u',',
#   u'summon',
#   u'their',
#   u'resolution',
#   u'and',
#   u'advance',
#   u';',
#   u'and',
#   u'the',
#   u'shrinking',
#   u'Jurgis',
#   u'is',
#   u'poked',
#   u'and',
#   u'scolded',
#   u'by',
#   u'the',
#   u'old',
#   u'folks',
#   u'until',
#   u'he',
#   u'consents',
#   u'to',
#   u'seat',
#   u'himself',
#   u'at',
#   u'the',
#   u'right',
#   u'hand',
#   u'of',
#   u'the',
#   u'bride',
#   u'.'],
#  [u'The',
#   u'two',
#   u'bridesmaids',
#   u',',
#   u'whose',
#   u'insignia',
#   u'of',
#   u'office',
#   u'are',
#   u'paper',
#   u'wreaths',
#   u',',
#   u'come',
#   u'next',
#   u',',
#   u'and',
#   u'after',
#   u'them',
#   u'the',
#   u'rest',
#   u'of',
#   u'the',
#   u'guests',
#   u',',
#   u'old',
#   u'and',
#   u'young',
#   u',',
#   u'boys',
#   u'and',
#   u'girls',
#   u'.'],
#  [u'The',
#   u'spirit',
#   u'of',
#   u'the',
#   u'occasion',
#   u'takes',
#   u'hold',
#   u'of',
#   u'the',
#   u'stately',
#   u'bartender',
#   u',',
#   u'who',
#   u'condescends',
#   u'to',
#   u'a',
#   u'plate',
#   u'of',
#   u'stewed',
#   u'duck',
#   u';',
#   u'even',
#   u'the',
#   u'fat',
#   u'policeman',
#   u'--',
#   u'whose',
#   u'duty',
#   u'it',
#   u'will',
#   u'be',
#   u',',
#   u'later',
#   u'in',
#   u'the',
#   u'evening',
#   u',',
#   u'to',
#   u'break',
#   u'up',
#   u'the',
#   u'fights',
#   u'--',
#   u'draws',
#   u'up',
#   u'a',
#   u'chair',
#   u'to',
#   u'the',
#   u'foot',
#   u'of',
#   u'the',
#   u'table',
#   u'.'],
#  [u'And',
#   u'the',
#   u'children',
#   u'shout',
#   u'and',
#   u'the',
#   u'babies',
#   u'yell',
#   u',',
#   u'and',
#   u'every',
#   u'one',
#   u'laughs',
#   u'and',
#   u'sings',
#   u'and',
#   u'chatters',
#   u'--',
#   u'while',
#   u'above',
#   u'all',
#   u'the',
#   u'deafening',
#   u'clamor',
#   u'Cousin',
#   u'Marija',
#   u'shouts',
#   u'orders',
#   u'to',
#   u'the',
#   u'musicians',
#   u'.'],
#  [u'The',
#   u'musicians',
#   u'--',
#   u'how',
#   u'shall',
#   u'one',
#   u'begin',
#   u'to',
#   u'describe',
#   u'them',
#   u'?'],
#  [u'All',
#   u'this',
#   u'time',
#   u'they',
#   u'have',
#   u'been',
#   u'there',
#   u',',
#   u'playing',
#   u'in',
#   u'a',
#   u'mad',
#   u'frenzy',
#   u'--',
#   u'all',
#   u'of',
#   u'this',
#   u'scene',
#   u'must',
#   u'be',
#   u'read',
#   u',',
#   u'or',
#   u'said',
#   u',',
#   u'or',
#   u'sung',
#   u',',
#   u'to',
#   u'music',
#   u'.'],
#  [u'It',
#   u'is',
#   u'the',
#   u'music',
#   u'which',
#   u'makes',
#   u'it',
#   u'what',
#   u'it',
#   u'is',
#   u';',
#   u'it',
#   u'is',
#   u'the',
#   u'music',
#   u'which',
#   u'changes',
#   u'the',
#   u'place',
#   u'from',
#   u'the',
#   u'rear',
#   u'room',
#   u'of',
#   u'a',
#   u'saloon',
#   u'in',
#   u'back',
#   u'of',
#   u'the',
#   u'yards',
#   u'to',
#   u'a',
#   u'fairy',
#   u'place',
#   u',',
#   u'a',
#   u'wonderland',
#   u',',
#   u'a',
#   u'little',
#   u'corner',
#   u'of',
#   u'the',
#   u'high',
#   u'mansions',
#   u'of',
#   u'the',
#   u'sky',
#   u'.'],
#  [u'The',
#   u'little',
#   u'person',
#   u'who',
#   u'leads',
#   u'this',
#   u'trio',
#   u'is',
#   u'an',
#   u'inspired',
#   u'man',
#   u'.'],
#  [u'His',
#   u'fiddle',
#   u'is',
#   u'out',
#   u'of',
#   u'tune',
#   u',',
#   u'and',
#   u'there',
#   u'is',
#   u'no',
#   u'rosin',
#   u'on',
#   u'his',
#   u'bow',
#   u',',
#   u'but',
#   u'still',
#   u'he',
#   u'is',
#   u'an',
#   u'inspired',
#   u'man',
#   u'--',
#   u'the',
#   u'hands',
#   u'of',
#   u'the',
#   u'muses',
#   u'have',
#   u'been',
#   u'laid',
#   u'upon',
#   u'him',
#   u'.'],
#  [u'He',
#   u'plays',
#   u'like',
#   u'one',
#   u'possessed',
#   u'by',
#   u'a',
#   u'demon',
#   u',',
#   u'by',
#   u'a',
#   u'whole',
#   u'horde',
#   u'of',
#   u'demons',
#   u'.'],
#  [u'You',
#   u'can',
#   u'feel',
#   u'them',
#   u'in',
#   u'the',
#   u'air',
#   u'round',
#   u'about',
#   u'him',
#   u',',
#   u'capering',
#   u'frenetically',
#   u';',
#   u'with',
#   u'their',
#   u'invisible',
#   u'feet',
#   u'they',
#   u'set',
#   u'the',
#   u'pace',
#   u',',
#   u'and',
#   u'the',
#   u'hair',
#   u'of',
#   u'the',
#   u'leader',
#   u'of',
#   u'the',
#   u'orchestra',
#   u'rises',
#   u'on',
#   u'end',
#   u',',
#   u'and',
#   u'his',
#   u'eyeballs',
#   u'start',
#   u'from',
#   u'their',
#   u'sockets',
#   u',',
#   u'as',
#   u'he',
#   u'toils',
#   u'to',
#   u'keep',
#   u'up',
#   u'with',
#   u'them',
#   u'.'],
#  [u'Tamoszius',
#   u'Kuszleika',
#   u'is',
#   u'his',
#   u'name',
#   u',',
#   u'and',
#   u'he',
#   u'has',
#   u'taught',
#   u'himself',
#   u'to',
#   u'play',
#   u'the',
#   u'violin',
#   u'by',
#   u'practicing',
#   u'all',
#   u'night',
#   u',',
#   u'after',
#   u'working',
#   u'all',
#   u'day',
#   u'on',
#   u'the',
#   u'killing',
#   u'beds',
#   u'.'],
#  [u'He',
#   u'is',
#   u'in',
#   u'his',
#   u'shirt',
#   u'sleeves',
#   u',',
#   u'with',
#   u'a',
#   u'vest',
#   u'figured',
#   u'with',
#   u'faded',
#   u'gold',
#   u'horseshoes',
#   u',',
#   u'and',
#   u'a',
#   u'pink-striped',
#   u'shirt',
#   u',',
#   u'suggestive',
#   u'of',
#   u'peppermint',
#   u'candy',
#   u'.'],
#  [u'A',
#   u'pair',
#   u'of',
#   u'military',
#   u'trousers',
#   u',',
#   u'light',
#   u'blue',
#   u'with',
#   u'a',
#   u'yellow',
#   u'stripe',
#   u',',
#   u'serve',
#   u'to',
#   u'give',
#   u'that',
#   u'suggestion',
#   u'of',
#   u'authority',
#   u'proper',
#   u'to',
#   u'the',
#   u'leader',
#   u'of',
#   u'a',
#   u'band',
#   u'.'],
#  [u'He',
#   u'is',
#   u'only',
#   u'about',
#   u'five',
#   u'feet',
#   u'high',
#   u',',
#   u'but',
#   u'even',
#   u'so',
#   u'these',
#   u'trousers',
#   u'are',
#   u'about',
#   u'eight',
#   u'inches',
#   u'short',
#   u'of',
#   u'the',
#   u'ground',
#   u'.'],
#  [u'You',
#   u'wonder',
#   u'where',
#   u'he',
#   u'can',
#   u'have',
#   u'gotten',
#   u'them',
#   u'or',
#   u'rather',
#   u'you',
#   u'would',
#   u'wonder',
#   u',',
#   u'if',
#   u'the',
#   u'excitement',
#   u'of',
#   u'being',
#   u'in',
#   u'his',
#   u'presence',
#   u'left',
#   u'you',
#   u'time',
#   u'to',
#   u'think',
#   u'of',
#   u'such',
#   u'things',
#   u'.'],
#  [u'For', u'he', u'is', u'an', u'inspired', u'man', u'.']]

# %% [markdown]
# #### Extracting part of speech information from the text

# %%
tagged_sentences = [nltk.pos_tag(word) for word in words] # for each sentence in words (sentence boundaries are maintained in words) assign the most probable part of speech for each word in the sentence

# %%
import os
os.getcwd()
# Out:
# '/home/harish/PycharmProjects/Events/DHCS/DHCS-workshop-notebooks/DHCS-workshop-notebooks'

# %%
#%store tagged_sentences >> pos_pride_and_prejudice.txt
# %store tagged_sentences >> pos_the_main_street.txt
#%store tagged_sentences >> pos_the_jungle.txt
# Out:
# Writing 'tagged_sentences' (list) to file 'pos_the_main_street.txt'.

# %%
tagged_sentences[100:150] # notice the sentence boundaries
# Out:
# [[(u'Then', 'RB'),
#   (u'the', 'DT'),
#   (u'tears', 'NNS'),
#   (u'begin', 'VBP'),
#   (u'to', 'TO'),
#   (u'come', 'VB'),
#   (u'into', 'IN'),
#   (u'her', 'PRP$'),
#   (u'eyes', 'NNS'),
#   (u';', ':'),
#   (u'and', 'CC'),
#   (u'as', 'IN'),
#   (u'she', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'ashamed', 'VBN'),
#   (u'to', 'TO'),
#   (u'wipe', 'VB'),
#   (u'them', 'PRP'),
#   (u'away', 'RB'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'ashamed', 'VBD'),
#   (u'to', 'TO'),
#   (u'let', 'VB'),
#   (u'them', 'PRP'),
#   (u'run', 'VB'),
#   (u'down', 'RP'),
#   (u'her', 'PRP$'),
#   (u'cheeks', 'NN'),
#   (u',', ','),
#   (u'she', 'PRP'),
#   (u'turns', 'VBZ'),
#   (u'and', 'CC'),
#   (u'shakes', 'VBZ'),
#   (u'her', 'PRP$'),
#   (u'head', 'NN'),
#   (u'a', 'DT'),
#   (u'little', 'JJ'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'then', 'RB'),
#   (u'flushes', 'NNS'),
#   (u'red', 'VBD'),
#   (u'when', 'WRB'),
#   (u'she', 'PRP'),
#   (u'sees', 'VBZ'),
#   (u'that', 'IN'),
#   (u'Jurgis', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'watching', 'VBG'),
#   (u'her', 'PRP'),
#   (u'.', '.')],
#  [(u'When', 'WRB'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'end', 'NN'),
#   (u'Tamoszius', 'NNP'),
#   (u'Kuszleika', 'NNP'),
#   (u'has', 'VBZ'),
#   (u'reached', 'VBN'),
#   (u'her', 'PRP'),
#   (u'side', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'is', 'VBZ'),
#   (u'waving', 'VBG'),
#   (u'his', 'PRP$'),
#   (u'magic', 'NN'),
#   (u'wand', 'NN'),
#   (u'above', 'IN'),
#   (u'her', 'PRP'),
#   (u',', ','),
#   (u'Onas', 'NNP'),
#   (u'cheeks', 'NN'),
#   (u'are', 'VBP'),
#   (u'scarlet', 'VBN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'she', 'PRP'),
#   (u'looks', 'VBZ'),
#   (u'as', 'IN'),
#   (u'if', 'IN'),
#   (u'she', 'PRP'),
#   (u'would', 'MD'),
#   (u'have', 'VB'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'up', 'RP'),
#   (u'and', 'CC'),
#   (u'run', 'VB'),
#   (u'away', 'RB'),
#   (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'this', 'DT'),
#   (u'crisis', 'NN'),
#   (u',', ','),
#   (u'however', 'RB'),
#   (u',', ','),
#   (u'she', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'saved', 'VBN'),
#   (u'by', 'IN'),
#   (u'Marija', 'NNP'),
#   (u'Berczynskas', 'NNP'),
#   (u',', ','),
#   (u'whom', 'WP'),
#   (u'the', 'DT'),
#   (u'muses', 'NNS'),
#   (u'suddenly', 'RB'),
#   (u'visit', 'VBP'),
#   (u'.', '.')],
#  [(u'Marija', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'fond', 'NN'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'song', 'NN'),
#   (u',', ','),
#   (u'a', 'DT'),
#   (u'song', 'NN'),
#   (u'of', 'IN'),
#   (u'lovers', 'NNS'),
#   (u'parting', 'VBG'),
#   (u';', ':'),
#   (u'she', 'PRP'),
#   (u'wishes', 'VBZ'),
#   (u'to', 'TO'),
#   (u'hear', 'VB'),
#   (u'it', 'PRP'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u',', ','),
#   (u'as', 'IN'),
#   (u'the', 'DT'),
#   (u'musicians', 'NNS'),
#   (u'do', 'VBP'),
#   (u'not', 'RB'),
#   (u'know', 'VB'),
#   (u'it', 'PRP'),
#   (u',', ','),
#   (u'she', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'risen', 'VBN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'is', 'VBZ'),
#   (u'proceeding', 'VBG'),
#   (u'to', 'TO'),
#   (u'teach', 'VB'),
#   (u'them', 'PRP'),
#   (u'.', '.')],
#  [(u'Marija', 'NNP'),
#   (u'is', 'VBZ'),
#   (u'short', 'JJ'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'powerful', 'JJ'),
#   (u'in', 'IN'),
#   (u'build', 'NN'),
#   (u'.', '.')],
#  [(u'She', 'PRP'),
#   (u'works', 'VBZ'),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'canning', 'NN'),
#   (u'factory', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'all', 'DT'),
#   (u'day', 'NN'),
#   (u'long', 'RB'),
#   (u'she', 'PRP'),
#   (u'handles', 'VBZ'),
#   (u'cans', 'NNS'),
#   (u'of', 'IN'),
#   (u'beef', 'NN'),
#   (u'that', 'WDT'),
#   (u'weigh', 'VBP'),
#   (u'fourteen', 'JJ'),
#   (u'pounds', 'NNS'),
#   (u'.', '.')],
#  [(u'She', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'a', 'DT'),
#   (u'broad', 'JJ'),
#   (u'Slavic', 'NNP'),
#   (u'face', 'NN'),
#   (u',', ','),
#   (u'with', 'IN'),
#   (u'prominent', 'JJ'),
#   (u'red', 'JJ'),
#   (u'cheeks', 'NN'),
#   (u'.', '.')],
#  [(u'When', 'WRB'),
#   (u'she', 'PRP'),
#   (u'opens', 'VBZ'),
#   (u'her', 'PRP'),
#   (u'mouth', 'NN'),
#   (u',', ','),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'tragical', 'JJ'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'you', 'PRP'),
#   (u'can', 'MD'),
#   (u'not', 'RB'),
#   (u'help', 'VB'),
#   (u'thinking', 'NN'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'horse', 'NN'),
#   (u'.', '.')],
#  [(u'She', 'PRP'),
#   (u'wears', 'VBZ'),
#   (u'a', 'DT'),
#   (u'blue', 'JJ'),
#   (u'flannel', 'NN'),
#   (u'shirt-waist', 'NN'),
#   (u',', ','),
#   (u'which', 'WDT'),
#   (u'is', 'VBZ'),
#   (u'now', 'RB'),
#   (u'rolled', 'VBN'),
#   (u'up', 'RP'),
#   (u'at', 'IN'),
#   (u'the', 'DT'),
#   (u'sleeves', 'NNS'),
#   (u',', ','),
#   (u'disclosing', 'VBG'),
#   (u'her', 'PRP$'),
#   (u'brawny', 'NN'),
#   (u'arms', 'NNS'),
#   (u';', ':'),
#   (u'she', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'a', 'DT'),
#   (u'carving', 'NN'),
#   (u'fork', 'NN'),
#   (u'in', 'IN'),
#   (u'her', 'PRP$'),
#   (u'hand', 'NN'),
#   (u',', ','),
#   (u'with', 'IN'),
#   (u'which', 'WDT'),
#   (u'she', 'PRP'),
#   (u'pounds', 'VBZ'),
#   (u'on', 'IN'),
#   (u'the', 'DT'),
#   (u'table', 'NN'),
#   (u'to', 'TO'),
#   (u'mark', 'VB'),
#   (u'the', 'DT'),
#   (u'time', 'NN'),
#   (u'.', '.')],
#  [(u'As', 'IN'),
#   (u'she', 'PRP'),
#   (u'roars', 'VBZ'),
#   (u'her', 'PRP'),
#   (u'song', 'NN'),
#   (u',', ','),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'voice', 'NN'),
#   (u'of', 'IN'),
#   (u'which', 'WDT'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'enough', 'JJ'),
#   (u'to', 'TO'),
#   (u'say', 'VB'),
#   (u'that', 'IN'),
#   (u'it', 'PRP'),
#   (u'leaves', 'VBZ'),
#   (u'no', 'DT'),
#   (u'portion', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'room', 'NN'),
#   (u'vacant', 'NN'),
#   (u',', ','),
#   (u'the', 'DT'),
#   (u'three', 'CD'),
#   (u'musicians', 'NNS'),
#   (u'follow', 'VBP'),
#   (u'her', 'PRP'),
#   (u',', ','),
#   (u'laboriously', 'RB'),
#   (u'and', 'CC'),
#   (u'note', 'VB'),
#   (u'by', 'IN'),
#   (u'note', 'NN'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'averaging', 'VBG'),
#   (u'one', 'CD'),
#   (u'note', 'NN'),
#   (u'behind', 'IN'),
#   (u';', ':'),
#   (u'thus', 'RB'),
#   (u'they', 'PRP'),
#   (u'toil', 'VBP'),
#   (u'through', 'IN'),
#   (u'stanza', 'NN'),
#   (u'after', 'IN'),
#   (u'stanza', 'NN'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'lovesick', 'JJ'),
#   (u'swains', 'NNS'),
#   (u'lamentation', 'NN'),
#   (u':', ':'),
#   (u'--', ':'),
#   (u'Sudiev', 'NNP'),
#   (u'kvietkeli', 'NN'),
#   (u',', ','),
#   (u'tu', 'JJ'),
#   (u'brangiausis', 'NN'),
#   (u';', ':'),
#   (u'Sudiev', 'NNP'),
#   (u'ir', 'NN'),
#   (u'laime', 'NN'),
#   (u',', ','),
#   (u'man', 'NN'),
#   (u'biednam', 'NN'),
#   (u',', ','),
#   (u'Matau', 'NNP'),
#   (u'--', ':'),
#   (u'paskyre', 'JJ'),
#   (u'teip', 'JJ'),
#   (u'Aukszcziausis', 'NNP'),
#   (u',', ','),
#   (u'Jog', 'NNP'),
#   (u'vargt', 'NN'),
#   (u'ant', 'NN'),
#   (u'svieto', 'NN'),
#   (u'reik', 'NN'),
#   (u'vienam', 'NN'),
#   (u'!', '.')],
#  [(u'When', 'WRB'),
#   (u'the', 'DT'),
#   (u'song', 'NN'),
#   (u'is', 'VBZ'),
#   (u'over', 'IN'),
#   (u',', ','),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'time', 'NN'),
#   (u'for', 'IN'),
#   (u'the', 'DT'),
#   (u'speech', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'old', 'JJ'),
#   (u'Dede', 'NNP'),
#   (u'Antanas', 'NNP'),
#   (u'rises', 'VBZ'),
#   (u'to', 'TO'),
#   (u'his', 'PRP$'),
#   (u'feet', 'NNS'),
#   (u'.', '.')],
#  [(u'Grandfather', 'NNP'),
#   (u'Anthony', 'NNP'),
#   (u',', ','),
#   (u'Jurgis', 'NNP'),
#   (u'father', 'NN'),
#   (u',', ','),
#   (u'is', 'VBZ'),
#   (u'not', 'RB'),
#   (u'more', 'RBR'),
#   (u'than', 'IN'),
#   (u'sixty', 'CD'),
#   (u'years', 'NNS'),
#   (u'of', 'IN'),
#   (u'age', 'NN'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'you', 'PRP'),
#   (u'would', 'MD'),
#   (u'think', 'VB'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u'was', 'VBD'),
#   (u'eighty', 'RB'),
#   (u'.', '.')],
#  [(u'He', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'been', 'VBN'),
#   (u'only', 'RB'),
#   (u'six', 'CD'),
#   (u'months', 'NNS'),
#   (u'in', 'IN'),
#   (u'America', 'NNP'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'change', 'NN'),
#   (u'has', 'VBZ'),
#   (u'not', 'RB'),
#   (u'done', 'VBN'),
#   (u'him', 'PRP'),
#   (u'good', 'JJ'),
#   (u'.', '.')],
#  [(u'In', 'IN'),
#   (u'his', 'PRP$'),
#   (u'manhood', 'NN'),
#   (u'he', 'PRP'),
#   (u'worked', 'VBD'),
#   (u'in', 'IN'),
#   (u'a', 'DT'),
#   (u'cotton', 'NN'),
#   (u'mill', 'NN'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'then', 'RB'),
#   (u'a', 'DT'),
#   (u'coughing', 'NN'),
#   (u'fell', 'VBD'),
#   (u'upon', 'IN'),
#   (u'him', 'PRP'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'he', 'PRP'),
#   (u'had', 'VBD'),
#   (u'to', 'TO'),
#   (u'leave', 'VB'),
#   (u';', ':'),
#   (u'out', 'RP'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'country', 'NN'),
#   (u'the', 'DT'),
#   (u'trouble', 'NN'),
#   (u'disappeared', 'VBD'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'been', 'VBN'),
#   (u'working', 'VBG'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'pickle', 'NN'),
#   (u'rooms', 'NNS'),
#   (u'at', 'IN'),
#   (u'Durhams', 'NNP'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'breathing', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'cold', 'NN'),
#   (u',', ','),
#   (u'damp', 'VB'),
#   (u'air', 'NN'),
#   (u'all', 'DT'),
#   (u'day', 'NN'),
#   (u'has', 'VBZ'),
#   (u'brought', 'VBN'),
#   (u'it', 'PRP'),
#   (u'back', 'RB'),
#   (u'.', '.')],
#  [(u'Now', 'RB'),
#   (u'as', 'IN'),
#   (u'he', 'PRP'),
#   (u'rises', 'VBZ'),
#   (u'he', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'seized', 'VBN'),
#   (u'with', 'IN'),
#   (u'a', 'DT'),
#   (u'coughing', 'NN'),
#   (u'fit', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'holds', 'VBZ'),
#   (u'himself', 'PRP'),
#   (u'by', 'IN'),
#   (u'his', 'PRP$'),
#   (u'chair', 'NN'),
#   (u'and', 'CC'),
#   (u'turns', 'VBZ'),
#   (u'away', 'RB'),
#   (u'his', 'PRP$'),
#   (u'wan', 'NN'),
#   (u'and', 'CC'),
#   (u'battered', 'VBD'),
#   (u'face', 'NN'),
#   (u'until', 'IN'),
#   (u'it', 'PRP'),
#   (u'passes', 'VBZ'),
#   (u'.', '.')],
#  [(u'Generally', 'RB'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'the', 'DT'),
#   (u'custom', 'NN'),
#   (u'for', 'IN'),
#   (u'the', 'DT'),
#   (u'speech', 'NN'),
#   (u'at', 'IN'),
#   (u'a', 'DT'),
#   (u'veselija', 'NN'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'taken', 'VBN'),
#   (u'out', 'IN'),
#   (u'of', 'IN'),
#   (u'one', 'CD'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'books', 'NNS'),
#   (u'and', 'CC'),
#   (u'learned', 'VBN'),
#   (u'by', 'IN'),
#   (u'heart', 'NN'),
#   (u';', ':'),
#   (u'but', 'CC'),
#   (u'in', 'IN'),
#   (u'his', 'PRP$'),
#   (u'youthful', 'JJ'),
#   (u'days', 'NNS'),
#   (u'Dede', 'NNP'),
#   (u'Antanas', 'NNP'),
#   (u'used', 'VBD'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'scholar', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'really', 'RB'),
#   (u'make', 'VB'),
#   (u'up', 'RP'),
#   (u'all', 'PDT'),
#   (u'the', 'DT'),
#   (u'love', 'NN'),
#   (u'letters', 'NNS'),
#   (u'of', 'IN'),
#   (u'his', 'PRP$'),
#   (u'friends', 'NNS'),
#   (u'.', '.')],
#  [(u'Now', 'RB'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'understood', 'JJ'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'composed', 'VBN'),
#   (u'an', 'DT'),
#   (u'original', 'JJ'),
#   (u'speech', 'NN'),
#   (u'of', 'IN'),
#   (u'congratulation', 'NN'),
#   (u'and', 'CC'),
#   (u'benediction', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'this', 'DT'),
#   (u'is', 'VBZ'),
#   (u'one', 'CD'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'events', 'NNS'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'day', 'NN'),
#   (u'.', '.')],
#  [(u'Even', 'RB'),
#   (u'the', 'DT'),
#   (u'boys', 'NNS'),
#   (u',', ','),
#   (u'who', 'WP'),
#   (u'are', 'VBP'),
#   (u'romping', 'VBG'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'room', 'NN'),
#   (u',', ','),
#   (u'draw', 'NN'),
#   (u'near', 'IN'),
#   (u'and', 'CC'),
#   (u'listen', 'VB'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'some', 'DT'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'women', 'NNS'),
#   (u'sob', 'NN'),
#   (u'and', 'CC'),
#   (u'wipe', 'VB'),
#   (u'their', 'PRP$'),
#   (u'aprons', 'NNS'),
#   (u'in', 'IN'),
#   (u'their', 'PRP$'),
#   (u'eyes', 'NNS'),
#   (u'.', '.')],
#  [(u'It', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'very', 'RB'),
#   (u'solemn', 'JJ'),
#   (u',', ','),
#   (u'for', 'IN'),
#   (u'Antanas', 'NNP'),
#   (u'Rudkus', 'NNP'),
#   (u'has', 'VBZ'),
#   (u'become', 'VBN'),
#   (u'possessed', 'VBN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'idea', 'NN'),
#   (u'that', 'IN'),
#   (u'he', 'PRP'),
#   (u'has', 'VBZ'),
#   (u'not', 'RB'),
#   (u'much', 'RB'),
#   (u'longer', 'RBR'),
#   (u'to', 'TO'),
#   (u'stay', 'VB'),
#   (u'with', 'IN'),
#   (u'his', 'PRP$'),
#   (u'children', 'NNS'),
#   (u'.', '.')],
#  [(u'His', 'PRP$'),
#   (u'speech', 'NN'),
#   (u'leaves', 'VBZ'),
#   (u'them', 'PRP'),
#   (u'all', 'DT'),
#   (u'so', 'RB'),
#   (u'tearful', 'JJ'),
#   (u'that', 'IN'),
#   (u'one', 'CD'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'guests', 'NNS'),
#   (u',', ','),
#   (u'Jokubas', 'NNP'),
#   (u'Szedvilas', 'NNP'),
#   (u',', ','),
#   (u'who', 'WP'),
#   (u'keeps', 'VBZ'),
#   (u'a', 'DT'),
#   (u'delicatessen', 'JJ'),
#   (u'store', 'NN'),
#   (u'on', 'IN'),
#   (u'Halsted', 'NNP'),
#   (u'Street', 'NNP'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'is', 'VBZ'),
#   (u'fat', 'JJ'),
#   (u'and', 'CC'),
#   (u'hearty', 'NN'),
#   (u',', ','),
#   (u'is', 'VBZ'),
#   (u'moved', 'VBN'),
#   (u'to', 'TO'),
#   (u'rise', 'VB'),
#   (u'and', 'CC'),
#   (u'say', 'VB'),
#   (u'that', 'IN'),
#   (u'things', 'NNS'),
#   (u'may', 'MD'),
#   (u'not', 'RB'),
#   (u'be', 'VB'),
#   (u'as', 'RB'),
#   (u'bad', 'JJ'),
#   (u'as', 'IN'),
#   (u'that', 'DT'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'then', 'RB'),
#   (u'to', 'TO'),
#   (u'go', 'VB'),
#   (u'on', 'IN'),
#   (u'and', 'CC'),
#   (u'make', 'VB'),
#   (u'a', 'DT'),
#   (u'little', 'JJ'),
#   (u'speech', 'NN'),
#   (u'of', 'IN'),
#   (u'his', 'PRP$'),
#   (u'own', 'JJ'),
#   (u',', ','),
#   (u'in', 'IN'),
#   (u'which', 'WDT'),
#   (u'he', 'PRP'),
#   (u'showers', 'VBZ'),
#   (u'congratulations', 'NNS'),
#   (u'and', 'CC'),
#   (u'prophecies', 'NNS'),
#   (u'of', 'IN'),
#   (u'happiness', 'NN'),
#   (u'upon', 'IN'),
#   (u'the', 'DT'),
#   (u'bride', 'NN'),
#   (u'and', 'CC'),
#   (u'groom', 'NN'),
#   (u',', ','),
#   (u'proceeding', 'VBG'),
#   (u'to', 'TO'),
#   (u'particulars', 'NNS'),
#   (u'which', 'WDT'),
#   (u'greatly', 'RB'),
#   (u'delight', 'VBD'),
#   (u'the', 'DT'),
#   (u'young', 'JJ'),
#   (u'men', 'NNS'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'which', 'WDT'),
#   (u'cause', 'VBP'),
#   (u'Ona', 'NNP'),
#   (u'to', 'TO'),
#   (u'blush', 'VB'),
#   (u'more', 'JJR'),
#   (u'furiously', 'RB'),
#   (u'than', 'IN'),
#   (u'ever', 'RB'),
#   (u'.', '.')],
#  [(u'Jokubas', 'NNP'),
#   (u'possesses', 'VBZ'),
#   (u'what', 'WP'),
#   (u'his', 'PRP$'),
#   (u'wife', 'NN'),
#   (u'complacently', 'RB'),
#   (u'describes', 'VBZ'),
#   (u'as', 'IN'),
#   (u'poetiszka', 'NN'),
#   (u'vaidintuve', 'NN'),
#   (u'--', ':'),
#   (u'a', 'DT'),
#   (u'poetical', 'JJ'),
#   (u'imagination', 'NN'),
#   (u'.', '.')],
#  [(u'Now', 'RB'),
#   (u'a', 'DT'),
#   (u'good', 'JJ'),
#   (u'many', 'JJ'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'guests', 'NNS'),
#   (u'have', 'VBP'),
#   (u'finished', 'VBN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u',', ','),
#   (u'since', 'IN'),
#   (u'there', 'EX'),
#   (u'is', 'VBZ'),
#   (u'no', 'DT'),
#   (u'pretense', 'NN'),
#   (u'of', 'IN'),
#   (u'ceremony', 'NN'),
#   (u',', ','),
#   (u'the', 'DT'),
#   (u'banquet', 'NN'),
#   (u'begins', 'VBZ'),
#   (u'to', 'TO'),
#   (u'break', 'VB'),
#   (u'up', 'RP'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'men', 'NNS'),
#   (u'gather', 'VBP'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'bar', 'NN'),
#   (u';', ':'),
#   (u'some', 'DT'),
#   (u'wander', 'VBP'),
#   (u'about', 'IN'),
#   (u',', ','),
#   (u'laughing', 'VBG'),
#   (u'and', 'CC'),
#   (u'singing', 'NN'),
#   (u';', ':'),
#   (u'here', 'RB'),
#   (u'and', 'CC'),
#   (u'there', 'RB'),
#   (u'will', 'MD'),
#   (u'be', 'VB'),
#   (u'a', 'DT'),
#   (u'little', 'JJ'),
#   (u'group', 'NN'),
#   (u',', ','),
#   (u'chanting', 'VBG'),
#   (u'merrily', 'RB'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'in', 'IN'),
#   (u'sublime', 'JJ'),
#   (u'indifference', 'NN'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'others', 'NNS'),
#   (u'and', 'CC'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'orchestra', 'NN'),
#   (u'as', 'RB'),
#   (u'well', 'RB'),
#   (u'.', '.')],
#  [(u'Everybody', 'NN'),
#   (u'is', 'VBZ'),
#   (u'more', 'RBR'),
#   (u'or', 'CC'),
#   (u'less', 'JJR'),
#   (u'restless', 'NN'),
#   (u'--', ':'),
#   (u'one', 'CD'),
#   (u'would', 'MD'),
#   (u'guess', 'VB'),
#   (u'that', 'IN'),
#   (u'something', 'NN'),
#   (u'is', 'VBZ'),
#   (u'on', 'IN'),
#   (u'their', 'PRP$'),
#   (u'minds', 'NNS'),
#   (u'.', '.')],
#  [(u'And', 'CC'),
#   (u'so', 'IN'),
#   (u'it', 'PRP'),
#   (u'proves', 'VBZ'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'last', 'JJ'),
#   (u'tardy', 'JJ'),
#   (u'diners', 'NNS'),
#   (u'are', 'VBP'),
#   (u'scarcely', 'RB'),
#   (u'given', 'VBN'),
#   (u'time', 'NN'),
#   (u'to', 'TO'),
#   (u'finish', 'VB'),
#   (u',', ','),
#   (u'before', 'IN'),
#   (u'the', 'DT'),
#   (u'tables', 'NNS'),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'debris', 'NN'),
#   (u'are', 'VBP'),
#   (u'shoved', 'VBN'),
#   (u'into', 'IN'),
#   (u'the', 'DT'),
#   (u'corner', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'chairs', 'NNS'),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'babies', 'NNS'),
#   (u'piled', 'VBD'),
#   (u'out', 'IN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'way', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'real', 'JJ'),
#   (u'celebration', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'evening', 'NN'),
#   (u'begins', 'VBZ'),
#   (u'.', '.')],
#  [(u'Then', 'RB'),
#   (u'Tamoszius', 'NNP'),
#   (u'Kuszleika', 'NNP'),
#   (u',', ','),
#   (u'after', 'IN'),
#   (u'replenishing', 'VBG'),
#   (u'himself', 'PRP'),
#   (u'with', 'IN'),
#   (u'a', 'DT'),
#   (u'pot', 'NN'),
#   (u'of', 'IN'),
#   (u'beer', 'NN'),
#   (u',', ','),
#   (u'returns', 'VBZ'),
#   (u'to', 'TO'),
#   (u'his', 'PRP$'),
#   (u'platform', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u',', ','),
#   (u'standing', 'VBG'),
#   (u'up', 'RP'),
#   (u',', ','),
#   (u'reviews', 'VBZ'),
#   (u'the', 'DT'),
#   (u'scene', 'NN'),
#   (u';', ':'),
#   (u'he', 'PRP'),
#   (u'taps', 'VBZ'),
#   (u'authoritatively', 'RB'),
#   (u'upon', 'IN'),
#   (u'the', 'DT'),
#   (u'side', 'NN'),
#   (u'of', 'IN'),
#   (u'his', 'PRP$'),
#   (u'violin', 'NN'),
#   (u',', ','),
#   (u'then', 'RB'),
#   (u'tucks', 'VBZ'),
#   (u'it', 'PRP'),
#   (u'carefully', 'RB'),
#   (u'under', 'IN'),
#   (u'his', 'PRP$'),
#   (u'chin', 'NN'),
#   (u',', ','),
#   (u'then', 'RB'),
#   (u'waves', 'VBZ'),
#   (u'his', 'PRP$'),
#   (u'bow', 'NN'),
#   (u'in', 'IN'),
#   (u'an', 'DT'),
#   (u'elaborate', 'JJ'),
#   (u'flourish', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'finally', 'RB'),
#   (u'smites', 'VBZ'),
#   (u'the', 'DT'),
#   (u'sounding', 'JJ'),
#   (u'strings', 'NNS'),
#   (u'and', 'CC'),
#   (u'closes', 'VBZ'),
#   (u'his', 'PRP$'),
#   (u'eyes', 'NNS'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'floats', 'VBZ'),
#   (u'away', 'RB'),
#   (u'in', 'IN'),
#   (u'spirit', 'NN'),
#   (u'upon', 'IN'),
#   (u'the', 'DT'),
#   (u'wings', 'NNS'),
#   (u'of', 'IN'),
#   (u'a', 'DT'),
#   (u'dreamy', 'JJ'),
#   (u'waltz', 'NN'),
#   (u'.', '.')],
#  [(u'His', 'PRP$'),
#   (u'companion', 'NN'),
#   (u'follows', 'VBZ'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'with', 'IN'),
#   (u'his', 'PRP$'),
#   (u'eyes', 'NNS'),
#   (u'open', 'JJ'),
#   (u',', ','),
#   (u'watching', 'VBG'),
#   (u'where', 'WRB'),
#   (u'he', 'PRP'),
#   (u'treads', 'VBZ'),
#   (u',', ','),
#   (u'so', 'RB'),
#   (u'to', 'TO'),
#   (u'speak', 'VB'),
#   (u';', ':'),
#   (u'and', 'CC'),
#   (u'finally', 'RB'),
#   (u'Valentinavyczia', 'NNP'),
#   (u',', ','),
#   (u'after', 'IN'),
#   (u'waiting', 'VBG'),
#   (u'for', 'IN'),
#   (u'a', 'DT'),
#   (u'little', 'JJ'),
#   (u'and', 'CC'),
#   (u'beating', 'VBG'),
#   (u'with', 'IN'),
#   (u'his', 'PRP$'),
#   (u'foot', 'NN'),
#   (u'to', 'TO'),
#   (u'get', 'VB'),
#   (u'the', 'DT'),
#   (u'time', 'NN'),
#   (u',', ','),
#   (u'casts', 'VBZ'),
#   (u'up', 'RP'),
#   (u'his', 'PRP$'),
#   (u'eyes', 'NNS'),
#   (u'to', 'TO'),
#   (u'the', 'DT'),
#   (u'ceiling', 'NN'),
#   (u'and', 'CC'),
#   (u'begins', 'VBZ'),
#   (u'to', 'TO'),
#   (u'saw', 'VB'),
#   (u'--', ':'),
#   (u'Broom', 'NN'),
#   (u'!', '.')],
#  [(u'broom', 'NN'), (u'!', '.')],
#  [(u'broom', 'NN'), (u'!', '.')],
#  [(u'The', 'DT'),
#   (u'company', 'NN'),
#   (u'pairs', 'VBZ'),
#   (u'off', 'RP'),
#   (u'quickly', 'RB'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'the', 'DT'),
#   (u'whole', 'JJ'),
#   (u'room', 'NN'),
#   (u'is', 'VBZ'),
#   (u'soon', 'RB'),
#   (u'in', 'IN'),
#   (u'motion', 'NN'),
#   (u'.', '.')],
#  [(u'Apparently', 'RB'),
#   (u'nobody', 'NN'),
#   (u'knows', 'VBZ'),
#   (u'how', 'WRB'),
#   (u'to', 'TO'),
#   (u'waltz', 'VB'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'that', 'DT'),
#   (u'is', 'VBZ'),
#   (u'nothing', 'NN'),
#   (u'of', 'IN'),
#   (u'any', 'DT'),
#   (u'consequence', 'NN'),
#   (u'--', ':'),
#   (u'there', 'EX'),
#   (u'is', 'VBZ'),
#   (u'music', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'they', 'PRP'),
#   (u'dance', 'VBP'),
#   (u',', ','),
#   (u'each', 'DT'),
#   (u'as', 'IN'),
#   (u'he', 'PRP'),
#   (u'pleases', 'VBZ'),
#   (u',', ','),
#   (u'just', 'RB'),
#   (u'as', 'IN'),
#   (u'before', 'IN'),
#   (u'they', 'PRP'),
#   (u'sang', 'VBP'),
#   (u'.', '.')],
#  [(u'Most', 'JJS'),
#   (u'of', 'IN'),
#   (u'them', 'PRP'),
#   (u'prefer', 'VBP'),
#   (u'the', 'DT'),
#   (u'two-step', 'NN'),
#   (u',', ','),
#   (u'especially', 'RB'),
#   (u'the', 'DT'),
#   (u'young', 'JJ'),
#   (u',', ','),
#   (u'with', 'IN'),
#   (u'whom', 'WP'),
#   (u'it', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'the', 'DT'),
#   (u'fashion', 'NN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'older', 'JJR'),
#   (u'people', 'NNS'),
#   (u'have', 'VBP'),
#   (u'dances', 'NNS'),
#   (u'from', 'IN'),
#   (u'home', 'NN'),
#   (u',', ','),
#   (u'strange', 'JJ'),
#   (u'and', 'CC'),
#   (u'complicated', 'VBD'),
#   (u'steps', 'NNS'),
#   (u'which', 'WDT'),
#   (u'they', 'PRP'),
#   (u'execute', 'VBP'),
#   (u'with', 'IN'),
#   (u'grave', 'JJ'),
#   (u'solemnity', 'NN'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'do', 'VBP'),
#   (u'not', 'RB'),
#   (u'dance', 'VB'),
#   (u'anything', 'NN'),
#   (u'at', 'IN'),
#   (u'all', 'DT'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'simply', 'RB'),
#   (u'hold', 'VB'),
#   (u'each', 'DT'),
#   (u'others', 'NNS'),
#   (u'hands', 'NNS'),
#   (u'and', 'CC'),
#   (u'allow', 'VB'),
#   (u'the', 'DT'),
#   (u'undisciplined', 'JJ'),
#   (u'joy', 'NN'),
#   (u'of', 'IN'),
#   (u'motion', 'NN'),
#   (u'to', 'TO'),
#   (u'express', 'VB'),
#   (u'itself', 'PRP'),
#   (u'with', 'IN'),
#   (u'their', 'PRP$'),
#   (u'feet', 'NNS'),
#   (u'.', '.')],
#  [(u'Among', 'IN'),
#   (u'these', 'DT'),
#   (u'are', 'VBP'),
#   (u'Jokubas', 'NNP'),
#   (u'Szedvilas', 'NNP'),
#   (u'and', 'CC'),
#   (u'his', 'PRP$'),
#   (u'wife', 'NN'),
#   (u',', ','),
#   (u'Lucija', 'NNP'),
#   (u',', ','),
#   (u'who', 'WP'),
#   (u'together', 'RB'),
#   (u'keep', 'VBP'),
#   (u'the', 'DT'),
#   (u'delicatessen', 'NN'),
#   (u'store', 'NN'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'consume', 'VBP'),
#   (u'nearly', 'RB'),
#   (u'as', 'RB'),
#   (u'much', 'JJ'),
#   (u'as', 'IN'),
#   (u'they', 'PRP'),
#   (u'sell', 'VBP'),
#   (u';', ':'),
#   (u'they', 'PRP'),
#   (u'are', 'VBP'),
#   (u'too', 'RB'),
#   (u'fat', 'JJ'),
#   (u'to', 'TO'),
#   (u'dance', 'VB'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'they', 'PRP'),
#   (u'stand', 'VBP'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'middle', 'NN'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'floor', 'NN'),
#   (u',', ','),
#   (u'holding', 'VBG'),
#   (u'each', 'DT'),
#   (u'other', 'JJ'),
#   (u'fast', 'NN'),
#   (u'in', 'IN'),
#   (u'their', 'PRP$'),
#   (u'arms', 'NNS'),
#   (u',', ','),
#   (u'rocking', 'VBG'),
#   (u'slowly', 'RB'),
#   (u'from', 'IN'),
#   (u'side', 'NN'),
#   (u'to', 'TO'),
#   (u'side', 'VB'),
#   (u'and', 'CC'),
#   (u'grinning', 'VBG'),
#   (u'seraphically', 'RB'),
#   (u',', ','),
#   (u'a', 'DT'),
#   (u'picture', 'NN'),
#   (u'of', 'IN'),
#   (u'toothless', 'NN'),
#   (u'and', 'CC'),
#   (u'perspiring', 'VBG'),
#   (u'ecstasy', 'NN'),
#   (u'.', '.')],
#  [(u'Of', 'IN'),
#   (u'these', 'DT'),
#   (u'older', 'JJR'),
#   (u'people', 'NNS'),
#   (u'many', 'JJ'),
#   (u'wear', 'VBP'),
#   (u'clothing', 'VBG'),
#   (u'reminiscent', 'NN'),
#   (u'in', 'IN'),
#   (u'some', 'DT'),
#   (u'detail', 'NN'),
#   (u'of', 'IN'),
#   (u'home', 'NN'),
#   (u'--', ':'),
#   (u'an', 'DT'),
#   (u'embroidered', 'JJ'),
#   (u'waistcoat', 'NN'),
#   (u'or', 'CC'),
#   (u'stomacher', 'NN'),
#   (u',', ','),
#   (u'or', 'CC'),
#   (u'a', 'DT'),
#   (u'gaily', 'RB'),
#   (u'colored', 'VBN'),
#   (u'handkerchief', 'NN'),
#   (u',', ','),
#   (u'or', 'CC'),
#   (u'a', 'DT'),
#   (u'coat', 'NN'),
#   (u'with', 'IN'),
#   (u'large', 'JJ'),
#   (u'cuffs', 'NNS'),
#   (u'and', 'CC'),
#   (u'fancy', 'JJ'),
#   (u'buttons', 'NNS'),
#   (u'.', '.')],
#  [(u'All', 'PDT'),
#   (u'these', 'DT'),
#   (u'things', 'NNS'),
#   (u'are', 'VBP'),
#   (u'carefully', 'RB'),
#   (u'avoided', 'VBN'),
#   (u'by', 'IN'),
#   (u'the', 'DT'),
#   (u'young', 'JJ'),
#   (u',', ','),
#   (u'most', 'JJS'),
#   (u'of', 'IN'),
#   (u'whom', 'WP'),
#   (u'have', 'VBP'),
#   (u'learned', 'VBN'),
#   (u'to', 'TO'),
#   (u'speak', 'VB'),
#   (u'English', 'NNP'),
#   (u'and', 'CC'),
#   (u'to', 'TO'),
#   (u'affect', 'VB'),
#   (u'the', 'DT'),
#   (u'latest', 'JJS'),
#   (u'style', 'NN'),
#   (u'of', 'IN'),
#   (u'clothing', 'NN'),
#   (u'.', '.')],
#  [(u'The', 'DT'),
#   (u'girls', 'NNS'),
#   (u'wear', 'VBP'),
#   (u'ready-made', 'JJ'),
#   (u'dresses', 'NNS'),
#   (u'or', 'CC'),
#   (u'shirt', 'NN'),
#   (u'waists', 'NNS'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'some', 'DT'),
#   (u'of', 'IN'),
#   (u'them', 'PRP'),
#   (u'look', 'VBP'),
#   (u'quite', 'RB'),
#   (u'pretty', 'RB'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'young', 'JJ'),
#   (u'men', 'NNS'),
#   (u'you', 'PRP'),
#   (u'would', 'MD'),
#   (u'take', 'VB'),
#   (u'to', 'TO'),
#   (u'be', 'VB'),
#   (u'Americans', 'NNPS'),
#   (u',', ','),
#   (u'of', 'IN'),
#   (u'the', 'DT'),
#   (u'type', 'NN'),
#   (u'of', 'IN'),
#   (u'clerks', 'NNS'),
#   (u',', ','),
#   (u'but', 'CC'),
#   (u'for', 'IN'),
#   (u'the', 'DT'),
#   (u'fact', 'NN'),
#   (u'that', 'IN'),
#   (u'they', 'PRP'),
#   (u'wear', 'VBP'),
#   (u'their', 'PRP$'),
#   (u'hats', 'NNS'),
#   (u'in', 'IN'),
#   (u'the', 'DT'),
#   (u'room', 'NN'),
#   (u'.', '.')],
#  [(u'Each', 'DT'),
#   (u'of', 'IN'),
#   (u'these', 'DT'),
#   (u'younger', 'JJR'),
#   (u'couples', 'NNS'),
#   (u'affects', 'VBZ'),
#   (u'a', 'DT'),
#   (u'style', 'NN'),
#   (u'of', 'IN'),
#   (u'its', 'PRP$'),
#   (u'own', 'JJ'),
#   (u'in', 'IN'),
#   (u'dancing', 'VBG'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'hold', 'VBP'),
#   (u'each', 'DT'),
#   (u'other', 'JJ'),
#   (u'tightly', 'RB'),
#   (u',', ','),
#   (u'some', 'DT'),
#   (u'at', 'IN'),
#   (u'a', 'DT'),
#   (u'cautious', 'JJ'),
#   (u'distance', 'NN'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'hold', 'VBP'),
#   (u'their', 'PRP$'),
#   (u'hands', 'NNS'),
#   (u'out', 'RP'),
#   (u'stiffly', 'NN'),
#   (u',', ','),
#   (u'some', 'DT'),
#   (u'drop', 'VBP'),
#   (u'them', 'PRP'),
#   (u'loosely', 'RB'),
#   (u'at', 'IN'),
#   (u'their', 'PRP$'),
#   (u'sides', 'NNS'),
#   (u'.', '.')],
#  [(u'Some', 'DT'),
#   (u'dance', 'NN'),
#   (u'springily', 'RB'),
#   (u',', ','),
#   (u'some', 'DT'),
#   (u'glide', 'NN'),
#   (u'softly', 'RB'),
#   (u',', ','),
#   (u'some', 'DT'),
#   (u'move', 'NN'),
#   (u'with', 'IN'),
#   (u'grave', 'JJ'),
#   (u'dignity', 'NN'),
#   (u'.', '.')],
#  [(u'There', 'EX'),
#   (u'are', 'VBP'),
#   (u'boisterous', 'JJ'),
#   (u'couples', 'NNS'),
#   (u',', ','),
#   (u'who', 'WP'),
#   (u'tear', 'VBP'),
#   (u'wildly', 'RB'),
#   (u'about', 'IN'),
#   (u'the', 'DT'),
#   (u'room', 'NN'),
#   (u',', ','),
#   (u'knocking', 'VBG'),
#   (u'every', 'DT'),
#   (u'one', 'CD'),
#   (u'out', 'IN'),
#   (u'of', 'IN'),
#   (u'their', 'PRP$'),
#   (u'way', 'NN'),
#   (u'.', '.')],
#  [(u'There', 'EX'),
#   (u'are', 'VBP'),
#   (u'nervous', 'JJ'),
#   (u'couples', 'NNS'),
#   (u',', ','),
#   (u'whom', 'WP'),
#   (u'these', 'DT'),
#   (u'frighten', 'NNS'),
#   (u',', ','),
#   (u'and', 'CC'),
#   (u'who', 'WP'),
#   (u'cry', 'VBP'),
#   (u',', ','),
#   (u'Nusfok', 'NNP'),
#   (u'!', '.')],
#  [(u'Kas', 'NNP'), (u'yra', 'NN'), (u'?', '.')],
#  [(u'at', 'IN'),
#   (u'them', 'PRP'),
#   (u'as', 'IN'),
#   (u'they', 'PRP'),
#   (u'pass', 'VBP'),
#   (u'.', '.')],
#  [(u'Each', 'DT'),
#   (u'couple', 'NN'),
#   (u'is', 'VBZ'),
#   (u'paired', 'VBN'),
#   (u'for', 'IN'),
#   (u'the', 'DT'),
#   (u'evening', 'NN'),
#   (u'--', ':'),
#   (u'you', 'PRP'),
#   (u'will', 'MD'),
#   (u'never', 'RB'),
#   (u'see', 'VB'),
#   (u'them', 'PRP'),
#   (u'change', 'VB'),
#   (u'about', 'IN'),
#   (u'.', '.')],
#  [(u'There', 'EX'),
#   (u'is', 'VBZ'),
#   (u'Alena', 'NNP'),
#   (u'Jasaityte', 'NNP'),
#   (u',', ','),
#   (u'for', 'IN'),
#   (u'instance', 'NN'),
#   (u',', ','),
#   (u'who', 'WP'),
#   (u'has', 'VBZ'),
#   (u'danced', 'VBN'),
#   (u'unending', 'JJ'),
#   (u'hours', 'NNS'),
#   (u'with', 'IN'),
#   (u'Juozas', 'NNP'),
#   (u'Raczius', 'NNP'),
#   (u',', ','),
#   (u'to', 'TO'),
#   (u'whom', 'WP'),
#   (u'she', 'PRP'),
#   (u'is', 'VBZ'),
#   (u'engaged', 'VBN'),
#   (u'.', '.')]]

# %%
#locations = [] # opens an empty list for locations
gpe =[] #opens an empty list for geopolitical entities
#persons = [] #opens an empty list for persons
#organizations = [] #opens an empty list for organizations

# %% [markdown]
# #### Extracting named entities from the text

# %%
for i in tagged_sentences: # for each part of speech tagged sentence in a tagged_sentences list, extract named entities based on the chunking
    chunked_sentence = nltk.ne_chunk(i, binary=False) # predict which noun phrases in the text are named entities. If binary is set to True, ask the model to predict whether something is a named entity or not. If set to False, the model predicts the type of named entity.   
    gpe.extend(extract_entity_names(chunked_sentence, 'GPE'))#extract geopolitical entities from the text
    #locations.extend(extract_entity_names(chunked_sentence, 'LOCATION')) # extract loctions from the text
    #persons.extend(extract_entity_names(chunked_sentence, 'PERSON')) #extract persons from the text
    #organizations.extend(extract_entity_names(chunked_sentence, 'ORGANIZATION')) #extract organizations from the text

# %%
length = len(gpe)
#length = len(locations)
#length = len(persons)
#length = len(organizations)

# %%
length
# Out:
# 1125

# %%
set(gpe) #get a unique set of geopolitical entities from the text
#set(locations)
#set(persons)
#set(organizations)
# Out:
# {u'Africa',
#  u'Again',
#  u'Agriculture',
#  u'Ah',
#  u'Aha',
#  u'Ai',
#  u'Aint',
#  u'Aladdin',
#  u'Aldermen',
#  u'Always',
#  u'America',
#  u'American',
#  u'Americans',
#  u'And',
#  u'Aniele',
#  u'Anieles',
#  u'Antanas',
#  u'Anyhow',
#  u'Anything',
#  u'Appeal',
#  u'Argentina',
#  u'August',
#  u'Aunt',
#  u'Australia',
#  u'Awful',
#  u'Ballroom',
#  u'Bean',
#  u'Beda',
#  u'Been',
#  u'Bethlehem',
#  u'Beyond',
#  u'Bohemian',
#  u'Bohemians',
#  u'Boston',
#  u'Bribery',
#  u'Brotherhood',
#  u'Brown',
#  u'Browns',
#  u'Bungtown',
#  u'Bureau',
#  u'CHICAGO',
#  u'California',
#  u'Canada',
#  u'Capital',
#  u'Cheap',
#  u'Chicago',
#  u'Chicagos',
#  u'Chinamen',
#  u'Christ',
#  u'Christmas',
#  u'Cincinnati',
#  u'City',
#  u'Cleo',
#  u'Colorado',
#  u'Come',
#  u'Comrade',
#  u'Couldnt',
#  u'County',
#  u'Creek',
#  u'Cut',
#  u'Czia',
#  u'De',
#  u'Dekui',
#  u'Delicatessen',
#  u'Der',
#  u'Detroit',
#  u'Dieve',
#  u'Dont',
#  u'Dot',
#  u'Downstairs',
#  u'Doyle',
#  u'Duane',
#  u'Duanes',
#  u'Duck',
#  u'Durham',
#  u'Durhams',
#  u'Durys',
#  u'Dutchwoman',
#  u'East',
#  u'Eastern',
#  u'Eat',
#  u'Ecrasez',
#  u'Egyptian',
#  u'Eiffel',
#  u'Eik',
#  u'Eiksz',
#  u'Elzbieta',
#  u'Elzbietas',
#  u'Employ',
#  u'English',
#  u'Europe',
#  u'European',
#  u'Evolution',
#  u'Fall River',
#  u'Far',
#  u'Farewell',
#  u'Faust',
#  u'Fertilizer',
#  u'Fifteen',
#  u'France',
#  u'Freddie',
#  u'Freddies',
#  u'French',
#  u'Funny',
#  u'Furious',
#  u'Gee',
#  u'German',
#  u'Germans',
#  u'Germany',
#  u'Gods',
#  u'Good',
#  u'Gott',
#  u'Grahams',
#  u'Graicziau',
#  u'Graiczunas',
#  u'Great',
#  u'Greed',
#  u'Greeks',
#  u'Greenbacker',
#  u'Grief',
#  u'Guvner',
#  u'Had',
#  u'Hadda',
#  u'Half',
#  u'Halloran',
#  u'Hamilton',
#  u'Hangin',
#  u'Heaven',
#  u'Heim',
#  u'Hell',
#  u'Hello',
#  u'Helpless',
#  u'Helps',
#  u'Hessian',
#  u'Hey',
#  u'Him',
#  u'Himmel',
#  u'Hinds',
#  u'Hindss',
#  u'Hip',
#  u'Ho',
#  u'Holland',
#  u'Home',
#  u'Honest',
#  u'Honor',
#  u'Horse',
#  u'Hospital',
#  u'Humph',
#  u'Hunger',
#  u'Hungry',
#  u'Id',
#  u'Ill',
#  u'Illinois',
#  u'Im',
#  u'Incandescent',
#  u'Indiana',
#  u'Indians',
#  u'Interest',
#  u'Irish',
#  u'Isaiah',
#  u'Italian',
#  u'Italians',
#  u'Italy',
#  u'Jadvyga',
#  u'Jadvygas',
#  u'Jake',
#  u'Japan',
#  u'Japanese',
#  u'Je',
#  u'Jesus',
#  u'Job',
#  u'Jokubas',
#  u'Joliet',
#  u'Jonas',
#  u'July',
#  u'June',
#  u'Juozapas',
#  u'Juozas',
#  u'Jurgis',
#  u'Jurgiss',
#  u'Kamskatka',
#  u'Kansas',
#  u'Kansas City',
#  u'Kas',
#  u'Kentucky',
#  u'Kittens',
#  u'Kitty',
#  u'Kotrina',
#  u'Labor',
#  u'Lessee',
#  u'Levee',
#  u'Lexington',
#  u'Lights',
#  u'Liquid',
#  u'Lithuania',
#  u'Lithuanian',
#  u'Lithuanians',
#  u'Little',
#  u'Look',
#  u'Looks',
#  u'Lord',
#  u'Lossa',
#  u'Lucas',
#  u'Lucija',
#  u'Macaroni',
#  u'Maine',
#  u'Manchuria',
#  u'Manitoba',
#  u'Marija',
#  u'Marijas',
#  u'Marriage',
#  u'Massachusetts',
#  u'Me',
#  u'Mebbe',
#  u'Men',
#  u'Mercy',
#  u'Missouri',
#  u'Money',
#  u'Months',
#  u'Mos',
#  u'Muma',
#  u'Namai',
#  u'Nay',
#  u'Nazareth',
#  u'Negro',
#  u'Negroes',
#  u'Never',
#  u'New',
#  u'New Years',
#  u'New York',
#  u'Next',
#  u'Ninety',
#  u'No',
#  u'Nobody',
#  u'Northern',
#  u'Norwegian',
#  u'Nothing',
#  u'Nuff',
#  u'Ohio',
#  u'Oklahoma',
#  u'Old',
#  u'Ole',
#  u'Omaha',
#  u'Ona',
#  u'Onas',
#  u'Oregon',
#  u'Organize',
#  u'Ostrinski',
#  u'Ostrinskis',
#  u'Packingtown',
#  u'Pagaiksztis',
#  u'Palauk',
#  u'Paris',
#  u'Part',
#  u'Pasilinksminimams',
#  u'Past',
#  u'Persian',
#  u'Pilgrim',
#  u'Please',
#  u'Polish',
#  u'Poor',
#  u'Potato',
#  u'Prieszpietys',
#  u'Prometheus',
#  u'Quick',
#  u'Raw',
#  u'Relentless',
#  u'Rome',
#  u'Roumanians',
#  u'Rudkus',
#  u'Rummy',
#  u'Russia',
#  u'Russian',
#  u'Ruysdael',
#  u'Rytoj',
#  u'Safes',
#  u'San Francisco',
#  u'Sauerkraut',
#  u'Save',
#  u'Say',
#  u'Scab',
#  u'Scully',
#  u'Scullys',
#  u'Septyni',
#  u'Seven',
#  u'Shake',
#  u'Shes',
#  u'Shovel',
#  u'Siberia',
#  u'Sicilians',
#  u'Sick',
#  u'Silesia',
#  u'Slovak',
#  u'Smolensk',
#  u'Socialism',
#  u'Sooner',
#  u'South',
#  u'South America',
#  u'South Carolina',
#  u'South Chicago',
#  u'South Dakota',
#  u'South Omaha',
#  u'Southern',
#  u'Spaniards',
#  u'St.',
#  u'St. Joseph',
#  u'St. Louis',
#  u'St. Paul',
#  u'Stand',
#  u'Stanislovas',
#  u'Stop',
#  u'Stranger',
#  u'Sudiev',
#  u'Sundays',
#  u'Susimilkie',
#  u'Swede',
#  u'System',
#  u'Szalin',
#  u'Szedvilas',
#  u'Szedvilases',
#  u'Szluofa',
#  u'Sznapsas',
#  u'Tamoszius',
#  u'Tea',
#  u'Texas',
#  u'Thank',
#  u'Thass',
#  u'Thats',
#  u'Thirty',
#  u'Tolstoy',
#  u'Tomorrow',
#  u'Tonight',
#  u'Toward',
#  u'Trojan',
#  u'Tu',
#  u'Understand',
#  u'United',
#  u'United States',
#  u'Upstairs',
#  u'Valentinavyczia',
#  u'Vatican',
#  u'Vell',
#  u'Vere',
#  u'Vigorous',
#  u'Vilna',
#  u'Vot',
#  u'Vun',
#  u'Vy',
#  u'Wait',
#  u'Walk',
#  u'Want',
#  u'Wanta',
#  u'Wealth',
#  u'Welcome',
#  u'Western',
#  u'Whatcha',
#  u'Which',
#  u'Whisky',
#  u'Whisky Point',
#  u'Whose',
#  u'Whuzya',
#  u'Whuzzis',
#  u'Wisconsin',
#  u'Womb',
#  u'Wonderlands',
#  u'Work',
#  u'Wot',
#  u'Youre',
#  u'Zarnos'}

# %%
#di_locations = list_to_dict(locations) # convert a list to a dictionary that counts the occurrences of each of geographical entity
#di_persons = list_to_dict(persons)
#di_organizations = list_to_dict(organizations)
di_gpe = list_to_dict(gpe)

# %%
#di_locations = OrderedDict(sorted(di_locations.items(), key=lambda t: t[1], reverse=True))
#di_persons = OrderedDict(sorted(di_persons.items(), key=lambda t: t[1], reverse=True))
#di_organizatios = OrderedDict(sorted(di_organizations.items(), key=lambda t: t[1], reverse=True))
di_gpe = OrderedDict(sorted(di_gpe.items(), key=lambda t: t[1], reverse=True)) #sort the dictionary in a decreasing order

# %%
#di_locations
#di_persons
#di_organizations
di_gpe
# Out:
# OrderedDict([(u'Jurgis', 166),
#              (u'Packingtown', 72),
#              (u'Chicago', 64),
#              (u'Ona', 45),
#              (u'America', 34),
#              (u'Durhams', 18),
#              (u'Jurgiss', 18),
#              (u'English', 17),
#              (u'Lithuanian', 15),
#              (u'Onas', 15),
#              (u'American', 14),
#              (u'Kotrina', 13),
#              (u'Browns', 12),
#              (u'Hamilton', 11),
#              (u'United States', 10),
#              (u'Lithuania', 10),
#              (u'Elzbieta', 9),
#              (u'Marija', 9),
#              (u'Im', 9),
#              (u'Polish', 8),
#              (u'Ah', 8),
#              (u'Dont', 7),
#              (u'New York', 7),
#              (u'Socialism', 6),
#              (u'Good', 6),
#              (u'Irish', 6),
#              (u'Guvner', 5),
#              (u'Marijas', 5),
#              (u'French', 5),
#              (u'Antanas', 5),
#              (u'Little', 5),
#              (u'Nobody', 4),
#              (u'Massachusetts', 4),
#              (u'Europe', 4),
#              (u'Russia', 4),
#              (u'Chicagos', 4),
#              (u'Jadvyga', 4),
#              (u'South Carolina', 4),
#              (u'Scullys', 4),
#              (u'Aniele', 4),
#              (u'Durham', 4),
#              (u'Thass', 4),
#              (u'Ho', 4),
#              (u'Hello', 4),
#              (u'Tamoszius', 4),
#              (u'South', 4),
#              (u'Kansas', 3),
#              (u'German', 3),
#              (u'Aldermen', 3),
#              (u'Szedvilas', 3),
#              (u'Texas', 3),
#              (u'Anieles', 3),
#              (u'Wait', 3),
#              (u'Please', 3),
#              (u'Duane', 3),
#              (u'Bohemian', 3),
#              (u'Kittens', 3),
#              (u'Je', 3),
#              (u'Thirty', 3),
#              (u'Quick', 3),
#              (u'Hell', 3),
#              (u'Halloran', 3),
#              (u'Freddie', 3),
#              (u'Organize', 3),
#              (u'Manchuria', 3),
#              (u'New', 3),
#              (u'Palauk', 3),
#              (u'Nothing', 3),
#              (u'Heaven', 3),
#              (u'Stanislovas', 3),
#              (u'California', 3),
#              (u'Vot', 3),
#              (u'Great', 3),
#              (u'Ai', 3),
#              (u'Indians', 2),
#              (u'Indiana', 2),
#              (u'Appeal', 2),
#              (u'Western', 2),
#              (u'Anything', 2),
#              (u'Scully', 2),
#              (u'Interest', 2),
#              (u'Me', 2),
#              (u'Ohio', 2),
#              (u'Greed', 2),
#              (u'Sooner', 2),
#              (u'Japanese', 2),
#              (u'Beyond', 2),
#              (u'Agriculture', 2),
#              (u'Next', 2),
#              (u'Job', 2),
#              (u'Vere', 2),
#              (u'Fertilizer', 2),
#              (u'Colorado', 2),
#              (u'Egyptian', 2),
#              (u'Germans', 2),
#              (u'Whose', 2),
#              (u'Ostrinski', 2),
#              (u'Levee', 2),
#              (u'Italian', 2),
#              (u'France', 2),
#              (u'Jonas', 2),
#              (u'Youre', 2),
#              (u'Honor', 2),
#              (u'Duanes', 2),
#              (u'Christ', 2),
#              (u'Hey', 2),
#              (u'Gott', 2),
#              (u'Rudkus', 2),
#              (u'Szedvilases', 2),
#              (u'Nay', 2),
#              (u'Kansas City', 2),
#              (u'Far', 2),
#              (u'Aint', 2),
#              (u'Again', 2),
#              (u'St. Joseph', 2),
#              (u'Oklahoma', 2),
#              (u'Jadvygas', 2),
#              (u'Americans', 2),
#              (u'No', 2),
#              (u'Kitty', 2),
#              (u'Sundays', 2),
#              (u'Nuff', 2),
#              (u'Ostrinskis', 2),
#              (u'Valentinavyczia', 2),
#              (u'Himmel', 2),
#              (u'Tu', 2),
#              (u'Canada', 1),
#              (u'Bureau', 1),
#              (u'Ecrasez', 1),
#              (u'Brown', 1),
#              (u'Juozapas', 1),
#              (u'Ballroom', 1),
#              (u'Bohemians', 1),
#              (u'Greenbacker', 1),
#              (u'Grief', 1),
#              (u'Eat', 1),
#              (u'Pilgrim', 1),
#              (u'CHICAGO', 1),
#              (u'South Omaha', 1),
#              (u'Whuzzis', 1),
#              (u'East', 1),
#              (u'Persian', 1),
#              (u'Bungtown', 1),
#              (u'Downstairs', 1),
#              (u'Marriage', 1),
#              (u'Employ', 1),
#              (u'Aha', 1),
#              (u'Szluofa', 1),
#              (u'Shes', 1),
#              (u'Home', 1),
#              (u'Maine', 1),
#              (u'St.', 1),
#              (u'Hinds', 1),
#              (u'Macaroni', 1),
#              (u'Sick', 1),
#              (u'Grahams', 1),
#              (u'Australia', 1),
#              (u'August', 1),
#              (u'June', 1),
#              (u'Russian', 1),
#              (u'New Years', 1),
#              (u'Sicilians', 1),
#              (u'Beda', 1),
#              (u'Roumanians', 1),
#              (u'Honest', 1),
#              (u'Septyni', 1),
#              (u'Gods', 1),
#              (u'Tonight', 1),
#              (u'Money', 1),
#              (u'Tomorrow', 1),
#              (u'Hessian', 1),
#              (u'Funny', 1),
#              (u'Lossa', 1),
#              (u'Northern', 1),
#              (u'Lord', 1),
#              (u'Christmas', 1),
#              (u'Holland', 1),
#              (u'Kas', 1),
#              (u'Prometheus', 1),
#              (u'Joliet', 1),
#              (u'Trojan', 1),
#              (u'Lucas', 1),
#              (u'Lessee', 1),
#              (u'Always', 1),
#              (u'Furious', 1),
#              (u'Lithuanians', 1),
#              (u'Dot', 1),
#              (u'St. Louis', 1),
#              (u'Upstairs', 1),
#              (u'Hindss', 1),
#              (u'Farewell', 1),
#              (u'Manitoba', 1),
#              (u'Horse', 1),
#              (u'Illinois', 1),
#              (u'Nazareth', 1),
#              (u'Smolensk', 1),
#              (u'Womb', 1),
#              (u'Hip', 1),
#              (u'Sudiev', 1),
#              (u'Negro', 1),
#              (u'Doyle', 1),
#              (u'Anyhow', 1),
#              (u'Him', 1),
#              (u'Mercy', 1),
#              (u'Evolution', 1),
#              (u'Hungry', 1),
#              (u'Vatican', 1),
#              (u'South Dakota', 1),
#              (u'Raw', 1),
#              (u'Say', 1),
#              (u'Incandescent', 1),
#              (u'Whisky', 1),
#              (u'Wot', 1),
#              (u'Which', 1),
#              (u'Save', 1),
#              (u'Welcome', 1),
#              (u'Norwegian', 1),
#              (u'Heim', 1),
#              (u'Comrade', 1),
#              (u'Work', 1),
#              (u'Stand', 1),
#              (u'Boston', 1),
#              (u'Jesus', 1),
#              (u'Past', 1),
#              (u'Helpless', 1),
#              (u'Spaniards', 1),
#              (u'Pagaiksztis', 1),
#              (u'Hangin', 1),
#              (u'Eastern', 1),
#              (u'Wonderlands', 1),
#              (u'Elzbietas', 1),
#              (u'Silesia', 1),
#              (u'Kamskatka', 1),
#              (u'Seven', 1),
#              (u'Hunger', 1),
#              (u'Dutchwoman', 1),
#              (u'Italians', 1),
#              (u'Duck', 1),
#              (u'De', 1),
#              (u'Graiczunas', 1),
#              (u'Germany', 1),
#              (u'Half', 1),
#              (u'Swede', 1),
#              (u'Kentucky', 1),
#              (u'Wisconsin', 1),
#              (u'Relentless', 1),
#              (u'Vell', 1),
#              (u'Fall River', 1),
#              (u'Delicatessen', 1),
#              (u'St. Paul', 1),
#              (u'Want', 1),
#              (u'Paris', 1),
#              (u'Had', 1),
#              (u'European', 1),
#              (u'Poor', 1),
#              (u'Mos', 1),
#              (u'Eiffel', 1),
#              (u'South Chicago', 1),
#              (u'Wanta', 1),
#              (u'Humph', 1),
#              (u'Lexington', 1),
#              (u'Whatcha', 1),
#              (u'Chinamen', 1),
#              (u'Pasilinksminimams', 1),
#              (u'Wealth', 1),
#              (u'Aladdin', 1),
#              (u'Hospital', 1),
#              (u'Freddies', 1),
#              (u'County', 1),
#              (u'Vigorous', 1),
#              (u'Juozas', 1),
#              (u'Oregon', 1),
#              (u'Part', 1),
#              (u'July', 1),
#              (u'Isaiah', 1),
#              (u'Hadda', 1),
#              (u'Sznapsas', 1),
#              (u'Thats', 1),
#              (u'Tolstoy', 1),
#              (u'Muma', 1),
#              (u'Lights', 1),
#              (u'Dieve', 1),
#              (u'Southern', 1),
#              (u'Gee', 1),
#              (u'Lucija', 1),
#              (u'Liquid', 1),
#              (u'Mebbe', 1),
#              (u'Months', 1),
#              (u'Whisky Point', 1),
#              (u'And', 1),
#              (u'Old', 1),
#              (u'Ole', 1),
#              (u'Ninety', 1),
#              (u'Bethlehem', 1),
#              (u'City', 1),
#              (u'Italy', 1),
#              (u'Capital', 1),
#              (u'Stop', 1),
#              (u'Bean', 1),
#              (u'Brotherhood', 1),
#              (u'Safes', 1),
#              (u'Rummy', 1),
#              (u'Vun', 1),
#              (u'Ill', 1),
#              (u'Dekui', 1),
#              (u'Faust', 1),
#              (u'Rome', 1),
#              (u'Zarnos', 1),
#              (u'Vy', 1),
#              (u'Id', 1),
#              (u'United', 1),
#              (u'Thank', 1),
#              (u'Labor', 1),
#              (u'Szalin', 1),
#              (u'Negroes', 1),
#              (u'San Francisco', 1),
#              (u'Argentina', 1),
#              (u'Durys', 1),
#              (u'Czia', 1),
#              (u'Susimilkie', 1),
#              (u'Potato', 1),
#              (u'Aunt', 1),
#              (u'Missouri', 1),
#              (u'Eik', 1),
#              (u'Shovel', 1),
#              (u'Cincinnati', 1),
#              (u'Creek', 1),
#              (u'Slovak', 1),
#              (u'Siberia', 1),
#              (u'System', 1),
#              (u'Been', 1),
#              (u'Men', 1),
#              (u'Fifteen', 1),
#              (u'Look', 1),
#              (u'Stranger', 1),
#              (u'Jokubas', 1),
#              (u'Toward', 1),
#              (u'Namai', 1),
#              (u'Scab', 1),
#              (u'Cheap', 1),
#              (u'South America', 1),
#              (u'Looks', 1),
#              (u'Shake', 1),
#              (u'Japan', 1),
#              (u'Cut', 1),
#              (u'Sauerkraut', 1),
#              (u'Greeks', 1),
#              (u'Whuzya', 1),
#              (u'Helps', 1),
#              (u'Vilna', 1),
#              (u'Awful', 1),
#              (u'Come', 1),
#              (u'Ruysdael', 1),
#              (u'Rytoj', 1),
#              (u'Der', 1),
#              (u'Detroit', 1),
#              (u'Tea', 1),
#              (u'Africa', 1),
#              (u'Walk', 1),
#              (u'Jake', 1),
#              (u'Graicziau', 1),
#              (u'Never', 1),
#              (u'Understand', 1),
#              (u'Omaha', 1),
#              (u'Eiksz', 1),
#              (u'Prieszpietys', 1),
#              (u'Bribery', 1),
#              (u'Cleo', 1),
#              (u'Couldnt', 1)])

# %%
#%store di_persons >> dic_pride_and_prejudice_per.txt 
#%store di_locations >> dic_pride_and_prejudice_loc.txt
#%store di_organizations >> dic_pride_and_prejudice_org.txt

#%store di_persons >> dic_main_street_per.txt
#%store di_locations >> dic_main_street_per_loc.txt
#%store di_organizations >> dic_main_street_org_org.txt

#%store di_persons >> dic_the_jungle_per.txt
#%store di_locations >> dic_the_jungle_loc.txt
#%store di_organizations >> dic_the_jungle_org.txt

# %% [markdown]
# #### Extracting noun phrases

# %%
nounphrases = []
grammar = "NP: {<DT>?<JJ>*<NN>}" #running regular expressions on part of speech to obtain noun phrase constituents from the text
for sent in tagged_sentences:
    cp = nltk.RegexpParser(grammar)
    result = cp.parse(sent)
    for sent in result.subtrees():
            if sent.label() == "NP":
                nounphrases.append(str(sent.leaves()))
for i in nounphrases:
    print (i)

#print (nounphrases)
#%store nounphrases >> nounphrases_pride_and_prejudice.txt
#%store nounphrases >> nounphrases_main_street.txt
#%store nounphrases >> nounphrases_the_jungle.txt
# Out:
# [(u'Chapter', 'NN')]
# [(u'oclock', 'NN')]
# [(u'the', 'DT'), (u'ceremony', 'NN')]
# [(u'a', 'DT'), (u'crowd', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'the', 'DT'), (u'exuberance', 'NN')]
# [(u'The', 'DT'), (u'occasion', 'NN')]
# [(u'task', 'NN')]
# [(u'due', 'JJ'), (u'form', 'NN')]
# [(u'home', 'NN')]
# [(u'out', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'tremendous', 'JJ'), (u'voice', 'NN')]
# [(u'the', 'DT'), (u'church', 'NN')]
# [(u'the', 'DT'), (u'hall', 'NN')]
# [(u'the', 'DT'), (u'coachman', 'NN')]
# [(u'faster', 'NN')]
# [(u'that', 'DT'), (u'personage', 'NN')]
# [(u'the', 'DT'), (u'matter', 'NN')]
# [(u'the', 'DT'), (u'window', 'NN')]
# [(u'the', 'DT'), (u'carriage', 'NN')]
# [(u'opinion', 'NN')]
# [(u'the', 'DT'), (u'advantage', 'NN')]
# [(u'altitude', 'NN')]
# [(u'the', 'DT'), (u'driver', 'NN')]
# [(u'ground', 'NN')]
# [(u'the', 'DT'), (u'result', 'NN')]
# [(u'a', 'DT'), (u'furious', 'JJ'), (u'altercation', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'a', 'DT'), (u'new', 'JJ'), (u'swarm', 'NN')]
# [(u'the', 'DT'), (u'cortege', 'NN')]
# [(u'each', 'DT'), (u'side', 'NN')]
# [(u'street', 'NN')]
# [(u'a', 'DT'), (u'mile', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'The', 'DT'), (u'music', 'NN')]
# [(u'a', 'DT'), (u'block', 'NN')]
# [(u'the', 'DT'), (u'dull', 'NN')]
# [(u'broom', 'NN')]
# [(u'broom', 'NN')]
# [(u'a', 'DT'), (u'cello', 'NN')]
# [(u'the', 'DT'), (u'squeaking', 'NN')]
# [(u'the', 'DT'), (u'throng', 'NN')]
# [(u'the', 'DT'), (u'debate', 'NN')]
# [(u'coachman', 'NN')]
# [(u'carriage', 'NN')]
# [(u'a', 'DT'), (u'way', 'NN')]
# [(u'the', 'DT'), (u'hall', 'NN')]
# [(u'the', 'DT'), (u'other', 'JJ'), (u'way', 'NN')]
# [(u'roaring', 'NN')]
# [(u'Eik', 'NN')]
# [(u'the', 'DT'), (u'orchestral', 'JJ'), (u'uproar', 'JJ'), (u'sound', 'NN')]
# [(u'fairy', 'JJ'), (u'music', 'NN')]
# [(u'darzas', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'The', 'DT'), (u'reader', 'NN')]
# [(u'much', 'JJ'), (u'converse', 'NN')]
# [(u'the', 'DT'), (u'language', 'NN')]
# [(u'the', 'DT'), (u'explanation', 'NN')]
# [(u'the', 'DT'), (u'place', 'NN')]
# [(u'the', 'DT'), (u'rear', 'JJ'), (u'room', 'NN')]
# [(u'a', 'DT'), (u'saloon', 'NN')]
# [(u'that', 'DT'), (u'part', 'NN')]
# [(u'back', 'NN')]
# [(u'This', 'DT'), (u'information', 'NN')]
# [(u'the', 'DT'), (u'matter', 'NN')]
# [(u'fact', 'NN')]
# [(u'the', 'DT'), (u'supreme', 'JJ'), (u'hour', 'NN')]
# [(u'ecstasy', 'NN')]
# [(u'the', 'DT'), (u'life', 'NN')]
# [(u'the', 'DT'), (u'scene', 'NN')]
# [(u'the', 'DT'), (u'wedding', 'NN')]
# [(u'feast', 'NN')]
# [(u'the', 'DT'), (u'joy-transfiguration', 'NN')]
# [(u'the', 'DT'), (u'doorway', 'NN')]
# [(u'breathless', 'NN')]
# [(u'the', 'DT'), (u'crowd', 'NN')]
# [(u'happiness', 'NN')]
# [(u'painful', 'NN')]
# [(u'a', 'DT'), (u'light', 'NN')]
# [(u'wonder', 'NN')]
# [(u'otherwise', 'NN')]
# [(u'wan', 'NN')]
# [(u'little', 'JJ'), (u'face', 'NN')]
# [(u'a', 'DT'), (u'muslin', 'NN')]
# [(u'dress', 'NN')]
# [(u'a', 'DT'), (u'stiff', 'JJ'), (u'little', 'JJ'), (u'veil', 'NN')]
# [(u'pink', 'JJ'), (u'paper', 'NN')]
# [(u'the', 'DT'), (u'veil', 'NN')]
# [(u'new', 'JJ'), (u'white', 'JJ'), (u'cotton', 'NN')]
# [(u'the', 'DT'), (u'pain', 'NN')]
# [(u'great', 'JJ'), (u'emotion', 'NN')]
# [(u'face', 'NN')]
# [(u'the', 'DT'), (u'tremor', 'NN')]
# [(u'form', 'NN')]
# [(u'age', 'NN')]
# [(u'a', 'DT'), (u'mere', 'JJ'), (u'child', 'NN')]
# [(u'the', 'DT'), (u'white', 'JJ'), (u'flower', 'NN')]
# [(u'the', 'DT'), (u'buttonhole', 'NN')]
# [(u'new', 'JJ'), (u'black', 'JJ'), (u'suit', 'NN')]
# [(u'the', 'DT'), (u'mighty', 'NN')]
# [(u'beetling', 'NN')]
# [(u'thick', 'JJ'), (u'black', 'JJ'), (u'hair', 'NN')]
# [(u'a', 'DT'), (u'two-hundred-and-fifty-pound', 'JJ'), (u'quarter', 'NN')]
# [(u'beef', 'NN')]
# [(u'a', 'DT'), (u'car', 'NN')]
# [(u'a', 'DT'), (u'stagger', 'NN')]
# [(u'a', 'DT'), (u'thought', 'NN')]
# [(u'corner', 'NN')]
# [(u'a', 'DT'), (u'hunted', 'JJ'), (u'animal', 'NN')]
# [(u'tongue', 'NN')]
# [(u'each', 'DT'), (u'time', 'NN')]
# [(u'a', 'DT'), (u'separation', 'NN')]
# [(u'a', 'DT'), (u'separation', 'NN')]
# [(u'no', 'DT'), (u'time', 'NN')]
# [(u'a', 'DT'), (u'chair', 'NN')]
# [(u'the', 'DT'), (u'feast', 'NN')]
# [(u'the', 'DT'), (u'veselija', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'a', 'DT'), (u'rule', 'NN')]
# [(u'district', 'NN')]
# [(u'quarter', 'NN')]
# [(u'the', 'DT'), (u'street', 'NN')]
# [(u'A', 'DT'), (u'charming', 'JJ'), (u'informality', 'NN')]
# [(u'this', 'DT'), (u'celebration', 'NN')]
# [(u'singing', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'medley', 'NN')]
# [(u'sound', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'a', 'DT'), (u'number', 'NN')]
# [(u'the', 'DT'), (u'total', 'NN')]
# [(u'no', 'DT'), (u'other', 'JJ'), (u'place', 'NN')]
# [(u'part', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'a', 'DT'), (u'collection', 'NN')]
# [(u'cribs', 'NN')]
# [(u'corner', 'NN')]
# [(u'the', 'DT'), (u'case', 'NN')]
# [(u'meat', 'NN')]
# [(u'bologna', 'NN')]
# [(u'The', 'DT'), (u'room', 'NN')]
# [(u'bare', 'NN')]
# [(u'save', 'NN')]
# [(u'a', 'DT'), (u'calendar', 'NN')]
# [(u'a', 'DT'), (u'picture', 'NN')]
# [(u'a', 'DT'), (u'race', 'NN')]
# [(u'horse', 'NN')]
# [(u'a', 'DT'), (u'family', 'NN')]
# [(u'tree', 'NN')]
# [(u'a', 'DT'), (u'gilded', 'JJ'), (u'frame', 'NN')]
# [(u'the', 'DT'), (u'right', 'NN')]
# [(u'a', 'DT'), (u'door', 'NN')]
# [(u'the', 'DT'), (u'saloon', 'NN')]
# [(u'the', 'DT'), (u'doorway', 'NN')]
# [(u'the', 'DT'), (u'corner', 'NN')]
# [(u'a', 'DT'), (u'bar', 'NN')]
# [(u'genius', 'NN')]
# [(u'clad', 'NN')]
# [(u'curl', 'NN')]
# [(u'side', 'NN')]
# [(u'forehead', 'NN')]
# [(u'the', 'DT'), (u'opposite', 'JJ'), (u'corner', 'NN')]
# [(u'a', 'DT'), (u'third', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'the', 'DT'), (u'hungrier', 'NN')]
# [(u'the', 'DT'), (u'head', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'a', 'DT'), (u'snow-white', 'JJ'), (u'cake', 'NN')]
# [(u'tower', 'NN')]
# [(u'constructed', 'JJ'), (u'decoration', 'NN')]
# [(u'sugar', 'NN')]
# [(u'a', 'DT'), (u'generous', 'JJ'), (u'sprinkling', 'NN')]
# [(u'pink', 'NN')]
# [(u'Beyond', 'NN')]
# [(u'a', 'DT'), (u'door', 'NN')]
# [(u'the', 'DT'), (u'kitchen', 'NN')]
# [(u'a', 'DT'), (u'glimpse', 'NN')]
# [(u'a', 'DT'), (u'range', 'NN')]
# [(u'much', 'JJ'), (u'steam', 'NN')]
# [(u'hither', 'NN')]
# [(u'thither', 'NN')]
# [(u'the', 'DT'), (u'corner', 'NN')]
# [(u'the', 'DT'), (u'left', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'platform', 'NN')]
# [(u'some', 'DT'), (u'impression', 'NN')]
# [(u'the', 'DT'), (u'hubbub', 'NN')]
# [(u'an', 'DT'), (u'open', 'JJ'), (u'window', 'NN')]
# [(u'whence', 'NN')]
# [(u'the', 'DT'), (u'populace', 'NN')]
# [(u'the', 'DT'), (u'steam', 'NN')]
# [(u'stepmother', 'NN')]
# [(u'bearing', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'platter', 'NN')]
# [(u'stewed', 'JJ'), (u'duck', 'NN')]
# [(u'way', 'NN')]
# [(u'a', 'DT'), (u'similar', 'JJ'), (u'burden', 'NN')]
# [(u'a', 'DT'), (u'minute', 'NN')]
# [(u'a', 'DT'), (u'big', 'JJ'), (u'yellow', 'JJ'), (u'bowl', 'NN')]
# [(u'smoking', 'NN')]
# [(u'herself', 'NN')]
# [(u'bit', 'NN')]
# [(u'bit', 'NN')]
# [(u'the', 'DT'), (u'feast', 'NN')]
# [(u'form', 'NN')]
# [(u'a', 'DT'), (u'ham', 'NN')]
# [(u'a', 'DT'), (u'dish', 'NN')]
# [(u'sauerkraut', 'NN')]
# [(u'rice', 'NN')]
# [(u'macaroni', 'NN')]
# [(u'bologna', 'NN')]
# [(u'penny', 'NN')]
# [(u'bowls', 'NN')]
# [(u'milk', 'NN')]
# [(u'beer', 'NN')]
# [(u'back', 'NN')]
# [(u'the', 'DT'), (u'bar', 'NN')]
# [(u'order', 'NN')]
# [(u'Eiksz', 'NN')]
# [(u'Graicziau', 'NN')]
# [(u'the', 'DT'), (u'stove', 'NN')]
# [(u'laughter', 'NN')]
# [(u'endless', 'JJ'), (u'badinage', 'NN')]
# [(u'merriment', 'NN')]
# [(u'part', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'resolution', 'NN')]
# [(u'advance', 'NN')]
# [(u'the', 'DT'), (u'shrinking', 'NN')]
# [(u'the', 'DT'), (u'right', 'JJ'), (u'hand', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'insignia', 'NN')]
# [(u'office', 'NN')]
# [(u'paper', 'NN')]
# [(u'the', 'DT'), (u'rest', 'NN')]
# [(u'The', 'DT'), (u'spirit', 'NN')]
# [(u'the', 'DT'), (u'occasion', 'NN')]
# [(u'hold', 'NN')]
# [(u'the', 'DT'), (u'stately', 'JJ'), (u'bartender', 'NN')]
# [(u'a', 'DT'), (u'plate', 'NN')]
# [(u'stewed', 'JJ'), (u'duck', 'NN')]
# [(u'the', 'DT'), (u'fat', 'JJ'), (u'policeman', 'NN')]
# [(u'duty', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'a', 'DT'), (u'chair', 'NN')]
# [(u'the', 'DT'), (u'foot', 'NN')]
# [(u'the', 'DT'), (u'table', 'NN')]
# [(u'shout', 'NN')]
# [(u'laughs', 'NN')]
# [(u'clamor', 'NN')]
# [(u'begin', 'NN')]
# [(u'this', 'DT'), (u'time', 'NN')]
# [(u'a', 'DT'), (u'mad', 'NN')]
# [(u'frenzy', 'NN')]
# [(u'this', 'DT'), (u'scene', 'NN')]
# [(u'sung', 'NN')]
# [(u'music', 'NN')]
# [(u'the', 'DT'), (u'music', 'NN')]
# [(u'the', 'DT'), (u'music', 'NN')]
# [(u'the', 'DT'), (u'place', 'NN')]
# [(u'the', 'DT'), (u'rear', 'JJ'), (u'room', 'NN')]
# [(u'a', 'DT'), (u'saloon', 'NN')]
# [(u'back', 'NN')]
# [(u'a', 'DT'), (u'fairy', 'JJ'), (u'place', 'NN')]
# [(u'a', 'DT'), (u'wonderland', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'corner', 'NN')]
# [(u'the', 'DT'), (u'sky', 'NN')]
# [(u'The', 'DT'), (u'little', 'JJ'), (u'person', 'NN')]
# [(u'this', 'DT'), (u'trio', 'NN')]
# [(u'an', 'DT'), (u'inspired', 'JJ'), (u'man', 'NN')]
# [(u'fiddle', 'NN')]
# [(u'tune', 'NN')]
# [(u'no', 'DT'), (u'rosin', 'NN')]
# [(u'bow', 'NN')]
# [(u'an', 'DT'), (u'inspired', 'JJ'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'demon', 'NN')]
# [(u'a', 'DT'), (u'whole', 'JJ'), (u'horde', 'NN')]
# [(u'the', 'DT'), (u'air', 'NN')]
# [(u'round', 'NN')]
# [(u'the', 'DT'), (u'pace', 'NN')]
# [(u'the', 'DT'), (u'hair', 'NN')]
# [(u'the', 'DT'), (u'leader', 'NN')]
# [(u'end', 'NN')]
# [(u'name', 'NN')]
# [(u'the', 'DT'), (u'violin', 'NN')]
# [(u'all', 'DT'), (u'night', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'shirt', 'NN')]
# [(u'a', 'DT'), (u'vest', 'NN')]
# [(u'faded', 'JJ'), (u'gold', 'NN')]
# [(u'a', 'DT'), (u'pink-striped', 'JJ'), (u'shirt', 'NN')]
# [(u'suggestive', 'NN')]
# [(u'peppermint', 'NN')]
# [(u'candy', 'NN')]
# [(u'A', 'DT'), (u'pair', 'NN')]
# [(u'light', 'JJ'), (u'blue', 'NN')]
# [(u'a', 'DT'), (u'yellow', 'JJ'), (u'stripe', 'NN')]
# [(u'that', 'DT'), (u'suggestion', 'NN')]
# [(u'authority', 'NN')]
# [(u'proper', 'NN')]
# [(u'the', 'DT'), (u'leader', 'NN')]
# [(u'a', 'DT'), (u'band', 'NN')]
# [(u'the', 'DT'), (u'ground', 'NN')]
# [(u'the', 'DT'), (u'excitement', 'NN')]
# [(u'presence', 'NN')]
# [(u'time', 'NN')]
# [(u'an', 'DT'), (u'inspired', 'JJ'), (u'man', 'NN')]
# [(u'Every', 'DT'), (u'inch', 'NN')]
# [(u'head', 'NN')]
# [(u'fro', 'NN')]
# [(u'a', 'DT'), (u'wizened-up', 'JJ'), (u'little', 'JJ'), (u'face', 'NN')]
# [(u'a', 'DT'), (u'turn', 'NN')]
# [(u'knit', 'NN')]
# [(u'work', 'NN')]
# [(u'necktie', 'JJ'), (u'bristle', 'NN')]
# [(u'every', 'DT'), (u'inch', 'NN')]
# [(u'behalf', 'NN')]
# [(u'call', 'NN')]
# [(u'the', 'DT'), (u'orchestra', 'NN')]
# [(u'The', 'DT'), (u'second', 'JJ'), (u'violin', 'NN')]
# [(u'a', 'DT'), (u'tall', 'NN')]
# [(u'gaunt', 'NN')]
# [(u'man', 'NN')]
# [(u'the', 'DT'), (u'mute', 'NN')]
# [(u'patient', 'JJ'), (u'look', 'NN')]
# [(u'an', 'DT'), (u'overdriven', 'JJ'), (u'mule', 'NN')]
# [(u'the', 'DT'), (u'whip', 'NN')]
# [(u'old', 'JJ'), (u'rut', 'NN')]
# [(u'The', 'DT'), (u'third', 'JJ'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'round', 'NN')]
# [(u'sentimental', 'JJ'), (u'nose', 'NN')]
# [(u'the', 'DT'), (u'sky', 'NN')]
# [(u'a', 'DT'), (u'look', 'NN')]
# [(u'infinite', 'JJ'), (u'yearning', 'NN')]
# [(u'a', 'DT'), (u'bass', 'NN')]
# [(u'part', 'NN')]
# [(u'cello', 'NN')]
# [(u'the', 'DT'), (u'excitement', 'NN')]
# [(u'nothing', 'NN')]
# [(u'no', 'DT'), (u'matter', 'NN')]
# [(u'task', 'NN')]
# [(u'long-drawn', 'NN')]
# [(u'lugubrious', 'JJ'), (u'note', 'NN')]
# [(u'oclock', 'NN')]
# [(u'the', 'DT'), (u'afternoon', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'hour', 'NN')]
# [(u'morning', 'NN')]
# [(u'third', 'NN')]
# [(u'the', 'DT'), (u'total', 'JJ'), (u'income', 'NN')]
# [(u'dollar', 'NN')]
# [(u'hour', 'NN')]
# [(u'the', 'DT'), (u'feast', 'NN')]
# [(u'way', 'NN')]
# [(u'excitement', 'NN')]
# [(u'a', 'DT'), (u'minute', 'NN')]
# [(u'breath', 'NN')]
# [(u'head', 'NN')]
# [(u'violin', 'NN')]
# [(u'the', 'DT'), (u'long', 'JJ'), (u'form', 'NN')]
# [(u'the', 'DT'), (u'second', 'JJ'), (u'violinist', 'NN')]
# [(u'the', 'DT'), (u'end', 'NN')]
# [(u'step', 'NN')]
# [(u'step', 'NN')]
# [(u'the', 'DT'), (u'cellist', 'NN')]
# [(u'instrument', 'NN')]
# [(u'the', 'DT'), (u'foot', 'NN')]
# [(u'a', 'DT'), (u'stool', 'NN')]
# [(u'glory', 'NN')]
# [(u'the', 'DT'), (u'scene', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'mistake', 'NN')]
# [(u'the', 'DT'), (u'dirt', 'NN')]
# [(u'noise', 'NN')]
# [(u'squalor', 'NN')]
# [(u'this', 'DT'), (u'material', 'NN')]
# [(u'utterance', 'NN')]
# [(u'merry', 'NN')]
# [(u'wailing', 'NN')]
# [(u'passionate', 'NN')]
# [(u'this', 'DT'), (u'music', 'NN')]
# [(u'music', 'NN')]
# [(u'music', 'NN')]
# [(u'home', 'NN')]
# [(u'sunlit', 'NN')]
# [(u'mighty', 'NN')]
# [(u'home', 'NN')]
# [(u'childhood', 'NN')]
# [(u'old', 'JJ'), (u'joys', 'NN')]
# [(u'laugh', 'NN')]
# [(u'weep', 'NN')]
# [(u'Some', 'DT'), (u'fall', 'NN')]
# [(u'the', 'DT'), (u'table', 'NN')]
# [(u'a', 'DT'), (u'cry', 'NN')]
# [(u'this', 'DT'), (u'song', 'NN')]
# [(u'the', 'DT'), (u'fire', 'NN')]
# [(u'brighter', 'NN')]
# [(u'fiddle', 'NN')]
# [(u'mad', 'JJ'), (u'career', 'NN')]
# [(u'The', 'DT'), (u'company', 'NN')]
# [(u'the', 'DT'), (u'floor', 'NN')]
# [(u'an', 'DT'), (u'old', 'JJ'), (u'wedding', 'NN')]
# [(u'song', 'NN')]
# [(u'the', 'DT'), (u'beauty', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'the', 'DT'), (u'joys', 'NN')]
# [(u'love', 'NN')]
# [(u'the', 'DT'), (u'excitement', 'NN')]
# [(u'this', 'DT'), (u'masterpiece', 'NN')]
# [(u'way', 'NN')]
# [(u'the', 'DT'), (u'head', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'a', 'DT'), (u'foot', 'NN')]
# [(u'space', 'NN')]
# [(u'bow', 'NN')]
# [(u'whenever', 'NN')]
# [(u'progress', 'NN')]
# [(u'needless', 'NN')]
# [(u'the', 'DT'), (u'cello', 'NN')]
# [(u'the', 'DT'), (u'head', 'NN')]
# [(u'station', 'NN')]
# [(u'the', 'DT'), (u'right', 'JJ'), (u'hand', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'soul', 'NN')]
# [(u'a', 'DT'), (u'while', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'something', 'NN')]
# [(u'elbow', 'NN')]
# [(u'part', 'NN')]
# [(u'wonder', 'NN')]
# [(u'a', 'DT'), (u'flutter', 'NN')]
# [(u'a', 'DT'), (u'hummingbird', 'NN')]
# [(u'breathless', 'NN')]
# [(u'the', 'DT'), (u'music', 'NN')]
# [(u'the', 'DT'), (u'far-off', 'JJ'), (u'look', 'NN')]
# [(u'heart', 'NN')]
# [(u'cheeks', 'NN')]
# [(u'head', 'NN')]
# [(u'the', 'DT'), (u'end', 'NN')]
# [(u'side', 'NN')]
# [(u'magic', 'NN')]
# [(u'wand', 'NN')]
# [(u'cheeks', 'NN')]
# [(u'this', 'DT'), (u'crisis', 'NN')]
# [(u'fond', 'NN')]
# [(u'a', 'DT'), (u'song', 'NN')]
# [(u'a', 'DT'), (u'song', 'NN')]
# [(u'build', 'NN')]
# [(u'a', 'DT'), (u'canning', 'NN')]
# [(u'factory', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'beef', 'NN')]
# [(u'face', 'NN')]
# [(u'prominent', 'JJ'), (u'red', 'JJ'), (u'cheeks', 'NN')]
# [(u'mouth', 'NN')]
# [(u'thinking', 'NN')]
# [(u'a', 'DT'), (u'horse', 'NN')]
# [(u'a', 'DT'), (u'blue', 'JJ'), (u'flannel', 'NN')]
# [(u'shirt-waist', 'NN')]
# [(u'brawny', 'NN')]
# [(u'a', 'DT'), (u'carving', 'NN')]
# [(u'fork', 'NN')]
# [(u'hand', 'NN')]
# [(u'the', 'DT'), (u'table', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'song', 'NN')]
# [(u'a', 'DT'), (u'voice', 'NN')]
# [(u'no', 'DT'), (u'portion', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'vacant', 'NN')]
# [(u'note', 'NN')]
# [(u'note', 'NN')]
# [(u'stanza', 'NN')]
# [(u'stanza', 'NN')]
# [(u'lamentation', 'NN')]
# [(u'kvietkeli', 'NN')]
# [(u'tu', 'JJ'), (u'brangiausis', 'NN')]
# [(u'ir', 'NN')]
# [(u'laime', 'NN')]
# [(u'man', 'NN')]
# [(u'biednam', 'NN')]
# [(u'vargt', 'NN')]
# [(u'ant', 'NN')]
# [(u'svieto', 'NN')]
# [(u'reik', 'NN')]
# [(u'vienam', 'NN')]
# [(u'the', 'DT'), (u'song', 'NN')]
# [(u'time', 'NN')]
# [(u'the', 'DT'), (u'speech', 'NN')]
# [(u'father', 'NN')]
# [(u'age', 'NN')]
# [(u'the', 'DT'), (u'change', 'NN')]
# [(u'manhood', 'NN')]
# [(u'a', 'DT'), (u'cotton', 'NN')]
# [(u'mill', 'NN')]
# [(u'a', 'DT'), (u'coughing', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'trouble', 'NN')]
# [(u'the', 'DT'), (u'pickle', 'NN')]
# [(u'the', 'DT'), (u'breathing', 'NN')]
# [(u'the', 'DT'), (u'cold', 'NN')]
# [(u'air', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'a', 'DT'), (u'coughing', 'NN')]
# [(u'fit', 'NN')]
# [(u'chair', 'NN')]
# [(u'wan', 'NN')]
# [(u'face', 'NN')]
# [(u'the', 'DT'), (u'custom', 'NN')]
# [(u'the', 'DT'), (u'speech', 'NN')]
# [(u'a', 'DT'), (u'veselija', 'NN')]
# [(u'heart', 'NN')]
# [(u'a', 'DT'), (u'scholar', 'NN')]
# [(u'the', 'DT'), (u'love', 'NN')]
# [(u'an', 'DT'), (u'original', 'JJ'), (u'speech', 'NN')]
# [(u'congratulation', 'NN')]
# [(u'benediction', 'NN')]
# [(u'the', 'DT'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'draw', 'NN')]
# [(u'sob', 'NN')]
# [(u'the', 'DT'), (u'idea', 'NN')]
# [(u'speech', 'NN')]
# [(u'a', 'DT'), (u'delicatessen', 'JJ'), (u'store', 'NN')]
# [(u'hearty', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'speech', 'NN')]
# [(u'happiness', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'groom', 'NN')]
# [(u'wife', 'NN')]
# [(u'poetiszka', 'NN')]
# [(u'vaidintuve', 'NN')]
# [(u'a', 'DT'), (u'poetical', 'JJ'), (u'imagination', 'NN')]
# [(u'no', 'DT'), (u'pretense', 'NN')]
# [(u'ceremony', 'NN')]
# [(u'the', 'DT'), (u'banquet', 'NN')]
# [(u'the', 'DT'), (u'bar', 'NN')]
# [(u'singing', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'group', 'NN')]
# [(u'sublime', 'JJ'), (u'indifference', 'NN')]
# [(u'the', 'DT'), (u'orchestra', 'NN')]
# [(u'Everybody', 'NN')]
# [(u'restless', 'NN')]
# [(u'something', 'NN')]
# [(u'time', 'NN')]
# [(u'the', 'DT'), (u'debris', 'NN')]
# [(u'the', 'DT'), (u'corner', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'the', 'DT'), (u'real', 'JJ'), (u'celebration', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'a', 'DT'), (u'pot', 'NN')]
# [(u'beer', 'NN')]
# [(u'platform', 'NN')]
# [(u'the', 'DT'), (u'scene', 'NN')]
# [(u'the', 'DT'), (u'side', 'NN')]
# [(u'violin', 'NN')]
# [(u'chin', 'NN')]
# [(u'bow', 'NN')]
# [(u'an', 'DT'), (u'elaborate', 'JJ'), (u'flourish', 'NN')]
# [(u'spirit', 'NN')]
# [(u'a', 'DT'), (u'dreamy', 'JJ'), (u'waltz', 'NN')]
# [(u'companion', 'NN')]
# [(u'foot', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'ceiling', 'NN')]
# [(u'Broom', 'NN')]
# [(u'broom', 'NN')]
# [(u'broom', 'NN')]
# [(u'The', 'DT'), (u'company', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'room', 'NN')]
# [(u'motion', 'NN')]
# [(u'nobody', 'NN')]
# [(u'nothing', 'NN')]
# [(u'any', 'DT'), (u'consequence', 'NN')]
# [(u'music', 'NN')]
# [(u'the', 'DT'), (u'two-step', 'NN')]
# [(u'the', 'DT'), (u'fashion', 'NN')]
# [(u'home', 'NN')]
# [(u'grave', 'JJ'), (u'solemnity', 'NN')]
# [(u'anything', 'NN')]
# [(u'the', 'DT'), (u'undisciplined', 'JJ'), (u'joy', 'NN')]
# [(u'motion', 'NN')]
# [(u'wife', 'NN')]
# [(u'the', 'DT'), (u'delicatessen', 'NN')]
# [(u'store', 'NN')]
# [(u'the', 'DT'), (u'middle', 'NN')]
# [(u'the', 'DT'), (u'floor', 'NN')]
# [(u'each', 'DT'), (u'other', 'JJ'), (u'fast', 'NN')]
# [(u'side', 'NN')]
# [(u'a', 'DT'), (u'picture', 'NN')]
# [(u'toothless', 'NN')]
# [(u'ecstasy', 'NN')]
# [(u'reminiscent', 'NN')]
# [(u'some', 'DT'), (u'detail', 'NN')]
# [(u'home', 'NN')]
# [(u'an', 'DT'), (u'embroidered', 'JJ'), (u'waistcoat', 'NN')]
# [(u'stomacher', 'NN')]
# [(u'handkerchief', 'NN')]
# [(u'a', 'DT'), (u'coat', 'NN')]
# [(u'style', 'NN')]
# [(u'clothing', 'NN')]
# [(u'shirt', 'NN')]
# [(u'the', 'DT'), (u'type', 'NN')]
# [(u'the', 'DT'), (u'fact', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'a', 'DT'), (u'style', 'NN')]
# [(u'a', 'DT'), (u'cautious', 'JJ'), (u'distance', 'NN')]
# [(u'stiffly', 'NN')]
# [(u'Some', 'DT'), (u'dance', 'NN')]
# [(u'some', 'DT'), (u'glide', 'NN')]
# [(u'some', 'DT'), (u'move', 'NN')]
# [(u'grave', 'JJ'), (u'dignity', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'way', 'NN')]
# [(u'yra', 'NN')]
# [(u'Each', 'DT'), (u'couple', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'instance', 'NN')]
# [(u'the', 'DT'), (u'beauty', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'a', 'DT'), (u'white', 'JJ'), (u'shirtwaist', 'NN')]
# [(u'labor', 'NN')]
# [(u'skirt', 'NN')]
# [(u'hand', 'NN')]
# [(u'stately', 'JJ'), (u'precision', 'NN')]
# [(u'the', 'DT'), (u'manner', 'NN')]
# [(u'a', 'DT'), (u'tough', 'JJ'), (u'aspect', 'NN')]
# [(u'hat', 'NN')]
# [(u'side', 'NN')]
# [(u'a', 'DT'), (u'cigarette', 'NN')]
# [(u'mouth', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'likewise', 'NN')]
# [(u'an', 'DT'), (u'invalid', 'JJ'), (u'mother', 'NN')]
# [(u'hair', 'NN')]
# [(u'the', 'DT'), (u'latter', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'knot', 'NN')]
# [(u'the', 'DT'), (u'top', 'NN')]
# [(u'head', 'NN')]
# [(u'an', 'DT'), (u'old', 'JJ'), (u'white', 'JJ'), (u'dress', 'NN')]
# [(u'trouble', 'NN')]
# [(u'view', 'NN')]
# [(u'head', 'NN')]
# [(u'shoulder', 'NN')]
# [(u'turn', 'NN')]
# [(u'the', 'DT'), (u'entire', 'JJ'), (u'evening', 'NN')]
# [(u'ecstasy', 'NN')]
# [(u'bliss', 'NN')]
# [(u'the', 'DT'), (u'story', 'NN')]
# [(u'the', 'DT'), (u'fifth', 'JJ'), (u'year', 'NN')]
# [(u'heart', 'NN')]
# [(u'the', 'DT'), (u'beginning', 'NN')]
# [(u'a', 'DT'), (u'father', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'other', 'JJ'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'large', 'JJ'), (u'family', 'NN')]
# [(u'a', 'DT'), (u'skilled', 'JJ'), (u'man', 'NN')]
# [(u'cruel', 'NN')]
# [(u'the', 'DT'), (u'heart', 'NN')]
# [(u'a', 'DT'), (u'beef-boner', 'NN')]
# [(u'a', 'DT'), (u'dangerous', 'JJ'), (u'trade', 'NN')]
# [(u'piecework', 'NN')]
# [(u'a', 'DT'), (u'bride', 'NN')]
# [(u'knife', 'NN')]
# [(u'mad', 'NN')]
# [(u'somebody', 'NN')]
# [(u'a', 'DT'), (u'bone', 'NN')]
# [(u'hand', 'NN')]
# [(u'the', 'DT'), (u'blade', 'NN')]
# [(u'a', 'DT'), (u'fearful', 'JJ'), (u'gash', 'NN')]
# [(u'the', 'DT'), (u'deadly', 'JJ'), (u'contagion', 'NN')]
# [(u'The', 'DT'), (u'cut', 'NN')]
# [(u'home', 'NN')]
# [(u'blood', 'NN')]
# [(u'poisoning', 'NN')]
# [(u'The', 'DT'), (u'last', 'JJ'), (u'time', 'NN')]
# [(u'job', 'NN')]
# [(u'standing', 'NN')]
# [(u'the', 'DT'), (u'packing', 'NN')]
# [(u'oclock', 'NN')]
# [(u'bitter', 'JJ'), (u'winter', 'NN')]
# [(u'a', 'DT'), (u'foot', 'NN')]
# [(u'snow', 'NN')]
# [(u'the', 'DT'), (u'ground', 'NN')]
# [(u'the', 'DT'), (u'air', 'NN')]
# [(u'an', 'DT'), (u'hour', 'NN')]
# [(u'a', 'DT'), (u'rest', 'NN')]
# [(u'perforce', 'NN')]
# [(u'no', 'DT'), (u'place', 'NN')]
# [(u'a', 'DT'), (u'minute', 'NN')]
# [(u'the', 'DT'), (u'leader', 'NN')]
# [(u'spite', 'NN')]
# [(u'This', 'DT'), (u'time', 'NN')]
# [(u'another', 'DT'), (u'sort', 'NN')]
# [(u'a', 'DT'), (u'dance', 'NN')]
# [(u'a', 'DT'), (u'Lithuanian', 'JJ'), (u'dance', 'NN')]
# [(u'the', 'DT'), (u'two-step', 'NN')]
# [(u'the', 'DT'), (u'majority', 'NN')]
# [(u'an', 'DT'), (u'intricate', 'JJ'), (u'series', 'NN')]
# [(u'fancy', 'JJ'), (u'skating', 'NN')]
# [(u'a', 'DT'), (u'dance', 'NN')]
# [(u'The', 'DT'), (u'climax', 'NN')]
# [(u'a', 'DT'), (u'furious', 'JJ'), (u'prestissimo', 'NN')]
# [(u'a', 'DT'), (u'mad', 'JJ'), (u'whirling', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'the', 'DT'), (u'place', 'NN')]
# [(u'a', 'DT'), (u'maze', 'NN')]
# [(u'the', 'DT'), (u'sight', 'NN')]
# [(u'this', 'DT'), (u'moment', 'NN')]
# [(u'protest', 'NN')]
# [(u'no', 'DT'), (u'mercy', 'NN')]
# [(u'The', 'DT'), (u'sweat', 'NN')]
# [(u'forehead', 'NN')]
# [(u'a', 'DT'), (u'cyclist', 'NN')]
# [(u'the', 'DT'), (u'last', 'JJ'), (u'lap', 'NN')]
# [(u'a', 'DT'), (u'race', 'NN')]
# [(u'body', 'NN')]
# [(u'a', 'DT'), (u'runaway', 'JJ'), (u'steam', 'NN')]
# [(u'engine', 'NN')]
# [(u'the', 'DT'), (u'ear', 'NN')]
# [(u'a', 'DT'), (u'pale', 'JJ'), (u'blue', 'NN')]
# [(u'mist', 'NN')]
# [(u'arm', 'NN')]
# [(u'wonderful', 'JJ'), (u'rush', 'NN')]
# [(u'the', 'DT'), (u'end', 'NN')]
# [(u'the', 'DT'), (u'tune', 'NN')]
# [(u'a', 'DT'), (u'final', 'JJ'), (u'shout', 'NN')]
# [(u'delight', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'beer', 'NN')]
# [(u'a', 'DT'), (u'long', 'JJ'), (u'breath', 'NN')]
# [(u'the', 'DT'), (u'great', 'JJ'), (u'event', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'the', 'DT'), (u'acziavimas', 'NN')]
# [(u'The', 'DT'), (u'acziavimas', 'NN')]
# [(u'a', 'DT'), (u'ceremony', 'NN')]
# [(u'uninterrupted', 'JJ'), (u'dance', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'ring', 'NN')]
# [(u'the', 'DT'), (u'music', 'NN')]
# [(u'a', 'DT'), (u'circle', 'NN')]
# [(u'the', 'DT'), (u'center', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'the', 'DT'), (u'enclosure', 'NN')]
# [(u'dance', 'NN')]
# [(u'merry', 'JJ'), (u'proceeding', 'NN')]
# [(u'laughter', 'NN')]
# [(u'singing', 'NN')]
# [(u'the', 'DT'), (u'guest', 'NN')]
# [(u'face', 'NN')]
# [(u'face', 'NN')]
# [(u'the', 'DT'), (u'hat', 'NN')]
# [(u'a', 'DT'), (u'sum', 'NN')]
# [(u'money', 'NN')]
# [(u'a', 'DT'), (u'dollar', 'NN')]
# [(u'power', 'NN')]
# [(u'estimate', 'NN')]
# [(u'the', 'DT'), (u'value', 'NN')]
# [(u'the', 'DT'), (u'privilege', 'NN')]
# [(u'this', 'DT'), (u'entertainment', 'NN')]
# [(u'a', 'DT'), (u'neat', 'JJ'), (u'sum', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'bridegroom', 'NN')]
# [(u'life', 'NN')]
# [(u'this', 'DT'), (u'entertainment', 'NN')]
# [(u'income', 'NN')]
# [(u'a', 'DT'), (u'person', 'NN')]
# [(u'this', 'DT'), (u'room', 'NN')]
# [(u'early', 'JJ'), (u'morning', 'NN')]
# [(u'night', 'NN')]
# [(u'a', 'DT'), (u'quarter', 'NN')]
# [(u'an', 'DT'), (u'inch', 'NN')]
# [(u'water', 'NN')]
# [(u'the', 'DT'), (u'floor', 'NN')]
# [(u'the', 'DT'), (u'year', 'NN')]
# [(u'the', 'DT'), (u'sunlight', 'NN')]
# [(u'afternoon', 'NN')]
# [(u'morning', 'NN')]
# [(u'a', 'DT'), (u'year', 'NN')]
# [(u'scarce', 'NN')]
# [(u'the', 'DT'), (u'top', 'NN')]
# [(u'the', 'DT'), (u'work', 'NN')]
# [(u'the', 'DT'), (u'half', 'NN')]
# [(u'a', 'DT'), (u'year', 'NN')]
# [(u'the', 'DT'), (u'third', 'NN')]
# [(u'a', 'DT'), (u'sum', 'NN')]
# [(u'a', 'DT'), (u'single', 'JJ'), (u'day', 'NN')]
# [(u'life', 'NN')]
# [(u'a', 'DT'), (u'wedding', 'NN')]
# [(u'feast', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'thing', 'NN')]
# [(u'own', 'JJ'), (u'wedding', 'NN')]
# [(u'a', 'DT'), (u'long', 'JJ'), (u'time', 'NN')]
# [(u'bit', 'NN')]
# [(u'everything', 'NN')]
# [(u'the', 'DT'), (u'power', 'NN')]
# [(u'the', 'DT'), (u'veselija', 'NN')]
# [(u'defeat', 'NN')]
# [(u'the', 'DT'), (u'difference', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'The', 'DT'), (u'veselija', 'NN')]
# [(u'a', 'DT'), (u'far-off', 'JJ'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'meaning', 'NN')]
# [(u'the', 'DT'), (u'cave', 'NN')]
# [(u'gaze', 'NN')]
# [(u'upon', 'NN')]
# [(u'lifetime', 'NN')]
# [(u'the', 'DT'), (u'sun', 'NN')]
# [(u'lifetime', 'NN')]
# [(u'the', 'DT'), (u'fact', 'NN')]
# [(u'life', 'NN')]
# [(u'no', 'DT'), (u'such', 'JJ'), (u'great', 'JJ'), (u'thing', 'NN')]
# [(u'the', 'DT'), (u'surface', 'NN')]
# [(u'a', 'DT'), (u'river', 'NN')]
# [(u'a', 'DT'), (u'thing', 'NN')]
# [(u'a', 'DT'), (u'juggler', 'NN')]
# [(u'a', 'DT'), (u'thing', 'NN')]
# [(u'a', 'DT'), (u'goblet', 'NN')]
# [(u'rare', 'JJ'), (u'red', 'JJ'), (u'wine', 'NN')]
# [(u'the', 'DT'), (u'master', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'toil', 'NN')]
# [(u'the', 'DT'), (u'memory', 'NN')]
# [(u'round', 'NN')]
# [(u'round', 'NN')]
# [(u'the', 'DT'), (u'other', 'JJ'), (u'way', 'NN')]
# [(u'hour', 'NN')]
# [(u'the', 'DT'), (u'darkness', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'the', 'DT'), (u'light', 'NN')]
# [(u'smoky', 'JJ'), (u'oil', 'NN')]
# [(u'tune', 'NN')]
# [(u'the', 'DT'), (u'end', 'NN')]
# [(u'every', 'DT'), (u'ten', 'NN')]
# [(u'a', 'DT'), (u'circumstance', 'NN')]
# [(u'scene', 'NN')]
# [(u'the', 'DT'), (u'fat', 'JJ'), (u'policeman', 'NN')]
# [(u'sleeping', 'NN')]
# [(u'place', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'desperation', 'NN')]
# [(u'the', 'DT'), (u'retreating', 'NN')]
# [(u'muse', 'NN')]
# [(u'All', 'DT'), (u'day', 'NN')]
# [(u'a', 'DT'), (u'state', 'NN')]
# [(u'wonderful', 'JJ'), (u'exaltation', 'NN')]
# [(u'soul', 'NN')]
# [(u'thou', 'JJ'), (u'art', 'NN')]
# [(u'fair', 'NN')]
# [(u'beer', 'NN')]
# [(u'music', 'NN')]
# [(u'motion', 'NN')]
# [(u'the', 'DT'), (u'chase', 'NN')]
# [(u'chariot', 'NN')]
# [(u'the', 'DT'), (u'track', 'NN')]
# [(u'the', 'DT'), (u'stupidity', 'NN')]
# [(u'Each', 'DT'), (u'time', 'NN')]
# [(u'a', 'DT'), (u'howl', 'NN')]
# [(u'fly', 'NN')]
# [(u'the', 'DT'), (u'floor', 'NN')]
# [(u'purple', 'NN')]
# [(u'incoherent', 'NN')]
# [(u'rage', 'NN')]
# [(u'the', 'DT'), (u'flesh', 'NN')]
# [(u'vain', 'NN')]
# [(u'the', 'DT'), (u'puffing', 'NN')]
# [(u'breathless', 'NN')]
# [(u'insist', 'NN')]
# [(u'vain', 'NN')]
# [(u'implore', 'NN')]
# [(u'Szalin', 'NN')]
# [(u'Palauk', 'NN')]
# [(u'isz', 'JJ'), (u'kelio', 'NN')]
# [(u'hell', 'NN')]
# [(u'sheer', 'NN')]
# [(u'terror', 'NN')]
# [(u'the', 'DT'), (u'orchestra', 'NN')]
# [(u'place', 'NN')]
# [(u'task', 'NN')]
# [(u'the', 'DT'), (u'burden', 'NN')]
# [(u'excitement', 'NN')]
# [(u'the', 'DT'), (u'soul', 'NN')]
# [(u'the', 'DT'), (u'ring', 'NN')]
# [(u'the', 'DT'), (u'shape', 'NN')]
# [(u'a', 'DT'), (u'pear', 'NN')]
# [(u'the', 'DT'), (u'stem', 'NN')]
# [(u'way', 'NN')]
# [(u'singing', 'NN')]
# [(u'volcano', 'NN')]
# [(u'energy', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'the', 'DT'), (u'night', 'NN')]
# [(u'air', 'NN')]
# [(u'chill', 'NN')]
# [(u'foot', 'NN')]
# [(u'the', 'DT'), (u'doorknob', 'NN')]
# [(u'slam', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'this', 'DT'), (u'procedure', 'NN')]
# [(u'the', 'DT'), (u'cause', 'NN')]
# [(u'a', 'DT'), (u'calamity', 'NN')]
# [(u'the', 'DT'), (u'hapless', 'NN')]
# [(u'victim', 'NN')]
# [(u'mouth', 'NN')]
# [(u'a', 'DT'), (u'bottle', 'NN')]
# [(u'liquid', 'NN')]
# [(u'pop', 'NN')]
# [(u'the', 'DT'), (u'doorway', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'the', 'DT'), (u'shriek', 'NN')]
# [(u'the', 'DT'), (u'dancing', 'NN')]
# [(u'a', 'DT'), (u'halt', 'NN')]
# [(u'horrid', 'JJ'), (u'murder', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'injury', 'NN')]
# [(u'a', 'DT'), (u'fly', 'NN')]
# [(u'bid', 'NN')]
# [(u'fair', 'NN')]
# [(u'a', 'DT'), (u'long', 'JJ'), (u'rest', 'NN')]
# [(u'the', 'DT'), (u'orchestra', 'NN')]
# [(u'plenty', 'NN')]
# [(u'peace', 'NN')]
# [(u'victim', 'NN')]
# [(u'the', 'DT'), (u'bar', 'NN')]
# [(u'beside', 'NN')]
# [(u'a', 'DT'), (u'foaming', 'JJ'), (u'schooner', 'NN')]
# [(u'beer', 'NN')]
# [(u'the', 'DT'), (u'meantime', 'NN')]
# [(u'another', 'DT'), (u'corner', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'an', 'DT'), (u'anxious', 'JJ'), (u'conference', 'NN')]
# [(u'the', 'DT'), (u'family', 'NN')]
# [(u'A', 'DT'), (u'trouble', 'NN')]
# [(u'The', 'DT'), (u'veselija', 'NN')]
# [(u'share', 'NN')]
# [(u'knew', 'NN')]
# [(u'share', 'NN')]
# [(u'the', 'DT'), (u'new', 'JJ'), (u'country', 'NN')]
# [(u'some', 'DT'), (u'subtle', 'JJ'), (u'poison', 'NN')]
# [(u'the', 'DT'), (u'air', 'NN')]
# [(u'crowds', 'NN')]
# [(u'a', 'DT'), (u'fine', 'JJ'), (u'dinner', 'NN')]
# [(u'the', 'DT'), (u'window', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'fun', 'NN')]
# [(u'face', 'NN')]
# [(u'the', 'DT'), (u'bar', 'NN')]
# [(u'the', 'DT'), (u'expense', 'NN')]
# [(u'the', 'DT'), (u'host', 'NN')]
# [(u'attention', 'NN')]
# [(u'the', 'DT'), (u'bride', 'NN')]
# [(u'meant', 'NN')]
# [(u'the', 'DT'), (u'family', 'NN')]
# [(u'dismay', 'NN')]
# [(u'an', 'DT'), (u'outlay', 'NN')]
# [(u'stood', 'NN')]
# [(u'terror', 'NN')]
# [(u'each', 'DT'), (u'item', 'NN')]
# [(u'gnawing', 'NN')]
# [(u'soul', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'rest', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'hall', 'NN')]
# [(u'a', 'DT'), (u'quarter', 'NN')]
# [(u'the', 'DT'), (u'church', 'NN')]
# [(u'a', 'DT'), (u'blessing', 'NN')]
# [(u'an', 'DT'), (u'end', 'NN')]
# [(u'the', 'DT'), (u'frightful', 'JJ'), (u'bill', 'NN')]
# [(u'the', 'DT'), (u'beer', 'NN')]
# [(u'liquor', 'NN')]
# [(u'advance', 'NN')]
# [(u'a', 'DT'), (u'guess', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'head', 'NN')]
# [(u'the', 'DT'), (u'dearest', 'NN')]
# [(u'a', 'DT'), (u'keg', 'NN')]
# [(u'beer', 'NN')]
# [(u'a', 'DT'), (u'certain', 'JJ'), (u'quality', 'NN')]
# [(u'a', 'DT'), (u'certain', 'JJ'), (u'price', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'some', 'DT'), (u'horrible', 'JJ'), (u'poison', 'NN')]
# [(u'nothing', 'NN')]
# [(u'a', 'DT'), (u'ruined', 'JJ'), (u'evening', 'NN')]
# [(u'while', 'NN')]
# [(u'law', 'NN')]
# [(u'The', 'DT'), (u'saloon-keeper', 'JJ'), (u'stood', 'NN')]
# [(u'the', 'DT'), (u'district', 'NN')]
# [(u'trouble', 'NN')]
# [(u'poor', 'JJ'), (u'old', 'JJ'), (u'ponas', 'NN')]
# [(u'instance', 'NN')]
# [(u'delicatessen', 'NN')]
# [(u'store', 'NN')]
# [(u'overdue', 'JJ'), (u'rent', 'NN')]
# [(u'old', 'JJ'), (u'poni', 'NN')]
# [(u'a', 'DT'), (u'widow', 'NN')]
# [(u'the', 'DT'), (u'rheumatism', 'NN')]
# [(u'the', 'DT'), (u'tradespeople', 'NN')]
# [(u'heart', 'NN')]
# [(u'the', 'DT'), (u'entire', 'JJ'), (u'profit', 'NN')]
# [(u'a', 'DT'), (u'little', 'JJ'), (u'place', 'NN')]
# [(u'All', 'DT'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'dump', 'NN')]
# [(u'food', 'NN')]
# [(u'the', 'DT'), (u'competition', 'NN')]
# [(u'mother', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'Money', 'NN')]
# [(u'the', 'DT'), (u'value', 'NN')]
# [(u'a', 'DT'), (u'feeling', 'NN')]
# [(u'something', 'NN')]
# [(u'nothing', 'NN')]
# [(u'a', 'DT'), (u'world', 'NN')]
# [(u'every', 'DT'), (u'hour', 'NN')]
# [(u'the', 'DT'), (u'day', 'NN')]
# [(u'an', 'DT'), (u'owl', 'NN')]
# [(u'night', 'NN')]
# [(u'a', 'DT'), (u'month', 'NN')]
# [(u'the', 'DT'), (u'frustrating', 'NN')]
# [(u'attempt', 'NN')]
# [(u'a', 'DT'), (u'score', 'NN')]
# [(u'a', 'DT'), (u'tribute', 'NN')]
# [(u'some', 'DT'), (u'money', 'NN')]
# [(u'house', 'NN')]
# [(u'round', 'NN')]
# [(u'the', 'DT'), (u'lamentation', 'NN')]
# [(u'the', 'DT'), (u'conversation', 'NN')]
# [(u'a', 'DT'), (u'thing', 'NN')]
# [(u'the', 'DT'), (u'patience', 'NN')]
# [(u'a', 'DT'), (u'saint', 'NN')]
# [(u'the', 'DT'), (u'story', 'NN')]
# [(u'silence', 'NN')]
# [(u'a', 'DT'), (u'gleam', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'doubtless', 'NN')]
# [(u'No', 'DT'), (u'bill', 'NN')]
# [(u'this', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'scandal', 'NN')]
# [(u'nothing', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'own', 'JJ'), (u'way', 'NN')]
# [(u'no', 'DT'), (u'use', 'NN')]
# [(u'look', 'NN')]
# [(u'side', 'NN')]
# [(u'the', 'DT'), (u'wide', 'JJ'), (u'look', 'NN')]
# [(u'terror', 'NN')]
# [(u'a', 'DT'), (u'low', 'JJ'), (u'voice', 'NN')]
# [(u'all', 'DT'), (u'somehow', 'NN')]
# [(u'harder', 'NN')]
# [(u'the', 'DT'), (u'solution', 'NN')]
# [(u'harder', 'NN')]
# [(u'official', 'NN')]
# [(u'passport', 'NN')]
# [(u'a', 'DT'), (u'third', 'NN')]
# [(u'the', 'DT'), (u'smooth-spoken', 'JJ'), (u'agent', 'NN')]
# [(u'hand', 'NN')]
# [(u'place', 'NN')]
# [(u'spite', 'NN')]
# [(u'a', 'DT'), (u'third', 'JJ'), (u'time', 'NN')]
# [(u'a', 'DT'), (u'deep', 'JJ'), (u'breath', 'NN')]
# [(u'a', 'DT'), (u'husband', 'NN')]
# [(u'a', 'DT'), (u'grown', 'JJ'), (u'woman', 'NN')]
# [(u'a', 'DT'), (u'husband', 'NN')]
# [(u'The', 'DT'), (u'last', 'JJ'), (u'sob', 'NN')]
# [(u'the', 'DT'), (u'orchestra', 'NN')]
# [(u'duty', 'NN')]
# [(u'The', 'DT'), (u'ceremony', 'NN')]
# [(u'the', 'DT'), (u'collection', 'NN')]
# [(u'begin', 'NN')]
# [(u'midnight', 'NN')]
# [(u'the', 'DT'), (u'stage', 'NN')]
# [(u'exhilaration', 'NN')]
# [(u'monotonous', 'JJ'), (u'measure', 'NN')]
# [(u'round', 'NN')]
# [(u'round', 'NN')]
# [(u'hour', 'NN')]
# [(u'hour', 'NN')]
# [(u'vacancy', 'NN')]
# [(u'stupor', 'NN')]
# [(u'an', 'DT'), (u'hour', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'everything', 'NN')]
# [(u'each', 'DT'), (u'group', 'NN')]
# [(u'own', 'JJ'), (u'song', 'NN')]
# [(u'time', 'NN')]
# [(u'a', 'DT'), (u'variety', 'NN')]
# [(u'drunkenness', 'NN')]
# [(u'Some', 'DT'), (u'stagger', 'NN')]
# [(u'maudlin', 'NN')]
# [(u'pretext', 'NN')]
# [(u'the', 'DT'), (u'fat', 'JJ'), (u'policeman', 'NN')]
# [(u'club', 'NN')]
# [(u'business', 'NN')]
# [(u'hand', 'NN')]
# [(u'a', 'DT'), (u'forest', 'NN')]
# [(u'fire', 'NN')]
# [(u'the', 'DT'), (u'station', 'NN')]
# [(u'The', 'DT'), (u'thing', 'NN')]
# [(u'head', 'NN')]
# [(u'scant', 'JJ'), (u'account', 'NN')]
# [(u'back', 'NN')]
# [(u'all', 'DT'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'habit', 'NN')]
# [(u'practice', 'NN')]
# [(u'a', 'DT'), (u'cause', 'NN')]
# [(u'congratulation', 'NN')]
# [(u'necessary', 'JJ'), (u'work', 'NN')]
# [(u'head-cracking', 'NN')]
# [(u'the', 'DT'), (u'whole', 'NN')]
# [(u'the', 'DT'), (u'cultured', 'JJ'), (u'world', 'NN')]
# [(u'no', 'DT'), (u'fight', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'policeman', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'deal', 'NN')]
# [(u'an', 'DT'), (u'occasion', 'NN')]
# [(u'steady', 'JJ'), (u'man', 'NN')]
# [(u'temper', 'NN')]
# [(u'a', 'DT'), (u'tight', 'JJ'), (u'shave', 'NN')]
# [(u'the', 'DT'), (u'fault', 'NN')]
# [(u'the', 'DT'), (u'altar', 'NN')]
# [(u'the', 'DT'), (u'corner', 'NN')]
# [(u'the', 'DT'), (u'deity', 'NN')]
# [(u'the', 'DT'), (u'true', 'JJ'), (u'home', 'NN')]
# [(u'any', 'DT'), (u'rate', 'NN')]
# [(u'substitute', 'NN')]
# [(u'earth', 'NN')]
# [(u'drunk', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'warpath', 'NN')]
# [(u'the', 'DT'), (u'preliminary', 'NN')]
# [(u'a', 'DT'), (u'good', 'JJ'), (u'cursing', 'NN')]
# [(u'the', 'DT'), (u'coat', 'NN')]
# [(u'the', 'DT'), (u'policeman', 'NN')]
# [(u'the', 'DT'), (u'place', 'NN')]
# [(u'the', 'DT'), (u'music', 'NN')]
# [(u'a', 'DT'), (u'minute', 'NN')]
# [(u'the', 'DT'), (u'merciless', 'NN')]
# [(u'tune', 'NN')]
# [(u'the', 'DT'), (u'tune', 'NN')]
# [(u'the', 'DT'), (u'last', 'JJ'), (u'half-hour', 'NN')]
# [(u'single', 'JJ'), (u'change', 'NN')]
# [(u'an', 'DT'), (u'American', 'JJ'), (u'tune', 'NN')]
# [(u'this', 'DT'), (u'time', 'NN')]
# [(u'any', 'DT'), (u'rate', 'NN')]
# [(u'the', 'DT'), (u'first', 'JJ'), (u'line', 'NN')]
# [(u'rest', 'NN')]
# [(u'the', 'DT'), (u'good', 'JJ'), (u'old', 'JJ'), (u'summertime', 'NN')]
# [(u'the', 'DT'), (u'good', 'JJ'), (u'old', 'JJ'), (u'summertime', 'NN')]
# [(u'the', 'DT'), (u'good', 'JJ'), (u'old', 'JJ'), (u'summertime', 'NN')]
# [(u'the', 'DT'), (u'good', 'JJ'), (u'old', 'JJ'), (u'summertime', 'NN')]
# [(u'something', 'NN')]
# [(u'dominant', 'NN')]
# [(u'a', 'DT'), (u'stupor', 'NN')]
# [(u'No', 'DT'), (u'one', 'NN')]
# [(u'oclock', 'NN')]
# [(u'the', 'DT'), (u'morning', 'NN')]
# [(u'joy', 'NN')]
# [(u'strength', 'NN')]
# [(u'the', 'DT'), (u'strength', 'NN')]
# [(u'unlimited', 'JJ'), (u'drink', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'the', 'DT'), (u'power', 'NN')]
# [(u'oclock', 'NN')]
# [(u'morning', 'NN')]
# [(u'working', 'NN')]
# [(u'a', 'DT'), (u'minute', 'NN')]
# [(u'pay', 'NN')]
# [(u'brass', 'NN')]
# [(u'check', 'NN')]
# [(u'the', 'DT'), (u'wall', 'NN')]
# [(u'the', 'DT'), (u'hungry', 'JJ'), (u'mob', 'NN')]
# [(u'every', 'DT'), (u'morning', 'NN')]
# [(u'the', 'DT'), (u'packing', 'NN')]
# [(u'oclock', 'NN')]
# [(u'no', 'DT'), (u'exception', 'NN')]
# [(u'this', 'DT'), (u'rule', 'NN')]
# [(u'a', 'DT'), (u'holiday', 'NN')]
# [(u'the', 'DT'), (u'day', 'NN')]
# [(u'wedding', 'NN')]
# [(u'day', 'NN')]
# [(u'a', 'DT'), (u'holiday', 'NN')]
# [(u'pay', 'NN')]
# [(u'no', 'DT'), (u'occasion', 'NN')]
# [(u'half', 'NN')]
# [(u'a', 'DT'), (u'stupor', 'NN')]
# [(u'the', 'DT'), (u'heavy', 'JJ'), (u'scent', 'NN')]
# [(u'the', 'DT'), (u'room', 'NN')]
# [(u'a', 'DT'), (u'drop', 'NN')]
# [(u'alcohol', 'NN')]
# [(u'oil', 'NN')]
# [(u'the', 'DT'), (u'floor', 'NN')]
# [(u'gazes', 'NN')]
# [(u'hungrily', 'NN')]
# [(u'shyness', 'NN')]
# [(u'the', 'DT'), (u'crowd', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'a', 'DT'), (u'carriage', 'NN')]
# [(u'shawl', 'NN')]
# [(u'own', 'JJ'), (u'coat', 'NN')]
# [(u'the', 'DT'), (u'carriage', 'NN')]
# [(u'no', 'DT'), (u'farewell', 'NN')]
# [(u'asleep', 'NN')]
# [(u'sheer', 'NN')]
# [(u'exhaustion', 'NN')]
# [(u'husband', 'NN')]
# [(u'wife', 'NN')]
# [(u'the', 'DT'), (u'former', 'JJ'), (u'snoring', 'NN')]
# [(u'the', 'DT'), (u'silent', 'JJ'), (u'night', 'NN')]
# [(u'the', 'DT'), (u'east', 'NN')]
# [(u'a', 'DT'), (u'word', 'NN')]
# [(u'head', 'NN')]
# [(u'shoulder', 'NN')]
# [(u'a', 'DT'), (u'moan', 'NN')]
# [(u'home', 'NN')]
# [(u'hand', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'today', 'NN')]
# [(u'the', 'DT'), (u'stairs', 'NN')]
# [(u'arm', 'NN')]
# [(u'terror', 'NN')]
# [(u'money', 'NN')]
# [(u'harder', 'NN')]
# [(u'Chapter', 'NN')]
# [(u'work', 'NN')]
# [(u'flesh', 'JJ'), (u'creep', 'NN')]
# [(u'a', 'DT'), (u'giant', 'JJ'), (u'besides', 'NN')]
# [(u'much', 'JJ'), (u'health', 'NN')]
# [(u'back', 'NN')]
# [(u'a', 'DT'), (u'boy', 'NN')]
# [(u'a', 'DT'), (u'boy', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'sort', 'NN')]
# [(u'man', 'NN')]
# [(u'hold', 'NN')]
# [(u'the', 'DT'), (u'sort', 'NN')]
# [(u'a', 'DT'), (u'grievance', 'NN')]
# [(u'hold', 'NN')]
# [(u'a', 'DT'), (u'certain', 'JJ'), (u'place', 'NN')]
# [(u'the', 'DT'), (u'run', 'NN')]
# [(u'nothing', 'NN')]
# [(u'the', 'DT'), (u'moment', 'NN')]
# [(u'round', 'NN')]
# [(u'fidgeting', 'NN')]
# [(u'the', 'DT'), (u'overflow', 'NN')]
# [(u'energy', 'NN')]
# [(u'a', 'DT'), (u'line', 'NN')]
# [(u'the', 'DT'), (u'line', 'NN')]
# [(u'impatience', 'NN')]
# [(u'restlessness', 'NN')]
# [(u'important', 'JJ'), (u'occasion', 'NN')]
# [(u'an', 'DT'), (u'hour', 'NN')]
# [(u'the', 'DT'), (u'second', 'JJ'), (u'day', 'NN')]
# [(u'arrival', 'NN')]
# [(u'laugh', 'NN')]
# [(u'vain', 'NN')]
# [(u'that', 'DT'), (u'crowd', 'NN')]
# [(u'a', 'DT'), (u'month', 'NN')]
# [(u'sort', 'NN')]
# [(u'money', 'NN')]
# [(u'drinking', 'NN')]
# [(u'the', 'DT'), (u'air', 'NN')]
# [(u'the', 'DT'), (u'rolling', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'fact', 'NN')]
# [(u'a', 'DT'), (u'city', 'NN')]
# [(u'a', 'DT'), (u'fair-sized', 'JJ'), (u'town', 'NN')]
# [(u'fortune', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'right', 'NN')]
# [(u'father', 'NN')]
# [(u'legend', 'NN')]
# [(u'that', 'DT'), (u'part', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'tract', 'NN')]
# [(u'time', 'NN')]
# [(u'immemorial', 'NN')]
# [(u'preserve', 'NN')]
# [(u'the', 'DT'), (u'nobility', 'NN')]
# [(u'title', 'NN')]
# [(u'turn', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'cleared', 'JJ'), (u'land', 'NN')]
# [(u'the', 'DT'), (u'midst', 'NN')]
# [(u'a', 'DT'), (u'wilderness', 'NN')]
# [(u'son', 'NN')]
# [(u'sister', 'NN')]
# [(u'the', 'DT'), (u'army', 'NN')]
# [(u'that', 'DT'), (u'day', 'NN')]
# [(u'nothing', 'NN')]
# [(u'The', 'DT'), (u'sister', 'NN')]
# [(u'husband', 'NN')]
# [(u'the', 'DT'), (u'place', 'NN')]
# [(u'son', 'NN')]
# [(u'a', 'DT'), (u'year', 'NN')]
# [(u'a', 'DT'), (u'half', 'NN')]
# [(u'a', 'DT'), (u'horse', 'NN')]
# [(u'fair', 'NN')]
# [(u'home', 'NN')]
# [(u'a', 'DT'), (u'foolish', 'JJ'), (u'trap', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'word', 'NN')]
# [(u'the', 'DT'), (u'exchange', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'the', 'DT'), (u'face', 'NN')]
# [(u'embarrassment', 'NN')]
# [(u'terror', 'NN')]
# [(u'wife', 'NN')]
# [(u'the', 'DT'), (u'fair', 'NN')]
# [(u'a', 'DT'), (u'rock', 'NN')]
# [(u'the', 'DT'), (u'girl', 'NN')]
# [(u'a', 'DT'), (u'child', 'NN')]
# [(u'a', 'DT'), (u'rich', 'JJ'), (u'man', 'NN')]
# [(u'daughter', 'NN')]
# [(u'that', 'DT'), (u'way', 'NN')]
# [(u'home', 'NN')]
# [(u'a', 'DT'), (u'heavy', 'JJ'), (u'heart', 'NN')]
# [(u'spring', 'NN')]
# [(u'summer', 'NN')]
# [(u'the', 'DT'), (u'fall', 'NN')]
# [(u'the', 'DT'), (u'harvest', 'NN')]
# [(u'journey', 'NN')]
# [(u'an', 'DT'), (u'unexpected', 'JJ'), (u'state', 'NN')]
# [(u'father', 'NN')]
# [(u'estate', 'NN')]
# [(u'heart', 'NN')]
# [(u'the', 'DT'), (u'prize', 'NN')]
# [(u'reach', 'NN')]
# [(u'stepmother', 'NN')]
# [(u'brother', 'NN')]
# [(u'a', 'DT'), (u'dried-up', 'JJ'), (u'little', 'JJ'), (u'man', 'NN')]
# [(u'the', 'DT'), (u'farm', 'NN')]
# [(u'great', 'JJ'), (u'consequence', 'NN')]
# [(u'the', 'DT'), (u'farm', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'family', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'half', 'NN')]
# [(u'court', 'NN')]
# [(u'the', 'DT'), (u'judge', 'NN')]
# [(u'the', 'DT'), (u'balance', 'NN')]
# [(u'decision', 'NN')]
# [(u'Ona', 'NN')]
# [(u'a', 'DT'), (u'friend', 'NN')]
# [(u'part', 'NN')]
# [(u'doubtless', 'NN')]
# [(u'somehow', 'NN')]
# [(u'a', 'DT'), (u'country', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'forthwith', 'NN')]
# [(u'marry', 'NN')]
# [(u'a', 'DT'), (u'rich', 'JJ'), (u'man', 'NN')]
# [(u'the', 'DT'), (u'bargain', 'NN')]
# [(u'that', 'DT'), (u'country', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'the', 'DT'), (u'army', 'NN')]
# [(u'money', 'NN')]
# [(u'count', 'NN')]
# [(u'any', 'DT'), (u'other', 'JJ'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'place', 'NN')]
# [(u'the', 'DT'), (u'price', 'NN')]
# [(u'a', 'DT'), (u'passage', 'NN')]
# [(u'an', 'DT'), (u'end', 'NN')]
# [(u'the', 'DT'), (u'following', 'JJ'), (u'spring', 'NN')]
# [(u'a', 'DT'), (u'contractor', 'NN')]
# [(u'a', 'DT'), (u'certain', 'JJ'), (u'time', 'NN')]
# [(u'home', 'NN')]
# [(u'a', 'DT'), (u'gang', 'NN')]
# [(u'a', 'DT'), (u'railroad', 'NN')]
# [(u'a', 'DT'), (u'fearful', 'JJ'), (u'experience', 'NN')]
# [(u'filth', 'NN')]
# [(u'bad', 'JJ'), (u'food', 'NN')]
# [(u'cruelty', 'NN')]
# [(u'overwork', 'NN')]
# [(u'fine', 'JJ'), (u'trim', 'NN')]
# [(u'coat', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'rest', 'NN')]
# [(u'steady', 'JJ'), (u'man', 'NN')]
# [(u'temper', 'NN')]
# [(u'the', 'DT'), (u'offender', 'NN')]
# [(u'the', 'DT'), (u'company', 'NN')]
# [(u'home', 'NN')]
# [(u'eye', 'NN')]
# [(u'the', 'DT'), (u'summer', 'NN')]
# [(u'time', 'NN')]
# [(u'the', 'DT'), (u'last', 'JJ'), (u'moment', 'NN')]
# [(u'a', 'DT'), (u'cousin', 'NN')]
# [(u'an', 'DT'), (u'orphan', 'NN')]
# [(u'childhood', 'NN')]
# [(u'a', 'DT'), (u'rich', 'JJ'), (u'farmer', 'NN')]
# [(u'the', 'DT'), (u'age', 'NN')]
# [(u'twenty', 'NN')]
# [(u'strength', 'NN')]
# [(u'the', 'DT'), (u'man', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'a', 'DT'), (u'hard', 'JJ'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'passage', 'NN')]
# [(u'an', 'DT'), (u'agent', 'NN')]
# [(u'a', 'DT'), (u'scoundrel', 'NN')]
# [(u'a', 'DT'), (u'trap', 'NN')]
# [(u'a', 'DT'), (u'good', 'JJ'), (u'deal', 'NN')]
# [(u'precious', 'JJ'), (u'money', 'NN')]
# [(u'such', 'JJ'), (u'horrible', 'JJ'), (u'fear', 'NN')]
# [(u'course', 'NN')]
# [(u'nothing', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'blue', 'JJ'), (u'uniform', 'NN')]
# [(u'a', 'DT'), (u'hotel', 'NN')]
# [(u'The', 'DT'), (u'law', 'NN')]
# [(u'the', 'DT'), (u'rate', 'NN')]
# [(u'card', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'a', 'DT'), (u'hotel', 'NN')]
# [(u'friend', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'word', 'NN')]
# [(u'the', 'DT'), (u'city', 'NN')]
# [(u'ceremony', 'NN')]
# [(u'the', 'DT'), (u'vista', 'NN')]
# [(u'the', 'DT'), (u'distance', 'NN')]
# [(u'some', 'DT'), (u'direction', 'NN')]
# [(u'any', 'DT'), (u'attention', 'NN')]
# [(u'helplessness', 'NN')]
# [(u'deadly', 'JJ'), (u'terror', 'NN')]
# [(u'any', 'DT'), (u'sort', 'NN')]
# [(u'person', 'NN')]
# [(u'official', 'JJ'), (u'uniform', 'NN')]
# [(u'a', 'DT'), (u'policeman', 'NN')]
# [(u'the', 'DT'), (u'street', 'NN')]
# [(u'hurry', 'NN')]
# [(u'the', 'DT'), (u'whole', 'NN')]
# [(u'the', 'DT'), (u'first', 'JJ'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'midst', 'NN')]
# [(u'confusion', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'doorway', 'NN')]
# [(u'a', 'DT'), (u'house', 'NN')]
# [(u'a', 'DT'), (u'policeman', 'NN')]
# [(u'the', 'DT'), (u'station', 'NN')]
# [(u'the', 'DT'), (u'morning', 'NN')]
# [(u'an', 'DT'), (u'interpreter', 'NN')]
# [(u'a', 'DT'), (u'car', 'NN')]
# [(u'a', 'DT'), (u'new', 'JJ'), (u'word', 'NN')]
# [(u'delight', 'NN')]
# [(u'this', 'DT'), (u'adventure', 'NN')]
# [(u'another', 'DT'), (u'share', 'NN')]
# [(u'the', 'DT'), (u'window', 'NN')]
# [(u'a', 'DT'), (u'street', 'NN')]
# [(u'forever', 'NN')]
# [(u'mile', 'NN')]
# [(u'mile', 'NN')]
# [(u'thirty-four', 'NN')]
# [(u'each', 'DT'), (u'side', 'NN')]
# [(u'uninterrupted', 'JJ'), (u'row', 'NN')]
# [(u'wretched', 'JJ'), (u'little', 'JJ'), (u'two-story', 'JJ'), (u'frame', 'NN')]
# [(u'every', 'DT'), (u'side', 'NN')]
# [(u'street', 'NN')]
# [(u'a', 'DT'), (u'hill', 'NN')]
# [(u'a', 'DT'), (u'hollow', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'endless', 'JJ'), (u'vista', 'NN')]
# [(u'a', 'DT'), (u'bridge', 'NN')]
# [(u'a', 'DT'), (u'filthy', 'JJ'), (u'creek', 'NN')]
# [(u'hard-baked', 'JJ'), (u'mud', 'NN')]
# [(u'a', 'DT'), (u'railroad', 'NN')]
# [(u'crossing', 'NN')]
# [(u'a', 'DT'), (u'tangle', 'NN')]
# [(u'puffing', 'NN')]
# [(u'freight', 'NN')]
# [(u'a', 'DT'), (u'great', 'JJ'), (u'factory', 'NN')]
# [(u'a', 'DT'), (u'dingy', 'NN')]
# [(u'building', 'NN')]
# [(u'smoke', 'NN')]
# [(u'the', 'DT'), (u'air', 'NN')]
# [(u'the', 'DT'), (u'earth', 'NN')]
# [(u'beneath', 'NN')]
# [(u'the', 'DT'), (u'desolate', 'NN')]
# [(u'procession', 'NN')]
# [(u'the', 'DT'), (u'procession', 'NN')]
# [(u'A', 'DT'), (u'full', 'JJ'), (u'hour', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'the', 'DT'), (u'city', 'NN')]
# [(u'the', 'DT'), (u'perplexing', 'NN')]
# [(u'the', 'DT'), (u'atmosphere', 'NN')]
# [(u'darker', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'earth', 'NN')]
# [(u'the', 'DT'), (u'grass', 'NN')]
# [(u'Every', 'DT'), (u'minute', 'NN')]
# [(u'the', 'DT'), (u'train', 'NN')]
# [(u'yellow', 'NN')]
# [(u'the', 'DT'), (u'landscape', 'NN')]
# [(u'bare', 'NN')]
# [(u'smoke', 'NN')]
# [(u'another', 'DT'), (u'circumstance', 'NN')]
# [(u'a', 'DT'), (u'strange', 'NN')]
# [(u'pungent', 'JJ'), (u'odor', 'NN')]
# [(u'this', 'DT'), (u'odor', 'NN')]
# [(u'taste', 'NN')]
# [(u'the', 'DT'), (u'trolley', 'NN')]
# [(u'car', 'NN')]
# [(u'way', 'NN')]
# [(u'the', 'DT'), (u'home', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'something', 'NN')]
# [(u'faint', 'NN')]
# [(u'smell', 'NN')]
# [(u'hold', 'NN')]
# [(u'leisure', 'NN')]
# [(u'an', 'DT'), (u'elemental', 'JJ'), (u'odor', 'NN')]
# [(u'crude', 'NN')]
# [(u'rancid', 'NN')]
# [(u'an', 'DT'), (u'intoxicant', 'NN')]
# [(u'wonder', 'NN')]
# [(u'the', 'DT'), (u'car', 'NN')]
# [(u'a', 'DT'), (u'halt', 'NN')]
# [(u'the', 'DT'), (u'door', 'NN')]
# [(u'a', 'DT'), (u'voice', 'NN')]
# [(u'the', 'DT'), (u'corner', 'NN')]
# [(u'a', 'DT'), (u'side', 'JJ'), (u'street', 'NN')]
# [(u'brick', 'NN')]
# [(u'a', 'DT'), (u'vista', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'chimneys', 'NN')]
# [(u'tall', 'NN')]
# [(u'the', 'DT'), (u'tallest', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'columns', 'NN')]
# [(u'smoke', 'NN')]
# [(u'thick', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'center', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'this', 'DT'), (u'smoke', 'NN')]
# [(u'a', 'DT'), (u'perpetual', 'JJ'), (u'explosion', 'NN')]
# ...
# [(u'energy', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'business', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'handling', 'NN')]
# [(u'rehandling', 'NN')]
# [(u'the', 'DT'), (u'accounting', 'NN')]
# [(u'reaccounting', 'NN')]
# [(u'the', 'DT'), (u'planning', 'NN')]
# [(u'worrying', 'NN')]
# [(u'the', 'DT'), (u'balancing', 'NN')]
# [(u'petty', 'JJ'), (u'profit', 'NN')]
# [(u'loss', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'machinery', 'NN')]
# [(u'the', 'DT'), (u'civil', 'JJ'), (u'law', 'NN')]
# [(u'the', 'DT'), (u'pettifogging', 'NN')]
# [(u'chicanery', 'NN')]
# [(u'the', 'DT'), (u'blind', 'NN')]
# [(u'haphazard', 'JJ'), (u'production', 'NN')]
# [(u'storage', 'NN')]
# [(u'the', 'DT'), (u'stock', 'NN')]
# [(u'manipulator', 'NN')]
# [(u'the', 'DT'), (u'paralyzing', 'NN')]
# [(u'the', 'DT'), (u'overstimulation', 'NN')]
# [(u'bank', 'NN')]
# [(u'drummer', 'NN')]
# [(u'solicitor', 'NN')]
# [(u'bill-poster', 'NN')]
# [(u'advertising', 'NN')]
# [(u'agent', 'NN')]
# [(u'competition', 'NN')]
# [(u'monopoly', 'JJ'), (u'railroad', 'NN')]
# [(u'the', 'DT'), (u'bad', 'JJ'), (u'air', 'NN')]
# [(u'the', 'DT'), (u'disease', 'NN')]
# [(u'the', 'DT'), (u'waste', 'NN')]
# [(u'the', 'DT'), (u'office', 'NN')]
# [(u'the', 'DT'), (u'waste', 'NN')]
# [(u'time', 'NN')]
# [(u'material', 'NN')]
# [(u'the', 'DT'), (u'piling', 'NN')]
# [(u'story', 'NN')]
# [(u'story', 'NN')]
# [(u'the', 'DT'), (u'burrowing', 'NN')]
# [(u'underground', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'business', 'NN')]
# [(u'insurance', 'NN')]
# [(u'the', 'DT'), (u'enormous', 'JJ'), (u'mass', 'NN')]
# [(u'clerical', 'JJ'), (u'labor', 'NN')]
# [(u'all', 'DT'), (u'utter', 'JJ'), (u'waste', 'NN')]
# [(u'the', 'DT'), (u'editor', 'NN')]
# [(u'a', 'DT'), (u'universal', 'JJ'), (u'automatic', 'JJ'), (u'insurance', 'NN')]
# [(u'company', 'NN')]
# [(u'bank', 'NN')]
# [(u'Capital', 'NN')]
# [(u'the', 'DT'), (u'property', 'NN')]
# [(u'injury', 'NN')]
# [(u'The', 'DT'), (u'bank', 'NN')]
# [(u'the', 'DT'), (u'universal', 'JJ'), (u'government', 'NN')]
# [(u'credit-account', 'NN')]
# [(u'the', 'DT'), (u'ledger', 'NN')]
# [(u'a', 'DT'), (u'universal', 'JJ'), (u'government', 'NN')]
# [(u'bulletin', 'NN')]
# [(u'everything', 'NN')]
# [(u'the', 'DT'), (u'commonwealth', 'NN')]
# [(u'sale', 'NN')]
# [(u'no', 'DT'), (u'one', 'NN')]
# [(u'any', 'DT'), (u'profit', 'NN')]
# [(u'the', 'DT'), (u'sale', 'NN')]
# [(u'any', 'DT'), (u'stimulus', 'NN')]
# [(u'no', 'DT'), (u'misrepresentation', 'NN')]
# [(u'no', 'DT'), (u'cheating', 'NN')]
# [(u'no', 'DT'), (u'adulteration', 'NN')]
# [(u'imitation', 'NN')]
# [(u'no', 'DT'), (u'bribery', 'NN')]
# [(u'grafting', 'NN')]
# [(u'the', 'DT'), (u'price', 'NN')]
# [(u'an', 'DT'), (u'article', 'NN')]
# [(u'The', 'DT'), (u'price', 'NN')]
# [(u'the', 'DT'), (u'labor', 'NN')]
# [(u'the', 'DT'), (u'total', 'JJ'), (u'product', 'NN')]
# [(u'the', 'DT'), (u'labor', 'NN')]
# [(u'the', 'DT'), (u'value', 'NN')]
# [(u'a', 'DT'), (u'bushel', 'NN')]
# [(u'wheat', 'NN')]
# [(u'the', 'DT'), (u'tenth', 'JJ'), (u'part', 'NN')]
# [(u'a', 'DT'), (u'farm', 'NN')]
# [(u'labor-day', 'NN')]
# [(u'an', 'DT'), (u'arbitrary', 'JJ'), (u'symbol', 'NN')]
# [(u'pay', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'farm', 'NN')]
# [(u'work', 'NN')]
# [(u'the', 'DT'), (u'cost', 'NN')]
# [(u'a', 'DT'), (u'bushel', 'NN')]
# [(u'wheat', 'NN')]
# [(u'farm', 'NN')]
# [(u'work', 'NN')]
# [(u'labor', 'NN')]
# [(u'some', 'DT'), (u'work', 'NN')]
# [(u'rural', 'JJ'), (u'mail', 'NN')]
# [(u'no', 'DT'), (u'coal', 'NN')]
# [(u'course', 'NN')]
# [(u'number', 'NN')]
# [(u'any', 'DT'), (u'particular', 'JJ'), (u'industry', 'NN')]
# [(u'the', 'DT'), (u'transfer', 'NN')]
# [(u'a', 'DT'), (u'universal', 'JJ'), (u'government', 'NN')]
# [(u'bulletin', 'NN')]
# [(u'time', 'NN')]
# [(u'the', 'DT'), (u'labor', 'NN')]
# [(u'cost', 'NN')]
# [(u'a', 'DT'), (u'book', 'NN')]
# [(u'the', 'DT'), (u'labor', 'NN')]
# [(u'cost', 'NN')]
# [(u'the', 'DT'), (u'paper', 'NN')]
# [(u'printing', 'NN')]
# [(u'binding', 'NN')]
# [(u'a', 'DT'), (u'fifth', 'NN')]
# [(u'present', 'JJ'), (u'cost', 'NN')]
# [(u'the', 'DT'), (u'author', 'NN')]
# [(u'the', 'DT'), (u'state', 'NN')]
# [(u'intellectual', 'JJ'), (u'production', 'NN')]
# [(u'The', 'DT'), (u'state', 'NN')]
# [(u'a', 'DT'), (u'year', 'NN')]
# [(u'the', 'DT'), (u'book', 'NN')]
# [(u'the', 'DT'), (u'author', 'NN')]
# [(u'thirty', 'NN')]
# [(u'every', 'DT'), (u'bon', 'NN')]
# [(u'mot', 'NN')]
# [(u'cost', 'NN')]
# [(u'a', 'DT'), (u'purse', 'NN')]
# [(u'gold', 'NN')]
# [(u'system', 'NN')]
# [(u'the', 'DT'), (u'providing', 'NN')]
# [(u'the', 'DT'), (u'material', 'NN')]
# [(u'a', 'DT'), (u'man', 'NN')]
# [(u'own', 'JJ'), (u'taste', 'NN')]
# [(u'own', 'JJ'), (u'way', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'earth', 'NN')]
# [(u'the', 'DT'), (u'majority', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'kind', 'NN')]
# [(u'sleep', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'kind', 'NN')]
# [(u'bed', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'kind', 'NN')]
# [(u'the', 'DT'), (u'majority', 'NN')]
# [(u'free', 'JJ'), (u'effort', 'NN')]
# [(u'present', 'NN')]
# [(u'a', 'DT'), (u'certain', 'JJ'), (u'preacher', 'NN')]
# [(u'a', 'DT'), (u'church', 'NN')]
# [(u'the', 'DT'), (u'preacher', 'NN')]
# [(u'nothing', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'way', 'NN')]
# [(u'nothing', 'NN')]
# [(u'the', 'DT'), (u'other', 'JJ'), (u'hand', 'NN')]
# [(u'wage', 'NN')]
# [(u'slavery', 'NN')]
# [(u'some', 'DT'), (u'spare', 'JJ'), (u'money', 'NN')]
# [(u'tribute', 'NN')]
# [(u'capitalist', 'NN')]
# [(u'a', 'DT'), (u'magazine', 'NN')]
# [(u'the', 'DT'), (u'purpose', 'NN')]
# [(u'the', 'DT'), (u'gospel', 'NN')]
# [(u'the', 'DT'), (u'prophet', 'NN')]
# [(u'the', 'DT'), (u'inventor', 'NN')]
# [(u'the', 'DT'), (u'noble', 'JJ'), (u'science', 'NN')]
# [(u'clean', 'JJ'), (u'eating', 'NN')]
# [(u'the', 'DT'), (u'discouraging', 'NN')]
# [(u'the', 'DT'), (u'scientific', 'JJ'), (u'breeding', 'NN')]
# [(u'the', 'DT'), (u'establishing', 'NN')]
# [(u'divorce', 'NN')]
# [(u'mutual', 'JJ'), (u'consent', 'NN')]
# [(u'a', 'DT'), (u'moment', 'NN')]
# [(u'a', 'DT'), (u'lecture', 'NN')]
# [(u'a', 'DT'), (u'laugh', 'NN')]
# [(u'competition', 'NN')]
# [(u'co-operation', 'NN')]
# [(u'a', 'DT'), (u'family', 'NN')]
# [(u'this', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'domestic', 'JJ'), (u'drudge', 'NN')]
# [(u'the', 'DT'), (u'wife', 'NN')]
# [(u'a', 'DT'), (u'wage', 'NN')]
# [(u'slave', 'NN')]
# [(u'the', 'DT'), (u'modern', 'JJ'), (u'system', 'NN')]
# [(u'pneumatic', 'JJ'), (u'house-cleaning', 'NN')]
# [(u'co-operative', 'JJ'), (u'cooking', 'NN')]
# [(u'single', 'JJ'), (u'item', 'NN')]
# [(u'the', 'DT'), (u'washing', 'NN')]
# [(u'the', 'DT'), (u'dish-washing', 'NN')]
# [(u'a', 'DT'), (u'family', 'NN')]
# [(u'an', 'DT'), (u'hour', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'work', 'NN')]
# [(u'the', 'DT'), (u'dish-washing', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'note', 'NN')]
# [(u'deadening', 'NN')]
# [(u'brutalizing', 'NN')]
# [(u'work', 'NN')]
# [(u'a', 'DT'), (u'cause', 'NN')]
# [(u'anemia', 'NN')]
# [(u'nervousness', 'NN')]
# [(u'prostitution', 'NN')]
# [(u'suicide', 'NN')]
# [(u'insanity', 'NN')]
# [(u'drunken', 'NN')]
# [(u'the', 'DT'), (u'community', 'NN')]
# [(u'a', 'DT'), (u'machine', 'NN')]
# [(u'the', 'DT'), (u'eye', 'NN')]
# [(u'the', 'DT'), (u'touch', 'NN')]
# [(u'a', 'DT'), (u'saving', 'NN')]
# [(u'the', 'DT'), (u'drudgery', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'new', 'JJ'), (u'science', 'NN')]
# [(u'agriculture', 'NN')]
# [(u'intensive', 'JJ'), (u'culture', 'NN')]
# [(u'a', 'DT'), (u'gardener', 'NN')]
# [(u'a', 'DT'), (u'season', 'NN')]
# [(u'a', 'DT'), (u'single', 'JJ'), (u'acre', 'NN')]
# [(u'the', 'DT'), (u'population', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'globe', 'NN')]
# [(u'the', 'DT'), (u'soil', 'NN')]
# [(u'the', 'DT'), (u'ignorance', 'NN')]
# [(u'poverty', 'NN')]
# [(u'scattered', 'JJ'), (u'farming', 'JJ'), (u'population', 'NN')]
# [(u'the', 'DT'), (u'problem', 'NN')]
# [(u'the', 'DT'), (u'food', 'NN')]
# [(u'supply', 'NN')]
# [(u'nation', 'NN')]
# [(u'hand', 'NN')]
# [(u'rocky', 'JJ'), (u'land', 'NN')]
# [(u'a', 'DT'), (u'national', 'JJ'), (u'timber', 'NN')]
# [(u'reserve', 'NN')]
# [(u'hunt', 'NN')]
# [(u'favorable', 'JJ'), (u'climate', 'NN')]
# [(u'soil', 'NN')]
# [(u'each', 'DT'), (u'product', 'NN')]
# [(u'the', 'DT'), (u'community', 'NN')]
# [(u'the', 'DT'), (u'acreage', 'NN')]
# [(u'improved', 'JJ'), (u'machinery', 'NN')]
# [(u'the', 'DT'), (u'direction', 'NN')]
# [(u'a', 'DT'), (u'farm', 'NN')]
# [(u'the', 'DT'), (u'awful', 'JJ'), (u'deadliness', 'NN')]
# [(u'farm', 'NN')]
# [(u'work', 'NN')]
# [(u'the', 'DT'), (u'revolution', 'NN')]
# [(u'the', 'DT'), (u'great', 'JJ'), (u'potato-planting', 'JJ'), (u'machine', 'NN')]
# [(u'an', 'DT'), (u'electric', 'JJ'), (u'motor', 'NN')]
# [(u'the', 'DT'), (u'furrow', 'NN')]
# [(u'a', 'DT'), (u'score', 'NN')]
# [(u'a', 'DT'), (u'day', 'NN')]
# [(u'the', 'DT'), (u'great', 'JJ'), (u'potato-digging', 'JJ'), (u'machine', 'NN')]
# [(u'electricity', 'NN')]
# [(u'a', 'DT'), (u'thousand-acre', 'JJ'), (u'field', 'NN')]
# [(u'earth', 'NN')]
# [(u'the', 'DT'), (u'latter', 'NN')]
# [(u'every', 'DT'), (u'other', 'JJ'), (u'kind', 'NN')]
# [(u'fruit', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'way', 'NN')]
# [(u'machinery', 'NN')]
# [(u'electricity', 'NN')]
# [(u'the', 'DT'), (u'future', 'NN')]
# [(u'a', 'DT'), (u'summer', 'NN')]
# [(u'holiday', 'NN')]
# [(u'needful', 'JJ'), (u'number', 'NN')]
# [(u'each', 'DT'), (u'place', 'NN')]
# [(u'system', 'NN')]
# [(u'independent', 'JJ'), (u'small', 'JJ'), (u'farming', 'NN')]
# [(u'ignorant', 'JJ'), (u'man', 'NN')]
# [(u'a', 'DT'), (u'yellow', 'NN')]
# [(u'sad-eyed', 'JJ'), (u'drudge', 'NN')]
# [(u'oclock', 'NN')]
# [(u'the', 'DT'), (u'morning', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'soil', 'NN')]
# [(u'all', 'DT'), (u'knowledge', 'NN')]
# [(u'hope', 'NN')]
# [(u'science', 'NN')]
# [(u'invention', 'NN')]
# [(u'the', 'DT'), (u'joys', 'NN')]
# [(u'the', 'DT'), (u'spirit', 'NN')]
# [(u'a', 'DT'), (u'bare', 'NN')]
# [(u'existence', 'NN')]
# [(u'competition', 'NN')]
# [(u'labor', 'NN')]
# [(u'boasting', 'NN')]
# [(u'freedom', 'NN')]
# [(u'a', 'DT'), (u'moment', 'NN')]
# [(u'place', 'NN')]
# [(u'beside', 'NN')]
# [(u'this', 'DT'), (u'fact', 'NN')]
# [(u'an', 'DT'), (u'unlimited', 'JJ'), (u'food', 'NN')]
# [(u'supply', 'NN')]
# [(u'discovery', 'NN')]
# [(u'the', 'DT'), (u'human', 'JJ'), (u'system', 'NN')]
# [(u'meat', 'NN')]
# [(u'a', 'DT'), (u'food', 'NN')]
# [(u'meat', 'NN')]
# [(u'vegetable', 'JJ'), (u'food', 'NN')]
# [(u'the', 'DT'), (u'palate', 'NN')]
# [(u'the', 'DT'), (u'girl-student', 'NN')]
# [(u'the', 'DT'), (u'first', 'JJ'), (u'time', 'NN')]
# [(u'wage', 'NN')]
# [(u'slavery', 'NN')]
# [(u'a', 'DT'), (u'task', 'NN')]
# [(u'labor', 'NN')]
# [(u'the', 'DT'), (u'price', 'NN')]
# [(u'such', 'JJ'), (u'work', 'NN')]
# [(u'dingy', 'NN')]
# [(u'stoking', 'JJ'), (u'machinery', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'way', 'NN')]
# [(u'become', 'NN')]
# [(u'year', 'NN')]
# [(u'year', 'NN')]
# [(u'the', 'DT'), (u'cost', 'NN')]
# [(u'slaughterhouse', 'NN')]
# [(u'meat', 'NN')]
# [(u'own', 'JJ'), (u'killing', 'NN')]
# [(u'the', 'DT'), (u'custom', 'NN')]
# [(u'another', 'DT'), (u'item', 'NN')]
# [(u'capitalism', 'NN')]
# [(u'a', 'DT'), (u'democracy', 'NN')]
# [(u'political', 'JJ'), (u'corruption', 'NN')]
# [(u'civic', 'JJ'), (u'administration', 'NN')]
# [(u'population', 'NN')]
# [(u'science', 'NN')]
# [(u'the', 'DT'), (u'majority', 'NN')]
# [(u'wealth', 'NN')]
# [(u'misery', 'NN')]
# [(u'life', 'NN')]
# [(u'the', 'DT'), (u'world', 'NN')]
# [(u'course', 'NN')]
# [(u'contagion', 'NN')]
# [(u'happiness', 'NN')]
# [(u'this', 'DT'), (u'reason', 'NN')]
# [(u'science', 'NN')]
# [(u'the', 'DT'), (u'future', 'NN')]
# [(u'importance', 'NN')]
# [(u'the', 'DT'), (u'application', 'NN')]
# [(u'the', 'DT'), (u'knowledge', 'NN')]
# [(u'the', 'DT'), (u'earth', 'NN')]
# [(u'right', 'NN')]
# [(u'a', 'DT'), (u'human', 'JJ'), (u'existence', 'NN')]
# [(u'silence', 'NN')]
# [(u'the', 'DT'), (u'beautiful', 'JJ'), (u'young', 'JJ'), (u'girl', 'NN')]
# [(u'something', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'look', 'NN')]
# [(u'the', 'DT'), (u'time', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'the', 'DT'), (u'group', 'NN')]
# [(u'a', 'DT'), (u'low', 'JJ'), (u'voice', 'NN')]
# [(u'a', 'DT'), (u'knave', 'NN')]
# [(u'election', 'NN')]
# [(u'day', 'NN')]
# [(u'the', 'DT'), (u'long', 'JJ'), (u'campaign', 'NN')]
# [(u'the', 'DT'), (u'whole', 'JJ'), (u'country', 'NN')]
# [(u'breath', 'NN')]
# [(u'the', 'DT'), (u'issue', 'NN')]
# [(u'the', 'DT'), (u'rest', 'NN')]
# [(u'the', 'DT'), (u'staff', 'NN')]
# [(u'dinner', 'NN')]
# [(u'the', 'DT'), (u'big', 'JJ'), (u'hall', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'that', 'DT'), (u'evening', 'NN')]
# [(u'the', 'DT'), (u'telegraph', 'NN')]
# [(u'instrument', 'NN')]
# [(u'the', 'DT'), (u'stage', 'NN')]
# [(u'vote', 'NN')]
# [(u'an', 'DT'), (u'increase', 'NN')]
# [(u'something', 'NN')]
# [(u'cent', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'reporting', 'NN')]
# [(u'night', 'NN')]
# [(u'the', 'DT'), (u'hall', 'NN')]
# [(u'the', 'DT'), (u'vote', 'NN')]
# [(u'thousand', 'NN')]
# [(u'an', 'DT'), (u'incredible', 'JJ'), (u'increase', 'NN')]
# [(u'the', 'DT'), (u'state', 'NN')]
# [(u'the', 'DT'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'city', 'NN')]
# [(u'the', 'DT'), (u'evening', 'NN')]
# [(u'waxed', 'NN')]
# [(u'the', 'DT'), (u'crowd', 'NN')]
# [(u'the', 'DT'), (u'meeting', 'NN')]
# [(u'a', 'DT'), (u'sight', 'NN')]
# [(u'a', 'DT'), (u'speech', 'NN')]
# [(u'shouting', 'NN')]
# [(u'a', 'DT'), (u'brief', 'JJ'), (u'silence', 'NN')]
# [(u'the', 'DT'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'national', 'JJ'), (u'office', 'NN')]
# [(u'a', 'DT'), (u'single', 'JJ'), (u'year', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'kind', 'NN')]
# [(u'a', 'DT'), (u'dozen', 'NN')]
# [(u'a', 'DT'), (u'single', 'JJ'), (u'batch', 'NN')]
# [(u'the', 'DT'), (u'audience', 'NN')]
# [(u'the', 'DT'), (u'vote', 'NN')]
# [(u'Quincy', 'NN')]
# [(u'the', 'DT'), (u'mayor', 'NN')]
# [(u'a', 'DT'), (u'Socialist', 'JJ'), (u'speaker', 'NN')]
# [(u'the', 'DT'), (u'home', 'NN')]
# [(u'the', 'DT'), (u'answer', 'NN')]
# [(u'labor', 'NN')]
# [(u'Movement', 'NN')]
# [(u'the', 'DT'), (u'city', 'NN')]
# [(u'a', 'DT'), (u'factory', 'JJ'), (u'district', 'NN')]
# [(u'no', 'DT'), (u'particular', 'JJ'), (u'difference', 'NN')]
# [(u'the', 'DT'), (u'increase', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'the', 'DT'), (u'tremendous', 'JJ'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'city', 'NN')]
# [(u'the', 'DT'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'spring', 'NN')]
# [(u'the', 'DT'), (u'fall', 'NN')]
# [(u'the', 'DT'), (u'same', 'JJ'), (u'year', 'NN')]
# [(u'year', 'NN')]
# [(u'the', 'DT'), (u'Democratic', 'JJ'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'Democratic', 'JJ'), (u'vote', 'NN')]
# [(u'the', 'DT'), (u'state', 'NN')]
# [(u'legislature', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'a', 'DT'), (u'new', 'JJ'), (u'standard', 'NN')]
# [(u'the', 'DT'), (u'party', 'NN')]
# [(u'the', 'DT'), (u'way', 'NN')]
# [(u'an', 'DT'), (u'orator', 'NN')]
# [(u'the', 'DT'), (u'platform', 'NN')]
# [(u'thousand', 'NN')]
# [(u'every', 'DT'), (u'sentence', 'NN')]
# [(u'The', 'DT'), (u'orator', 'NN')]
# [(u'the', 'DT'), (u'head', 'NN')]
# [(u'the', 'DT'), (u'citys', 'NN')]
# [(u'relief', 'NN')]
# [(u'bureau', 'NN')]
# [(u'the', 'DT'), (u'sight', 'NN')]
# [(u'misery', 'NN')]
# [(u'corruption', 'NN')]
# [(u'fire', 'NN')]
# [(u'the', 'DT'), (u'crowd', 'NN')]
# [(u'spirit', 'NN')]
# [(u'the', 'DT'), (u'revolution', 'NN')]
# [(u'Organize', 'NN')]
# [(u'Organize', 'NN')]
# [(u'Organize', 'NN')]
# [(u'cry', 'NN')]
# [(u'this', 'DT'), (u'tremendous', 'JJ'), (u'vote', 'NN')]
# [(u'party', 'NN')]
# [(u'This', 'DT'), (u'election', 'NN')]
# [(u'the', 'DT'), (u'excitement', 'NN')]
# [(u'this', 'DT'), (u'vote', 'NN')]
# [(u'resolution', 'NN')]
# [(u'the', 'DT'), (u'flush', 'NN')]
# [(u'victory', 'NN')]
# [(u'the', 'DT'), (u'country', 'NN')]
# [(u'the', 'DT'), (u'old', 'JJ'), (u'party', 'NN')]
# [(u'this', 'DT'), (u'vote', 'NN')]
# [(u'own', 'JJ'), (u'city', 'NN')]
# [(u'a', 'DT'), (u'municipal-ownership', 'JJ'), (u'Democracy', 'NN')]
# [(u'the', 'DT'), (u'spring', 'NN')]
# [(u'plunder', 'NN')]
# [(u'corruption', 'NN')]
# [(u'office', 'NN')]
# [(u'thing', 'NN')]
# [(u'the', 'DT'), (u'thing', 'NN')]
# [(u'city', 'NN')]
# [(u'municipal', 'JJ'), (u'ownership', 'NN')]
# [(u'party', 'NN')]
# [(u'opportunity', 'NN')]
# [(u'the', 'DT'), (u'radical', 'JJ'), (u'Democracy', 'NN')]
# [(u'a', 'DT'), (u'lie', 'NN')]
# [(u'nakedness', 'NN')]
# [(u'the', 'DT'), (u'rush', 'NN')]
# [(u'the', 'DT'), (u'tide', 'NN')]
# [(u'till', 'NN')]
# [(u'flood', 'NN')]
# [(u'the', 'DT'), (u'rallying', 'NN')]
# [(u'standard', 'NN')]
# [(u'the', 'DT'), (u'victory', 'NN')]
# [(u'the', 'DT'), (u'opposition', 'NN')]
